# %%
import torch
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from segment_anything import sam_model_registry
from torch.optim import Adam
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from scipy import ndimage

# ==================== CONFIGURATION ====================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Paths
train_image_dir = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_images'
train_mask_dir = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_1cmasks'
val_image_dir = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_images'
val_mask_dir =  '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_1cmasks'
sam_checkpoint = "/home/iiitdmk-param/Desktop/Research/3/Data/sam_vit_b.pth"
model_type = "vit_b"

# Training parameters
BATCH_SIZE = 4
NUM_EPOCHS = 100
LEARNING_RATE = 1e-4
NUM_CLASSES = 18

# Topological loss parameters
TOPO_LOSS_WEIGHT = 0.3  # Weight for topological loss

# ==================== CLASS INFORMATION ====================
CLASS_INFO = {
    0: {"name": "background", "rgb": [0, 0, 0]},
    1: {"name": "airplane", "rgb": [166, 202, 240]},
    2: {"name": "bare soil", "rgb": [128, 128, 0]},
    3: {"name": "buildings", "rgb": [0, 0, 128]},
    4: {"name": "cars", "rgb": [255, 0, 0]},
    5: {"name": "chaparral", "rgb": [0, 128, 0]},
    6: {"name": "court", "rgb": [128, 0, 0]},
    7: {"name": "dock", "rgb": [255, 233, 233]},
    8: {"name": "field", "rgb": [160, 160, 164]},
    9: {"name": "grass", "rgb": [0, 128, 128]},
    10: {"name": "mobile home", "rgb": [90, 87, 255]},
    11: {"name": "pavement", "rgb": [255, 255, 0]},
    12: {"name": "sand", "rgb": [255, 192, 0]},
    13: {"name": "sea", "rgb": [0, 0, 255]},
    14: {"name": "ship", "rgb": [255, 0, 192]},
    15: {"name": "tanks", "rgb": [128, 0, 128]},
    16: {"name": "trees", "rgb": [0, 255, 0]},
    17: {"name": "water", "rgb": [0, 255, 255]}
}

# ==================== TOPOLOGICAL LOSS ====================
class TopologicalLoss(nn.Module):
    def __init__(self, class_weights=None, eps=1e-8):
        """
        Topological loss for semantic segmentation
        Focuses on preserving connectivity and shape structure
        """
        super().__init__()
        self.eps = eps
        
        # Class-specific topological importance weights
        if class_weights is None:
            self.class_weights = {
                3: 1.0,   # buildings - high (solid, connected shapes)
                11: 1.2,  # pavement - very high (connectivity critical)
                13: 0.8,  # sea - medium (boundary smoothness)
                17: 0.8,  # water - medium (boundary smoothness)
                8: 0.5,   # field - low (some shape consistency)
                5: 0.4,   # chaparral - low
                9: 0.4,   # grass - low
                16: 0.4,  # trees - low
                # Other classes get default weight
            }
        else:
            self.class_weights = class_weights
            
        self.default_weight = 0.1

    def compute_component_loss(self, pred_binary, target_binary):
        """Compute loss for connected components (0D topology)"""
        if pred_binary.sum() == 0 and target_binary.sum() == 0:
            return torch.tensor(0.0, device=pred_binary.device)
        
        # Convert to numpy for connected component analysis
        pred_np = pred_binary.cpu().numpy().astype(np.uint8)
        target_np = target_binary.cpu().numpy().astype(np.uint8)
        
        # Count connected components
        pred_components, _ = ndimage.label(pred_np)
        target_components, _ = ndimage.label(target_np)
        
        pred_count = np.max(pred_components) if np.max(pred_components) > 0 else 0
        target_count = np.max(target_components) if np.max(target_components) > 0 else 0
        
        # Component count difference
        comp_diff = torch.abs(torch.tensor(pred_count - target_count, dtype=torch.float32, device=pred_binary.device))
        
        return comp_diff

    def compute_boundary_loss(self, pred_binary, target_binary):
        """Compute boundary consistency loss"""
        if pred_binary.sum() == 0 and target_binary.sum() == 0:
            return torch.tensor(0.0, device=pred_binary.device)
        
        # Convert to numpy for morphological operations
        pred_np = pred_binary.cpu().numpy().astype(np.uint8)
        target_np = target_binary.cpu().numpy().astype(np.uint8)
        
        # Compute boundaries using erosion
        kernel = np.ones((3, 3), np.uint8)
        pred_boundary = cv2.morphologyEx(pred_np, cv2.MORPH_GRADIENT, kernel)
        target_boundary = cv2.morphologyEx(target_np, cv2.MORPH_GRADIENT, kernel)
        
        # Boundary consistency
        boundary_intersection = np.logical_and(pred_boundary, target_boundary).sum()
        boundary_union = np.logical_or(pred_boundary, target_boundary).sum()
        
        if boundary_union == 0:
            return torch.tensor(0.0, device=pred_binary.device)
        
        boundary_iou = boundary_intersection / boundary_union
        boundary_loss = 1.0 - boundary_iou
        
        return torch.tensor(boundary_loss, dtype=torch.float32, device=pred_binary.device)

    def forward(self, pred_masks, target_masks):
        """
        Compute topological loss between predictions and targets
        
        Args:
            pred_masks: Tensor of shape [B, H, W] with class indices
            target_masks: Tensor of shape [B, H, W] with class indices
        """
        batch_size = pred_masks.shape[0]
        total_loss = 0.0
        valid_classes_count = 0
        
        for batch_idx in range(batch_size):
            pred_mask = pred_masks[batch_idx]
            target_mask = target_masks[batch_idx]
            
            # Get unique classes in this batch item
            unique_classes = torch.unique(torch.cat([pred_mask, target_mask]))
            
            for class_id in unique_classes:
                class_id = class_id.item()
                if class_id == 0:  # Skip background
                    continue
                    
                class_weight = self.class_weights.get(class_id, self.default_weight)
                if class_weight == 0:
                    continue
                
                # Extract binary masks for this class
                pred_binary = (pred_mask == class_id).float()
                target_binary = (target_mask == class_id).float()
                
                # Skip if both are empty
                if pred_binary.sum() == 0 and target_binary.sum() == 0:
                    continue
                
                class_loss = 0.0
                
                # 1. Component count loss
                comp_loss = self.compute_component_loss(pred_binary, target_binary)
                class_loss += comp_loss
                
                # 2. Boundary consistency loss
                boundary_loss = self.compute_boundary_loss(pred_binary, target_binary)
                class_loss += boundary_loss
                
                total_loss += class_weight * class_loss
                valid_classes_count += 1
        
        # Normalize by number of valid class comparisons
        if valid_classes_count > 0:
            total_loss = total_loss / valid_classes_count
        
        return total_loss

# ==================== COMBINED LOSS ====================
class CombinedLoss(nn.Module):
    def __init__(self, topo_weight=TOPO_LOSS_WEIGHT):
        super().__init__()
        self.ce_loss = nn.CrossEntropyLoss()
        self.topo_loss = TopologicalLoss()
        self.topo_weight = topo_weight
    
    def forward(self, logits, targets, pred_masks=None):
        # Standard cross entropy loss
        ce_loss = self.ce_loss(logits, targets)
        
        # Topological loss (if pred_masks are provided)
        if pred_masks is not None:
            topo_loss = self.topo_loss(pred_masks, targets)
            total_loss = ce_loss + self.topo_weight * topo_loss
            return total_loss, ce_loss, topo_loss
        else:
            return ce_loss, ce_loss, torch.tensor(0.0)

# ==================== SIMPLE DATA TRANSFORM ====================
class SimpleTransform:
    def __call__(self, image, mask):
        # Resize to 256x256 and normalize
        image = cv2.resize(image, (256, 256))
        mask = cv2.resize(mask, (256, 256), interpolation=cv2.INTER_NEAREST)
        
        # Normalize image
        image = image.astype(np.float32) / 255.0
        image = (image - np.array([0.485, 0.456, 0.406])) / np.array([0.229, 0.224, 0.225])
        
        # Convert to tensor
        image = torch.from_numpy(image).permute(2, 0, 1).float()
        mask = torch.from_numpy(mask).long()
        
        return image, mask

# ==================== MODEL ARCHITECTURE ====================
class HighIoUSAMWrapper(nn.Module):
    def __init__(self, sam_model, num_classes):
        super().__init__()
        self.sam = sam_model
        self.num_classes = num_classes
        
        # Simple segmentation head
        self.segmentation_head = nn.Sequential(
            nn.Conv2d(256, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, num_classes, 1)
        )
        
        # Freeze SAM encoder
        for param in self.sam.image_encoder.parameters():
            param.requires_grad = False
    
    def unfreeze_encoder(self, percentage=0.5):
        total_layers = len(list(self.sam.image_encoder.parameters()))
        layers_to_unfreeze = int(total_layers * percentage)
        
        for i, param in enumerate(self.sam.image_encoder.parameters()):
            if i >= (total_layers - layers_to_unfreeze):
                param.requires_grad = True
    
    def forward(self, x):
        # Input should be 1024x1024 for SAM
        image_embeddings = self.sam.image_encoder(x)
        logits = self.segmentation_head(image_embeddings)
        return logits

# ==================== DATASET ====================
class HighIoUDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        
        self.image_files = sorted([f for f in os.listdir(image_dir) 
                                 if f.endswith(('.png', '.jpg', '.jpeg', '.tif'))])
        
        print(f"Found {len(self.image_files)} images in {image_dir}")
    
    def __len__(self):
        return len(self.image_files)
    
    def __getitem__(self, idx):
        image_path = os.path.join(self.image_dir, self.image_files[idx])
        base_name = os.path.splitext(self.image_files[idx])[0]
        mask_path = os.path.join(self.mask_dir, base_name + '.png')
        
        # Load image
        image = cv2.imread(image_path)
        if image is None:
            raise ValueError(f"Could not load image: {image_path}")
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # Load mask
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        if mask is None:
            raise ValueError(f"Could not load mask: {mask_path}")
        
        # Apply transformations
        if self.transform:
            image, mask = self.transform(image, mask)
        else:
            # Default processing
            image = cv2.resize(image, (256, 256))
            mask = cv2.resize(mask, (256, 256), interpolation=cv2.INTER_NEAREST)
            image = torch.from_numpy(image).permute(2, 0, 1).float() / 255.0
            mask = torch.from_numpy(mask).long()
        
        return {'image': image, 'mask': mask}

# ==================== FIXED METRICS ====================
def calculate_iou(pred_mask, true_mask, num_classes):
    ious = []
    
    for class_id in range(num_classes):
        pred_inds = (pred_mask == class_id)
        target_inds = (true_mask == class_id)
        
        intersection = np.logical_and(pred_inds, target_inds).sum()
        union = np.logical_or(pred_inds, target_inds).sum()
        
        if union == 0:
            ious.append(float('nan'))
        else:
            ious.append(float(intersection / union))
    
    return np.nanmean(ious)

# ==================== MODIFIED TRAINING FUNCTION ====================
def train_high_iou_sam():
    print("=== PHASE 1: HIGH IoU SAM TRAINING WITH TOPOLOGICAL LOSS ===")
    print(f"Using batch size: {BATCH_SIZE}")
    print(f"Topological loss weight: {TOPO_LOSS_WEIGHT}")
    
    # Load SAM model
    print("Loading SAM model...")
    sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
    model = HighIoUSAMWrapper(sam, NUM_CLASSES).to(device)
    
    # Create datasets
    transform = SimpleTransform()
    train_dataset = HighIoUDataset(train_image_dir, train_mask_dir, transform)
    val_dataset = HighIoUDataset(val_image_dir, val_mask_dir, transform)
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
    
    print(f"Training samples: {len(train_dataset)}")
    print(f"Validation samples: {len(val_dataset)}")
    
    # Use combined loss with topological component
    criterion = CombinedLoss(topo_weight=TOPO_LOSS_WEIGHT)
    optimizer = Adam(model.parameters(), lr=LEARNING_RATE)
    scheduler = ReduceLROnPlateau(optimizer, mode='max', patience=5, factor=0.5, verbose=True)
    
    best_iou = 0.0
    
    print("Starting training with topological loss...")
    for epoch in range(NUM_EPOCHS):
        # Training phase
        model.train()
        epoch_total_loss = 0
        epoch_ce_loss = 0
        epoch_topo_loss = 0
        num_batches = 0
        
        for batch_idx, batch in enumerate(train_loader):
            images = batch['image'].to(device)
            masks = batch['mask'].to(device)
            
            # Ensure masks are long type
            if masks.dtype != torch.long:
                masks = masks.long()
            
            optimizer.zero_grad()
            
            # Resize images to 1024x1024 for SAM
            images_resized = F.interpolate(images, size=1024, mode='bilinear', align_corners=False)
            
            # Forward pass
            logits = model(images_resized)
            
            # Resize logits back to 256x256
            logits = F.interpolate(logits, size=256, mode='bilinear', align_corners=False)
            
            # Get predicted masks for topological loss
            pred_masks = torch.argmax(logits, dim=1)
            
            # Compute combined loss
            total_loss, ce_loss, topo_loss = criterion(logits, masks, pred_masks)
            
            total_loss.backward()
            optimizer.step()
            
            epoch_total_loss += total_loss.item()
            epoch_ce_loss += ce_loss.item()
            epoch_topo_loss += topo_loss.item()
            num_batches += 1
            
            if batch_idx % 10 == 0:
                print(f'Epoch {epoch+1}, Batch {batch_idx}: '
                      f'Total Loss: {total_loss.item():.4f}, '
                      f'CE: {ce_loss.item():.4f}, '
                      f'Topo: {topo_loss.item():.4f}')
        
        avg_total_loss = epoch_total_loss / num_batches
        avg_ce_loss = epoch_ce_loss / num_batches
        avg_topo_loss = epoch_topo_loss / num_batches
        
        # Validation phase
        model.eval()
        val_iou = 0
        num_val_samples = 0
        
        with torch.no_grad():
            for val_batch in val_loader:
                images = val_batch['image'].to(device)
                masks = val_batch['mask'].to(device)
                
                if masks.dtype != torch.long:
                    masks = masks.long()
                
                images_resized = F.interpolate(images, size=1024, mode='bilinear', align_corners=False)
                logits = model(images_resized)
                logits = F.interpolate(logits, size=256, mode='bilinear', align_corners=False)
                pred_masks = torch.argmax(logits, dim=1)
                
                for i in range(pred_masks.shape[0]):
                    iou = calculate_iou(pred_masks[i].cpu().numpy(), masks[i].cpu().numpy(), NUM_CLASSES)
                    val_iou += iou
                    num_val_samples += 1
        
        avg_val_iou = val_iou / num_val_samples if num_val_samples > 0 else 0
        scheduler.step(avg_val_iou)
        
        print(f'Epoch {epoch+1}/{NUM_EPOCHS}:')
        print(f'  Train - Total: {avg_total_loss:.4f}, CE: {avg_ce_loss:.4f}, Topo: {avg_topo_loss:.4f}')
        print(f'  Val IoU: {avg_val_iou:.4f}')
        
        if avg_val_iou > best_iou:
            best_iou = avg_val_iou
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': avg_total_loss,
                'iou': best_iou,
                'ce_loss': avg_ce_loss,
                'topo_loss': avg_topo_loss,
            }, 'topo_best_high_iou_sam.pth')
            print(f'✅ Saved new best model with IoU: {best_iou:.4f}')
        
        # Gradually unfreeze encoder
        if epoch == 20:
            model.unfreeze_encoder(0.3)
            print("🔄 Unfrozen 30% of encoder layers")
        elif epoch == 40:
            model.unfreeze_encoder(0.6)
            print("🔄 Unfrozen 60% of encoder layers")
        elif epoch == 60:
            model.unfreeze_encoder(1.0)
            print("🔄 Unfrozen all encoder layers")
        
        if best_iou > 0.85 and epoch > 50:
            print(f"🎯 Good IoU achieved! Stopping early at epoch {epoch+1}")
            break
    
    print(f"=== TRAINING COMPLETED ===")
    print(f"Best validation IoU: {best_iou:.4f}")
    
    return model, best_iou

# ==================== MAIN EXECUTION ====================
if __name__ == "__main__":
    trained_model, final_iou = train_high_iou_sam()
    
    print(f"\n🎯 PHASE 1 COMPLETED with IoU: {final_iou:.4f}")
    
    if final_iou >= 0.85:
        print("✅ Ready for Phase 2: Weak data processing")
    else:
        print("❌ Need to improve Phase 1")
# Out:
# Using device: cuda
# === PHASE 1: HIGH IoU SAM TRAINING WITH TOPOLOGICAL LOSS ===
# Using batch size: 4
# Topological loss weight: 0.3
# Loading SAM model...
# Found 630 images in /home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_images
# Found 630 images in /home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_images
# Training samples: 630
# Validation samples: 630
# Starting training with topological loss...
# Epoch 1, Batch 0: Total Loss: 11.3985, CE: 2.8515, Topo: 28.4898
# Epoch 1, Batch 10: Total Loss: 9.2062, CE: 2.7844, Topo: 21.4062
# Epoch 1, Batch 20: Total Loss: 6.6627, CE: 2.5309, Topo: 13.7729
# Epoch 1, Batch 30: Total Loss: 7.4592, CE: 2.7768, Topo: 15.6080
# Epoch 1, Batch 40: Total Loss: 6.3288, CE: 2.2665, Topo: 13.5409
# Epoch 1, Batch 50: Total Loss: 4.6027, CE: 2.0826, Topo: 8.4005
# Epoch 1, Batch 60: Total Loss: 4.9261, CE: 2.3891, Topo: 8.4567
# Epoch 1, Batch 70: Total Loss: 4.5065, CE: 1.9251, Topo: 8.6045
# Epoch 1, Batch 80: Total Loss: 5.6215, CE: 2.3159, Topo: 11.0185
# Epoch 1, Batch 90: Total Loss: 4.7645, CE: 2.2211, Topo: 8.4778
# Epoch 1, Batch 100: Total Loss: 4.7806, CE: 2.1656, Topo: 8.7168
# Epoch 1, Batch 110: Total Loss: 3.3368, CE: 1.8163, Topo: 5.0684
# Epoch 1, Batch 120: Total Loss: 4.3656, CE: 2.2250, Topo: 7.1355
# Epoch 1, Batch 130: Total Loss: 4.4025, CE: 2.1861, Topo: 7.3879
# Epoch 1, Batch 140: Total Loss: 4.1322, CE: 1.8209, Topo: 7.7041
# Epoch 1, Batch 150: Total Loss: 4.9253, CE: 2.3613, Topo: 8.5470
# Epoch 1/100:
#   Train - Total: 5.5294, CE: 2.2681, Topo: 10.8712
#   Val IoU: 0.1345
# ✅ Saved new best model with IoU: 0.1345
# Epoch 2, Batch 0: Total Loss: 4.0465, CE: 2.2936, Topo: 5.8432
# Epoch 2, Batch 10: Total Loss: 4.0178, CE: 2.0549, Topo: 6.5429
# Epoch 2, Batch 20: Total Loss: 3.9547, CE: 1.7978, Topo: 7.1895
# Epoch 2, Batch 30: Total Loss: 3.9115, CE: 1.8931, Topo: 6.7282
# Epoch 2, Batch 40: Total Loss: 2.9713, CE: 1.8281, Topo: 3.8107
# Epoch 2, Batch 50: Total Loss: 5.7305, CE: 2.1423, Topo: 11.9608
# Epoch 2, Batch 60: Total Loss: 4.5494, CE: 1.8762, Topo: 8.9109
# Epoch 2, Batch 70: Total Loss: 4.1407, CE: 1.6894, Topo: 8.1712
# Epoch 2, Batch 80: Total Loss: 3.4963, CE: 1.9335, Topo: 5.2093
# Epoch 2, Batch 90: Total Loss: 4.1654, CE: 1.9195, Topo: 7.4862
# Epoch 2, Batch 100: Total Loss: 4.6312, CE: 2.2241, Topo: 8.0235
# Epoch 2, Batch 110: Total Loss: 5.4152, CE: 2.5138, Topo: 9.6713
# Epoch 2, Batch 120: Total Loss: 4.7895, CE: 2.1061, Topo: 8.9446
# Epoch 2, Batch 130: Total Loss: 3.9466, CE: 1.7238, Topo: 7.4093
# Epoch 2, Batch 140: Total Loss: 4.5761, CE: 1.9488, Topo: 8.7575
# Epoch 2, Batch 150: Total Loss: 3.4718, CE: 1.7942, Topo: 5.5920
# Epoch 2/100:
#   Train - Total: 4.2062, CE: 1.9039, Topo: 7.6744
#   Val IoU: 0.1756
# ✅ Saved new best model with IoU: 0.1756
# Epoch 3, Batch 0: Total Loss: 3.7101, CE: 1.6030, Topo: 7.0236
# Epoch 3, Batch 10: Total Loss: 4.4086, CE: 1.8570, Topo: 8.5053
# Epoch 3, Batch 20: Total Loss: 4.3492, CE: 1.3621, Topo: 9.9573
# Epoch 3, Batch 30: Total Loss: 4.3007, CE: 1.7174, Topo: 8.6109
# Epoch 3, Batch 40: Total Loss: 4.6368, CE: 1.9611, Topo: 8.9191
# Epoch 3, Batch 50: Total Loss: 4.9476, CE: 1.8214, Topo: 10.4209
# Epoch 3, Batch 60: Total Loss: 3.6801, CE: 1.5952, Topo: 6.9498
# Epoch 3, Batch 70: Total Loss: 3.0135, CE: 1.5705, Topo: 4.8102
# Epoch 3, Batch 80: Total Loss: 3.8675, CE: 1.6030, Topo: 7.5483
# Epoch 3, Batch 90: Total Loss: 3.3705, CE: 1.4934, Topo: 6.2570
# Epoch 3, Batch 100: Total Loss: 4.6551, CE: 1.8546, Topo: 9.3350
# Epoch 3, Batch 110: Total Loss: 4.1798, CE: 1.7081, Topo: 8.2391
# Epoch 3, Batch 120: Total Loss: 3.9272, CE: 1.6508, Topo: 7.5878
# Epoch 3, Batch 130: Total Loss: 3.1008, CE: 1.2888, Topo: 6.0399
# Epoch 3, Batch 140: Total Loss: 2.8869, CE: 1.2948, Topo: 5.3070
# Epoch 3, Batch 150: Total Loss: 3.9541, CE: 1.6461, Topo: 7.6932
# Epoch 3/100:
#   Train - Total: 3.9237, CE: 1.6973, Topo: 7.4214
#   Val IoU: 0.2082
# ✅ Saved new best model with IoU: 0.2082
# Epoch 4, Batch 0: Total Loss: 4.0359, CE: 1.7299, Topo: 7.6865
# Epoch 4, Batch 10: Total Loss: 3.4426, CE: 1.5643, Topo: 6.2608
# Epoch 4, Batch 20: Total Loss: 2.7555, CE: 1.4966, Topo: 4.1961
# Epoch 4, Batch 30: Total Loss: 3.4192, CE: 1.5882, Topo: 6.1035
# Epoch 4, Batch 40: Total Loss: 3.7655, CE: 1.4321, Topo: 7.7778
# Epoch 4, Batch 50: Total Loss: 3.9998, CE: 1.7563, Topo: 7.4784
# Epoch 4, Batch 60: Total Loss: 3.4334, CE: 1.8280, Topo: 5.3512
# Epoch 4, Batch 70: Total Loss: 3.5174, CE: 1.8993, Topo: 5.3935
# Epoch 4, Batch 80: Total Loss: 2.7805, CE: 1.2959, Topo: 4.9486
# Epoch 4, Batch 90: Total Loss: 3.2580, CE: 1.3754, Topo: 6.2752
# Epoch 4, Batch 100: Total Loss: 3.7659, CE: 1.3445, Topo: 8.0716
# Epoch 4, Batch 110: Total Loss: 4.0106, CE: 1.5504, Topo: 8.2008
# Epoch 4, Batch 120: Total Loss: 3.5945, CE: 1.8348, Topo: 5.8658
# Epoch 4, Batch 130: Total Loss: 7.0293, CE: 1.3138, Topo: 19.0515
# Epoch 4, Batch 140: Total Loss: 4.0195, CE: 1.9586, Topo: 6.8698
# Epoch 4, Batch 150: Total Loss: 3.0856, CE: 1.2316, Topo: 6.1799
# Epoch 4/100:
#   Train - Total: 3.7043, CE: 1.5671, Topo: 7.1241
#   Val IoU: 0.2276
# ✅ Saved new best model with IoU: 0.2276
# Epoch 5, Batch 0: Total Loss: 4.2529, CE: 1.6758, Topo: 8.5903
# Epoch 5, Batch 10: Total Loss: 2.7600, CE: 1.1741, Topo: 5.2862
# Epoch 5, Batch 20: Total Loss: 3.6694, CE: 1.4595, Topo: 7.3663
# Epoch 5, Batch 30: Total Loss: 2.5947, CE: 1.2049, Topo: 4.6328
# Epoch 5, Batch 40: Total Loss: 3.8466, CE: 1.8449, Topo: 6.6723
# Epoch 5, Batch 50: Total Loss: 2.9963, CE: 1.4955, Topo: 5.0028
# Epoch 5, Batch 60: Total Loss: 3.7604, CE: 1.2845, Topo: 8.2532
# Epoch 5, Batch 70: Total Loss: 2.5253, CE: 1.0323, Topo: 4.9767
# Epoch 5, Batch 80: Total Loss: 3.9067, CE: 1.9926, Topo: 6.3802
# Epoch 5, Batch 90: Total Loss: 3.6405, CE: 1.8237, Topo: 6.0560
# Epoch 5, Batch 100: Total Loss: 4.2539, CE: 1.5114, Topo: 9.1418
# Epoch 5, Batch 110: Total Loss: 3.7111, CE: 1.9537, Topo: 5.8579
# Epoch 5, Batch 120: Total Loss: 3.7276, CE: 1.1731, Topo: 8.5150
# Epoch 5, Batch 130: Total Loss: 4.1145, CE: 1.6687, Topo: 8.1526
# Epoch 5, Batch 140: Total Loss: 3.3299, CE: 1.1721, Topo: 7.1926
# Epoch 5, Batch 150: Total Loss: 4.0259, CE: 1.3295, Topo: 8.9878
# Epoch 5/100:
#   Train - Total: 3.6213, CE: 1.4673, Topo: 7.1798
#   Val IoU: 0.2414
# ✅ Saved new best model with IoU: 0.2414
# Epoch 6, Batch 0: Total Loss: 3.0646, CE: 1.6424, Topo: 4.7407
# Epoch 6, Batch 10: Total Loss: 3.9796, CE: 1.5835, Topo: 7.9869
# Epoch 6, Batch 20: Total Loss: 2.8870, CE: 1.4777, Topo: 4.6976
# Epoch 6, Batch 30: Total Loss: 3.6222, CE: 1.5650, Topo: 6.8574
# Epoch 6, Batch 40: Total Loss: 3.5482, CE: 1.4940, Topo: 6.8472
# Epoch 6, Batch 50: Total Loss: 4.5231, CE: 1.4641, Topo: 10.1965
# Epoch 6, Batch 60: Total Loss: 4.3290, CE: 1.3508, Topo: 9.9276
# Epoch 6, Batch 70: Total Loss: 3.5232, CE: 1.5039, Topo: 6.7307
# Epoch 6, Batch 80: Total Loss: 5.5759, CE: 1.2293, Topo: 14.4884
# Epoch 6, Batch 90: Total Loss: 3.0287, CE: 1.2565, Topo: 5.9076
# Epoch 6, Batch 100: Total Loss: 3.1618, CE: 1.3299, Topo: 6.1063
# Epoch 6, Batch 110: Total Loss: 3.2167, CE: 1.2774, Topo: 6.4644
# Epoch 6, Batch 120: Total Loss: 2.8682, CE: 1.1865, Topo: 5.6058
# Epoch 6, Batch 130: Total Loss: 2.6718, CE: 1.0985, Topo: 5.2441
# Epoch 6, Batch 140: Total Loss: 3.6243, CE: 1.4417, Topo: 7.2755
# Epoch 6, Batch 150: Total Loss: 3.0249, CE: 1.2123, Topo: 6.0420
# Epoch 6/100:
#   Train - Total: 3.5843, CE: 1.3837, Topo: 7.3355
#   Val IoU: 0.2336
# Epoch 7, Batch 0: Total Loss: 3.4124, CE: 1.5063, Topo: 6.3539
# Epoch 7, Batch 10: Total Loss: 2.9084, CE: 1.0699, Topo: 6.1285
# Epoch 7, Batch 20: Total Loss: 3.5193, CE: 1.1866, Topo: 7.7756
# Epoch 7, Batch 30: Total Loss: 4.2907, CE: 1.6715, Topo: 8.7306
# Epoch 7, Batch 40: Total Loss: 4.3514, CE: 1.3756, Topo: 9.9193
# Epoch 7, Batch 50: Total Loss: 2.9317, CE: 1.1494, Topo: 5.9412
# Epoch 7, Batch 60: Total Loss: 4.1215, CE: 1.2516, Topo: 9.5664
# Epoch 7, Batch 70: Total Loss: 5.5417, CE: 1.3354, Topo: 14.0211
# Epoch 7, Batch 80: Total Loss: 4.0223, CE: 1.4342, Topo: 8.6270
# Epoch 7, Batch 90: Total Loss: 2.8988, CE: 1.2200, Topo: 5.5962
# Epoch 7, Batch 100: Total Loss: 3.7283, CE: 1.1942, Topo: 8.4470
# Epoch 7, Batch 110: Total Loss: 3.8444, CE: 1.8712, Topo: 6.5774
# Epoch 7, Batch 120: Total Loss: 4.1014, CE: 1.5208, Topo: 8.6020
# Epoch 7, Batch 130: Total Loss: 3.8673, CE: 1.2880, Topo: 8.5977
# Epoch 7, Batch 140: Total Loss: 4.9387, CE: 1.9888, Topo: 9.8330
# Epoch 7, Batch 150: Total Loss: 3.4504, CE: 1.2816, Topo: 7.2294
# Epoch 7/100:
#   Train - Total: 3.6208, CE: 1.3432, Topo: 7.5920
#   Val IoU: 0.2501
# ✅ Saved new best model with IoU: 0.2501
# Epoch 8, Batch 0: Total Loss: 2.6697, CE: 1.0263, Topo: 5.4781
# Epoch 8, Batch 10: Total Loss: 3.0830, CE: 1.0719, Topo: 6.7037
# Epoch 8, Batch 20: Total Loss: 3.3397, CE: 0.9217, Topo: 8.0599
# Epoch 8, Batch 30: Total Loss: 3.2638, CE: 1.1337, Topo: 7.1003
# Epoch 8, Batch 40: Total Loss: 3.2889, CE: 0.9671, Topo: 7.7391
# Epoch 8, Batch 50: Total Loss: 4.9105, CE: 1.2901, Topo: 12.0683
# Epoch 8, Batch 60: Total Loss: 3.4708, CE: 1.1850, Topo: 7.6191
# Epoch 8, Batch 70: Total Loss: 3.8672, CE: 1.1121, Topo: 9.1838
# Epoch 8, Batch 80: Total Loss: 4.6797, CE: 1.2280, Topo: 11.5057
# Epoch 8, Batch 90: Total Loss: 3.9717, CE: 1.7074, Topo: 7.5477
# Epoch 8, Batch 100: Total Loss: 3.4642, CE: 1.2391, Topo: 7.4170
# Epoch 8, Batch 110: Total Loss: 3.5233, CE: 1.6274, Topo: 6.3195
# Epoch 8, Batch 120: Total Loss: 3.0752, CE: 1.2436, Topo: 6.1056
# Epoch 8, Batch 130: Total Loss: 2.8027, CE: 1.1570, Topo: 5.4857
# Epoch 8, Batch 140: Total Loss: 2.6030, CE: 1.1014, Topo: 5.0054
# Epoch 8, Batch 150: Total Loss: 2.3773, CE: 1.1864, Topo: 3.9694
# Epoch 8/100:
#   Train - Total: 3.4483, CE: 1.2871, Topo: 7.2042
#   Val IoU: 0.2718
# ✅ Saved new best model with IoU: 0.2718
# Epoch 9, Batch 0: Total Loss: 3.9455, CE: 2.0425, Topo: 6.3433
# Epoch 9, Batch 10: Total Loss: 3.1854, CE: 1.5893, Topo: 5.3205
# Epoch 9, Batch 20: Total Loss: 4.0009, CE: 1.3740, Topo: 8.7562
# Epoch 9, Batch 30: Total Loss: 5.0792, CE: 1.3540, Topo: 12.4172
# Epoch 9, Batch 40: Total Loss: 3.3259, CE: 1.1179, Topo: 7.3601
# Epoch 9, Batch 50: Total Loss: 2.2329, CE: 0.7679, Topo: 4.8835
# Epoch 9, Batch 60: Total Loss: 3.2619, CE: 1.4641, Topo: 5.9929
# Epoch 9, Batch 70: Total Loss: 3.5112, CE: 1.4320, Topo: 6.9305
# Epoch 9, Batch 80: Total Loss: 2.3725, CE: 0.8667, Topo: 5.0194
# Epoch 9, Batch 90: Total Loss: 3.1740, CE: 1.2493, Topo: 6.4158
# Epoch 9, Batch 100: Total Loss: 3.3268, CE: 1.2963, Topo: 6.7685
# Epoch 9, Batch 110: Total Loss: 3.8564, CE: 1.2734, Topo: 8.6101
# Epoch 9, Batch 120: Total Loss: 3.1110, CE: 1.3735, Topo: 5.7917
# Epoch 9, Batch 130: Total Loss: 3.1697, CE: 1.3090, Topo: 6.2022
# Epoch 9, Batch 140: Total Loss: 3.3655, CE: 1.5778, Topo: 5.9588
# Epoch 9, Batch 150: Total Loss: 3.2569, CE: 0.8492, Topo: 8.0257
# Epoch 9/100:
#   Train - Total: 3.5291, CE: 1.2659, Topo: 7.5443
#   Val IoU: 0.2650
# Epoch 10, Batch 0: Total Loss: 3.4128, CE: 1.2968, Topo: 7.0535
# Epoch 10, Batch 10: Total Loss: 3.7178, CE: 1.2384, Topo: 8.2649
# Epoch 10, Batch 20: Total Loss: 3.2863, CE: 0.8756, Topo: 8.0358
# Epoch 10, Batch 30: Total Loss: 3.4513, CE: 1.1487, Topo: 7.6753
# Epoch 10, Batch 40: Total Loss: 3.2281, CE: 1.0174, Topo: 7.3691
# Epoch 10, Batch 50: Total Loss: 2.5071, CE: 1.1018, Topo: 4.6845
# Epoch 10, Batch 60: Total Loss: 3.4382, CE: 1.1350, Topo: 7.6775
# Epoch 10, Batch 70: Total Loss: 4.6493, CE: 1.3245, Topo: 11.0826
# Epoch 10, Batch 80: Total Loss: 3.0904, CE: 1.1067, Topo: 6.6123
# Epoch 10, Batch 90: Total Loss: 3.9758, CE: 1.0592, Topo: 9.7219
# Epoch 10, Batch 100: Total Loss: 3.8046, CE: 1.3913, Topo: 8.0444
# Epoch 10, Batch 110: Total Loss: 2.8264, CE: 1.0161, Topo: 6.0343
# Epoch 10, Batch 120: Total Loss: 2.3476, CE: 0.9993, Topo: 4.4942
# Epoch 10, Batch 130: Total Loss: 3.6493, CE: 1.1959, Topo: 8.1782
# Epoch 10, Batch 140: Total Loss: 3.3188, CE: 1.1295, Topo: 7.2977
# Epoch 10, Batch 150: Total Loss: 3.3879, CE: 1.1648, Topo: 7.4104
# Epoch 10/100:
#   Train - Total: 3.3874, CE: 1.2247, Topo: 7.2090
#   Val IoU: 0.2837
# ✅ Saved new best model with IoU: 0.2837
# Epoch 11, Batch 0: Total Loss: 3.9739, CE: 1.4266, Topo: 8.4910
# Epoch 11, Batch 10: Total Loss: 4.0681, CE: 1.2824, Topo: 9.2859
# Epoch 11, Batch 20: Total Loss: 2.3320, CE: 0.9399, Topo: 4.6404
# Epoch 11, Batch 30: Total Loss: 3.1442, CE: 1.3269, Topo: 6.0575
# Epoch 11, Batch 40: Total Loss: 2.6953, CE: 1.0821, Topo: 5.3774
# Epoch 11, Batch 50: Total Loss: 3.2675, CE: 1.1973, Topo: 6.9007
# Epoch 11, Batch 60: Total Loss: 3.9506, CE: 1.5694, Topo: 7.9373
# Epoch 11, Batch 70: Total Loss: 7.6166, CE: 1.3413, Topo: 20.9175
# Epoch 11, Batch 80: Total Loss: 3.8941, CE: 1.1065, Topo: 9.2920
# Epoch 11, Batch 90: Total Loss: 3.1218, CE: 1.2298, Topo: 6.3068
# Epoch 11, Batch 100: Total Loss: 2.8306, CE: 1.1407, Topo: 5.6329
# Epoch 11, Batch 110: Total Loss: 3.1382, CE: 1.3568, Topo: 5.9380
# Epoch 11, Batch 120: Total Loss: 3.3165, CE: 1.2873, Topo: 6.7642
# Epoch 11, Batch 130: Total Loss: 3.8652, CE: 1.3080, Topo: 8.5239
# Epoch 11, Batch 140: Total Loss: 3.6730, CE: 1.4529, Topo: 7.4001
# Epoch 11, Batch 150: Total Loss: 4.3468, CE: 1.6414, Topo: 9.0182
# Epoch 11/100:
#   Train - Total: 3.3389, CE: 1.1609, Topo: 7.2600
#   Val IoU: 0.2682
# Epoch 12, Batch 0: Total Loss: 2.7209, CE: 1.2230, Topo: 4.9930
# Epoch 12, Batch 10: Total Loss: 3.2619, CE: 1.4110, Topo: 6.1695
# Epoch 12, Batch 20: Total Loss: 2.4432, CE: 0.9290, Topo: 5.0475
# Epoch 12, Batch 30: Total Loss: 2.7582, CE: 0.9466, Topo: 6.0388
# Epoch 12, Batch 40: Total Loss: 2.7568, CE: 1.2117, Topo: 5.1503
# Epoch 12, Batch 50: Total Loss: 3.4353, CE: 1.2117, Topo: 7.4119
# Epoch 12, Batch 60: Total Loss: 3.3764, CE: 1.2242, Topo: 7.1738
# Epoch 12, Batch 70: Total Loss: 2.9321, CE: 1.0238, Topo: 6.3608
# Epoch 12, Batch 80: Total Loss: 4.0878, CE: 1.4004, Topo: 8.9578
# Epoch 12, Batch 90: Total Loss: 2.8986, CE: 1.2355, Topo: 5.5438
# Epoch 12, Batch 100: Total Loss: 3.5598, CE: 1.2164, Topo: 7.8114
# Epoch 12, Batch 110: Total Loss: 4.4526, CE: 1.4122, Topo: 10.1348
# Epoch 12, Batch 120: Total Loss: 2.9527, CE: 1.2257, Topo: 5.7565
# Epoch 12, Batch 130: Total Loss: 2.4528, CE: 0.7061, Topo: 5.8224
# Epoch 12, Batch 140: Total Loss: 3.2813, CE: 1.1106, Topo: 7.2357
# Epoch 12, Batch 150: Total Loss: 4.1705, CE: 1.4291, Topo: 9.1380
# Epoch 12/100:
#   Train - Total: 3.2450, CE: 1.1420, Topo: 7.0101
#   Val IoU: 0.2862
# ✅ Saved new best model with IoU: 0.2862
# Epoch 13, Batch 0: Total Loss: 3.6376, CE: 1.3740, Topo: 7.5454
# Epoch 13, Batch 10: Total Loss: 3.3934, CE: 1.0526, Topo: 7.8026
# Epoch 13, Batch 20: Total Loss: 3.7333, CE: 1.2879, Topo: 8.1515
# Epoch 13, Batch 30: Total Loss: 2.5160, CE: 0.9490, Topo: 5.2234
# Epoch 13, Batch 40: Total Loss: 3.9260, CE: 1.2117, Topo: 9.0477
# Epoch 13, Batch 50: Total Loss: 2.9399, CE: 1.2070, Topo: 5.7762
# Epoch 13, Batch 60: Total Loss: 2.7851, CE: 1.2229, Topo: 5.2073
# Epoch 13, Batch 70: Total Loss: 2.6077, CE: 1.0631, Topo: 5.1488
# Epoch 13, Batch 80: Total Loss: 3.9148, CE: 1.8257, Topo: 6.9634
# Epoch 13, Batch 90: Total Loss: 3.2833, CE: 1.0873, Topo: 7.3201
# Epoch 13, Batch 100: Total Loss: 1.7698, CE: 0.5932, Topo: 3.9220
# Epoch 13, Batch 110: Total Loss: 3.7532, CE: 0.8835, Topo: 9.5654
# Epoch 13, Batch 120: Total Loss: 2.6400, CE: 1.1732, Topo: 4.8893
# Epoch 13, Batch 130: Total Loss: 4.0346, CE: 1.3600, Topo: 8.9156
# Epoch 13, Batch 140: Total Loss: 2.7439, CE: 1.1731, Topo: 5.2363
# Epoch 13, Batch 150: Total Loss: 3.4811, CE: 1.4262, Topo: 6.8497
# Epoch 13/100:
#   Train - Total: 3.2925, CE: 1.1364, Topo: 7.1870
#   Val IoU: 0.2711
# Epoch 14, Batch 0: Total Loss: 3.3291, CE: 0.7733, Topo: 8.5193
# Epoch 14, Batch 10: Total Loss: 4.0615, CE: 1.3664, Topo: 8.9835
# Epoch 14, Batch 20: Total Loss: 3.1424, CE: 0.8330, Topo: 7.6978
# Epoch 14, Batch 30: Total Loss: 2.1360, CE: 0.8741, Topo: 4.2062
# Epoch 14, Batch 40: Total Loss: 4.2214, CE: 1.4039, Topo: 9.3915
# Epoch 14, Batch 50: Total Loss: 2.8481, CE: 0.9155, Topo: 6.4418
# Epoch 14, Batch 60: Total Loss: 3.1340, CE: 1.0956, Topo: 6.7946
# Epoch 14, Batch 70: Total Loss: 3.0470, CE: 1.1146, Topo: 6.4412
# Epoch 14, Batch 80: Total Loss: 1.9815, CE: 0.7054, Topo: 4.2537
# Epoch 14, Batch 90: Total Loss: 2.4156, CE: 0.8189, Topo: 5.3224
# Epoch 14, Batch 100: Total Loss: 3.2320, CE: 0.9240, Topo: 7.6935
# Epoch 14, Batch 110: Total Loss: 3.2144, CE: 1.3868, Topo: 6.0921
# Epoch 14, Batch 120: Total Loss: 3.9484, CE: 1.1460, Topo: 9.3414
# Epoch 14, Batch 130: Total Loss: 3.7265, CE: 0.9218, Topo: 9.3490
# Epoch 14, Batch 140: Total Loss: 4.2356, CE: 1.2161, Topo: 10.0648
# Epoch 14, Batch 150: Total Loss: 3.8439, CE: 1.1552, Topo: 8.9622
# Epoch 14/100:
#   Train - Total: 3.3110, CE: 1.1167, Topo: 7.3144
#   Val IoU: 0.2830
# Epoch 15, Batch 0: Total Loss: 2.9761, CE: 0.9188, Topo: 6.8577
# Epoch 15, Batch 10: Total Loss: 3.2258, CE: 1.0837, Topo: 7.1404
# Epoch 15, Batch 20: Total Loss: 3.0660, CE: 1.1336, Topo: 6.4414
# Epoch 15, Batch 30: Total Loss: 2.8260, CE: 0.8778, Topo: 6.4937
# Epoch 15, Batch 40: Total Loss: 3.9077, CE: 1.3828, Topo: 8.4164
# Epoch 15, Batch 50: Total Loss: 2.8517, CE: 1.0835, Topo: 5.8941
# Epoch 15, Batch 60: Total Loss: 3.4779, CE: 1.0365, Topo: 8.1381
# Epoch 15, Batch 70: Total Loss: 3.4839, CE: 1.2124, Topo: 7.5719
# Epoch 15, Batch 80: Total Loss: 3.7034, CE: 1.3838, Topo: 7.7322
# Epoch 15, Batch 90: Total Loss: 3.8311, CE: 1.2104, Topo: 8.7357
# Epoch 15, Batch 100: Total Loss: 3.9241, CE: 1.0306, Topo: 9.6447
# Epoch 15, Batch 110: Total Loss: 3.2953, CE: 1.1024, Topo: 7.3097
# Epoch 15, Batch 120: Total Loss: 3.1423, CE: 1.1077, Topo: 6.7820
# Epoch 15, Batch 130: Total Loss: 2.7444, CE: 0.8420, Topo: 6.3415
# Epoch 15, Batch 140: Total Loss: 2.6060, CE: 1.2832, Topo: 4.4092
# Epoch 15, Batch 150: Total Loss: 3.4740, CE: 1.1476, Topo: 7.7547
# Epoch 15/100:
#   Train - Total: 3.2589, CE: 1.0806, Topo: 7.2607
#   Val IoU: 0.3021
# ✅ Saved new best model with IoU: 0.3021
# Epoch 16, Batch 0: Total Loss: 1.8288, CE: 0.6981, Topo: 3.7692
# Epoch 16, Batch 10: Total Loss: 3.6041, CE: 0.8028, Topo: 9.3377
# Epoch 16, Batch 20: Total Loss: 2.6261, CE: 0.7126, Topo: 6.3783
# Epoch 16, Batch 30: Total Loss: 4.4270, CE: 1.1540, Topo: 10.9101
# Epoch 16, Batch 40: Total Loss: 3.0541, CE: 1.0918, Topo: 6.5412
# Epoch 16, Batch 50: Total Loss: 3.5793, CE: 1.2036, Topo: 7.9192
# Epoch 16, Batch 60: Total Loss: 3.4428, CE: 1.5568, Topo: 6.2866
# Epoch 16, Batch 70: Total Loss: 2.0573, CE: 0.7704, Topo: 4.2896
# Epoch 16, Batch 80: Total Loss: 2.7787, CE: 0.8515, Topo: 6.4243
# Epoch 16, Batch 90: Total Loss: 3.6154, CE: 0.9169, Topo: 8.9951
# Epoch 16, Batch 100: Total Loss: 3.6502, CE: 1.4338, Topo: 7.3880
# Epoch 16, Batch 110: Total Loss: 2.6498, CE: 0.9579, Topo: 5.6398
# Epoch 16, Batch 120: Total Loss: 2.7470, CE: 0.9077, Topo: 6.1311
# Epoch 16, Batch 130: Total Loss: 2.4198, CE: 1.0056, Topo: 4.7139
# Epoch 16, Batch 140: Total Loss: 2.9392, CE: 0.8966, Topo: 6.8086
# Epoch 16, Batch 150: Total Loss: 3.5841, CE: 1.2527, Topo: 7.7715
# Epoch 16/100:
#   Train - Total: 3.1150, CE: 1.0491, Topo: 6.8864
#   Val IoU: 0.2870
# Epoch 17, Batch 0: Total Loss: 3.0612, CE: 1.0421, Topo: 6.7305
# Epoch 17, Batch 10: Total Loss: 3.8681, CE: 1.1388, Topo: 9.0973
# Epoch 17, Batch 20: Total Loss: 3.9489, CE: 1.0044, Topo: 9.8151
# Epoch 17, Batch 30: Total Loss: 4.2239, CE: 1.5259, Topo: 8.9934
# Epoch 17, Batch 40: Total Loss: 2.1533, CE: 0.7170, Topo: 4.7877
# Epoch 17, Batch 50: Total Loss: 2.9362, CE: 0.9572, Topo: 6.5966
# Epoch 17, Batch 60: Total Loss: 3.0227, CE: 1.0693, Topo: 6.5113
# Epoch 17, Batch 70: Total Loss: 3.0503, CE: 0.6723, Topo: 7.9268
# Epoch 17, Batch 80: Total Loss: 2.9770, CE: 1.0320, Topo: 6.4835
# Epoch 17, Batch 90: Total Loss: 6.9367, CE: 0.9852, Topo: 19.8383
# Epoch 17, Batch 100: Total Loss: 3.0763, CE: 1.0574, Topo: 6.7297
# Epoch 17, Batch 110: Total Loss: 3.7459, CE: 1.6293, Topo: 7.0553
# Epoch 17, Batch 120: Total Loss: 4.1937, CE: 1.0063, Topo: 10.6249
# Epoch 17, Batch 130: Total Loss: 3.0657, CE: 1.2155, Topo: 6.1673
# Epoch 17, Batch 140: Total Loss: 2.2884, CE: 0.7382, Topo: 5.1673
# Epoch 17, Batch 150: Total Loss: 3.7095, CE: 0.9676, Topo: 9.1397
# Epoch 17/100:
#   Train - Total: 3.3015, CE: 1.0556, Topo: 7.4863
#   Val IoU: 0.2949
# Epoch 18, Batch 0: Total Loss: 3.7547, CE: 1.0451, Topo: 9.0320
# Epoch 18, Batch 10: Total Loss: 3.5611, CE: 1.2800, Topo: 7.6037
# Epoch 18, Batch 20: Total Loss: 3.3018, CE: 0.8556, Topo: 8.1542
# Epoch 18, Batch 30: Total Loss: 2.6244, CE: 0.6444, Topo: 6.6000
# Epoch 18, Batch 40: Total Loss: 1.8482, CE: 0.6481, Topo: 4.0005
# Epoch 18, Batch 50: Total Loss: 2.2105, CE: 0.7114, Topo: 4.9968
# Epoch 18, Batch 60: Total Loss: 2.9640, CE: 1.2663, Topo: 5.6591
# Epoch 18, Batch 70: Total Loss: 2.9505, CE: 0.7311, Topo: 7.3981
# Epoch 18, Batch 80: Total Loss: 2.2468, CE: 0.8155, Topo: 4.7710
# Epoch 18, Batch 90: Total Loss: 3.5955, CE: 1.2006, Topo: 7.9831
# Epoch 18, Batch 100: Total Loss: 3.9815, CE: 1.6362, Topo: 7.8177
# Epoch 18, Batch 110: Total Loss: 3.6561, CE: 1.5495, Topo: 7.0220
# Epoch 18, Batch 120: Total Loss: 2.6605, CE: 0.9822, Topo: 5.5943
# Epoch 18, Batch 130: Total Loss: 3.1573, CE: 0.9230, Topo: 7.4475
# Epoch 18, Batch 140: Total Loss: 3.1667, CE: 1.3402, Topo: 6.0882
# Epoch 18, Batch 150: Total Loss: 2.9987, CE: 0.8960, Topo: 7.0091
# Epoch 18/100:
#   Train - Total: 3.1302, CE: 1.0253, Topo: 7.0163
#   Val IoU: 0.3016
# Epoch 19, Batch 0: Total Loss: 2.8873, CE: 0.7749, Topo: 7.0415
# Epoch 19, Batch 10: Total Loss: 2.8329, CE: 1.3348, Topo: 4.9937
# Epoch 19, Batch 20: Total Loss: 3.4135, CE: 0.8652, Topo: 8.4945
# Epoch 19, Batch 30: Total Loss: 3.7944, CE: 0.8589, Topo: 9.7850
# Epoch 19, Batch 40: Total Loss: 2.0916, CE: 0.6769, Topo: 4.7157
# Epoch 19, Batch 50: Total Loss: 2.7034, CE: 1.1686, Topo: 5.1161
# Epoch 19, Batch 60: Total Loss: 3.1061, CE: 1.2499, Topo: 6.1876
# Epoch 19, Batch 70: Total Loss: 2.9262, CE: 0.9905, Topo: 6.4524
# Epoch 19, Batch 80: Total Loss: 4.4329, CE: 1.4980, Topo: 9.7830
# Epoch 19, Batch 90: Total Loss: 4.0553, CE: 1.4781, Topo: 8.5907
# Epoch 19, Batch 100: Total Loss: 2.2164, CE: 1.1571, Topo: 3.5311
# Epoch 19, Batch 110: Total Loss: 3.0819, CE: 1.1480, Topo: 6.4462
# Epoch 19, Batch 120: Total Loss: 3.4193, CE: 0.7809, Topo: 8.7945
# Epoch 19, Batch 130: Total Loss: 3.5904, CE: 1.3444, Topo: 7.4866
# Epoch 19, Batch 140: Total Loss: 2.9187, CE: 1.0929, Topo: 6.0860
# Epoch 19, Batch 150: Total Loss: 3.8285, CE: 0.7605, Topo: 10.2267
# Epoch 19/100:
#   Train - Total: 3.2006, CE: 1.0206, Topo: 7.2668
#   Val IoU: 0.2992
# Epoch 20, Batch 0: Total Loss: 2.4235, CE: 0.8675, Topo: 5.1864
# Epoch 20, Batch 10: Total Loss: 2.3572, CE: 0.7652, Topo: 5.3066
# Epoch 20, Batch 20: Total Loss: 2.8522, CE: 1.0249, Topo: 6.0910
# Epoch 20, Batch 30: Total Loss: 2.6318, CE: 0.9585, Topo: 5.5776
# Epoch 20, Batch 40: Total Loss: 2.7892, CE: 0.9588, Topo: 6.1014
# Epoch 20, Batch 50: Total Loss: 3.4813, CE: 1.1878, Topo: 7.6451
# Epoch 20, Batch 60: Total Loss: 2.7825, CE: 0.7215, Topo: 6.8698
# Epoch 20, Batch 70: Total Loss: 2.6458, CE: 1.0151, Topo: 5.4357
# Epoch 20, Batch 80: Total Loss: 4.0105, CE: 1.3198, Topo: 8.9691
# Epoch 20, Batch 90: Total Loss: 3.0782, CE: 1.0931, Topo: 6.6172
# Epoch 20, Batch 100: Total Loss: 3.0496, CE: 0.9744, Topo: 6.9173
# Epoch 20, Batch 110: Total Loss: 2.4452, CE: 0.8670, Topo: 5.2606
# Epoch 20, Batch 120: Total Loss: 2.6391, CE: 0.7399, Topo: 6.3307
# Epoch 20, Batch 130: Total Loss: 2.7653, CE: 1.0972, Topo: 5.5601
# Epoch 20, Batch 140: Total Loss: 2.5512, CE: 0.8092, Topo: 5.8067
# Epoch 20, Batch 150: Total Loss: 4.0151, CE: 1.3021, Topo: 9.0433
# Epoch 20/100:
#   Train - Total: 3.0953, CE: 0.9852, Topo: 7.0337
#   Val IoU: 0.3128
# ✅ Saved new best model with IoU: 0.3128
# Epoch 21, Batch 0: Total Loss: 2.2541, CE: 0.7712, Topo: 4.9432
# Epoch 21, Batch 10: Total Loss: 3.3553, CE: 1.2027, Topo: 7.1751
# Epoch 21, Batch 20: Total Loss: 3.6442, CE: 1.3180, Topo: 7.7541
# Epoch 21, Batch 30: Total Loss: 1.6053, CE: 0.6494, Topo: 3.1863
# Epoch 21, Batch 40: Total Loss: 2.4972, CE: 0.7869, Topo: 5.7009
# Epoch 21, Batch 50: Total Loss: 4.5703, CE: 0.7474, Topo: 12.7431
# Epoch 21, Batch 60: Total Loss: 3.6139, CE: 1.1305, Topo: 8.2781
# Epoch 21, Batch 70: Total Loss: 2.9125, CE: 1.0688, Topo: 6.1456
# Epoch 21, Batch 80: Total Loss: 3.7592, CE: 0.8998, Topo: 9.5313
# Epoch 21, Batch 90: Total Loss: 3.6153, CE: 1.1627, Topo: 8.1756
# Epoch 21, Batch 100: Total Loss: 2.8191, CE: 0.6792, Topo: 7.1332
# Epoch 21, Batch 110: Total Loss: 3.3281, CE: 0.9825, Topo: 7.8187
# Epoch 21, Batch 120: Total Loss: 3.5031, CE: 1.3301, Topo: 7.2434
# Epoch 21, Batch 130: Total Loss: 3.6400, CE: 1.1117, Topo: 8.4278
# Epoch 21, Batch 140: Total Loss: 2.8945, CE: 0.9567, Topo: 6.4594
# Epoch 21, Batch 150: Total Loss: 3.3646, CE: 1.1697, Topo: 7.3161
# Epoch 21/100:
#   Train - Total: 3.1506, CE: 0.9768, Topo: 7.2460
#   Val IoU: 0.2927
# 🔄 Unfrozen 30% of encoder layers
# Epoch 22, Batch 0: Total Loss: 4.3542, CE: 0.6624, Topo: 12.3057
# Epoch 22, Batch 10: Total Loss: 2.1811, CE: 0.9119, Topo: 4.2304
# Epoch 22, Batch 20: Total Loss: 2.3999, CE: 0.6002, Topo: 5.9989
# Epoch 22, Batch 30: Total Loss: 2.9095, CE: 1.0347, Topo: 6.2493
# Epoch 22, Batch 40: Total Loss: 3.2725, CE: 0.9753, Topo: 7.6572
# Epoch 22, Batch 50: Total Loss: 2.1954, CE: 0.6946, Topo: 5.0026
# Epoch 22, Batch 60: Total Loss: 2.3497, CE: 0.8435, Topo: 5.0206
# Epoch 22, Batch 70: Total Loss: 2.3669, CE: 0.9311, Topo: 4.7859
# Epoch 22, Batch 80: Total Loss: 2.7899, CE: 0.8312, Topo: 6.5290
# Epoch 22, Batch 90: Total Loss: 2.3431, CE: 1.1313, Topo: 4.0394
# Epoch 22, Batch 100: Total Loss: 2.1858, CE: 0.6639, Topo: 5.0729
# Epoch 22, Batch 110: Total Loss: 1.7785, CE: 0.6759, Topo: 3.6756
# Epoch 22, Batch 120: Total Loss: 1.9167, CE: 0.6675, Topo: 4.1640
# Epoch 22, Batch 130: Total Loss: 2.8565, CE: 1.1022, Topo: 5.8476
# Epoch 22, Batch 140: Total Loss: 4.1577, CE: 1.8176, Topo: 7.8004
# Epoch 22, Batch 150: Total Loss: 2.8441, CE: 1.0944, Topo: 5.8324
# Epoch 22/100:
#   Train - Total: 2.6871, CE: 0.9238, Topo: 5.8775
#   Val IoU: 0.4370
# ✅ Saved new best model with IoU: 0.4370
# Epoch 23, Batch 0: Total Loss: 1.8318, CE: 0.5380, Topo: 4.3128
# Epoch 23, Batch 10: Total Loss: 2.4173, CE: 0.5440, Topo: 6.2443
# Epoch 23, Batch 20: Total Loss: 2.8763, CE: 0.7641, Topo: 7.0407
# Epoch 23, Batch 30: Total Loss: 2.0106, CE: 0.8511, Topo: 3.8648
# Epoch 23, Batch 40: Total Loss: 2.5650, CE: 0.6640, Topo: 6.3365
# Epoch 23, Batch 50: Total Loss: 1.4343, CE: 0.4524, Topo: 3.2730
# Epoch 23, Batch 60: Total Loss: 2.0381, CE: 0.5004, Topo: 5.1257
# Epoch 23, Batch 70: Total Loss: 1.4060, CE: 0.5756, Topo: 2.7680
# Epoch 23, Batch 80: Total Loss: 2.0081, CE: 0.7342, Topo: 4.2461
# Epoch 23, Batch 90: Total Loss: 1.7919, CE: 0.5088, Topo: 4.2769
# Epoch 23, Batch 100: Total Loss: 2.8906, CE: 0.8388, Topo: 6.8394
# Epoch 23, Batch 110: Total Loss: 4.4533, CE: 0.8923, Topo: 11.8700
# Epoch 23, Batch 120: Total Loss: 2.0888, CE: 0.6202, Topo: 4.8952
# Epoch 23, Batch 130: Total Loss: 1.4882, CE: 0.5543, Topo: 3.1131
# Epoch 23, Batch 140: Total Loss: 1.2290, CE: 0.3355, Topo: 2.9786
# Epoch 23, Batch 150: Total Loss: 2.2314, CE: 0.6896, Topo: 5.1393
# Epoch 23/100:
#   Train - Total: 2.3346, CE: 0.7264, Topo: 5.3609
#   Val IoU: 0.5052
# ✅ Saved new best model with IoU: 0.5052
# Epoch 24, Batch 0: Total Loss: 2.8603, CE: 0.9587, Topo: 6.3386
# Epoch 24, Batch 10: Total Loss: 2.1143, CE: 0.7930, Topo: 4.4041
# Epoch 24, Batch 20: Total Loss: 2.0061, CE: 0.8313, Topo: 3.9158
# Epoch 24, Batch 30: Total Loss: 0.8629, CE: 0.3262, Topo: 1.7891
# Epoch 24, Batch 40: Total Loss: 1.4395, CE: 0.7078, Topo: 2.4390
# Epoch 24, Batch 50: Total Loss: 2.0703, CE: 0.4022, Topo: 5.5605
# Epoch 24, Batch 60: Total Loss: 2.1831, CE: 1.0186, Topo: 3.8816
# Epoch 24, Batch 70: Total Loss: 1.6491, CE: 0.7105, Topo: 3.1287
# Epoch 24, Batch 80: Total Loss: 2.5084, CE: 0.6336, Topo: 6.2493
# Epoch 24, Batch 90: Total Loss: 1.0276, CE: 0.3545, Topo: 2.2437
# Epoch 24, Batch 100: Total Loss: 2.2358, CE: 1.0272, Topo: 4.0289
# Epoch 24, Batch 110: Total Loss: 1.3890, CE: 0.5580, Topo: 2.7698
# Epoch 24, Batch 120: Total Loss: 2.6242, CE: 0.5731, Topo: 6.8368
# Epoch 24, Batch 130: Total Loss: 1.0352, CE: 0.3888, Topo: 2.1548
# Epoch 24, Batch 140: Total Loss: 0.6859, CE: 0.2756, Topo: 1.3678
# Epoch 24, Batch 150: Total Loss: 1.4290, CE: 0.4788, Topo: 3.1674
# Epoch 24/100:
#   Train - Total: 2.1215, CE: 0.6356, Topo: 4.9528
#   Val IoU: 0.5475
# ✅ Saved new best model with IoU: 0.5475
# Epoch 25, Batch 0: Total Loss: 3.8452, CE: 0.4316, Topo: 11.3788
# Epoch 25, Batch 10: Total Loss: 1.7076, CE: 0.6463, Topo: 3.5376
# Epoch 25, Batch 20: Total Loss: 1.8084, CE: 0.6982, Topo: 3.7007
# Epoch 25, Batch 30: Total Loss: 1.7626, CE: 0.5832, Topo: 3.9312
# Epoch 25, Batch 40: Total Loss: 2.5275, CE: 0.4394, Topo: 6.9602
# Epoch 25, Batch 50: Total Loss: 1.3404, CE: 0.3985, Topo: 3.1395
# Epoch 25, Batch 60: Total Loss: 2.3886, CE: 0.4759, Topo: 6.3755
# Epoch 25, Batch 70: Total Loss: 2.7356, CE: 0.7428, Topo: 6.6426
# Epoch 25, Batch 80: Total Loss: 1.2000, CE: 0.4648, Topo: 2.4506
# Epoch 25, Batch 90: Total Loss: 1.5102, CE: 0.5203, Topo: 3.2995
# Epoch 25, Batch 100: Total Loss: 0.8591, CE: 0.3823, Topo: 1.5892
# Epoch 25, Batch 110: Total Loss: 1.2393, CE: 0.3895, Topo: 2.8324
# Epoch 25, Batch 120: Total Loss: 1.1925, CE: 0.5129, Topo: 2.2654
# Epoch 25, Batch 130: Total Loss: 2.3018, CE: 0.6987, Topo: 5.3435
# Epoch 25, Batch 140: Total Loss: 2.5168, CE: 0.6822, Topo: 6.1151
# Epoch 25, Batch 150: Total Loss: 2.3468, CE: 0.6585, Topo: 5.6279
# Epoch 25/100:
#   Train - Total: 1.9058, CE: 0.5435, Topo: 4.5409
#   Val IoU: 0.5890
# ✅ Saved new best model with IoU: 0.5890
# Epoch 26, Batch 0: Total Loss: 1.4417, CE: 0.4972, Topo: 3.1485
# Epoch 26, Batch 10: Total Loss: 2.3992, CE: 0.4133, Topo: 6.6197
# Epoch 26, Batch 20: Total Loss: 0.6507, CE: 0.3311, Topo: 1.0653
# Epoch 26, Batch 30: Total Loss: 1.3455, CE: 0.4539, Topo: 2.9719
# Epoch 26, Batch 40: Total Loss: 2.9868, CE: 0.5563, Topo: 8.1016
# Epoch 26, Batch 50: Total Loss: 3.0643, CE: 0.1974, Topo: 9.5563
# Epoch 26, Batch 60: Total Loss: 1.2984, CE: 0.4664, Topo: 2.7734
# Epoch 26, Batch 70: Total Loss: 1.2461, CE: 0.4261, Topo: 2.7332
# Epoch 26, Batch 80: Total Loss: 0.6394, CE: 0.3203, Topo: 1.0636
# Epoch 26, Batch 90: Total Loss: 2.5776, CE: 0.4717, Topo: 7.0195
# Epoch 26, Batch 100: Total Loss: 1.1876, CE: 0.4053, Topo: 2.6077
# Epoch 26, Batch 110: Total Loss: 1.5460, CE: 0.6283, Topo: 3.0590
# Epoch 26, Batch 120: Total Loss: 4.2727, CE: 0.6915, Topo: 11.9374
# Epoch 26, Batch 130: Total Loss: 1.6125, CE: 0.2794, Topo: 4.4436
# Epoch 26, Batch 140: Total Loss: 1.4508, CE: 0.4342, Topo: 3.3887
# Epoch 26, Batch 150: Total Loss: 2.0407, CE: 0.5990, Topo: 4.8055
# Epoch 26/100:
#   Train - Total: 1.7509, CE: 0.5055, Topo: 4.1513
#   Val IoU: 0.6164
# ✅ Saved new best model with IoU: 0.6164
# Epoch 27, Batch 0: Total Loss: 1.9117, CE: 0.6340, Topo: 4.2590
# Epoch 27, Batch 10: Total Loss: 0.9223, CE: 0.3176, Topo: 2.0156
# Epoch 27, Batch 20: Total Loss: 1.4379, CE: 0.4528, Topo: 3.2839
# Epoch 27, Batch 30: Total Loss: 1.1533, CE: 0.4794, Topo: 2.2463
# Epoch 27, Batch 40: Total Loss: 1.4582, CE: 0.6873, Topo: 2.5697
# Epoch 27, Batch 50: Total Loss: 1.9681, CE: 0.4162, Topo: 5.1730
# Epoch 27, Batch 60: Total Loss: 2.9777, CE: 0.3411, Topo: 8.7884
# Epoch 27, Batch 70: Total Loss: 0.8296, CE: 0.2149, Topo: 2.0489
# Epoch 27, Batch 80: Total Loss: 0.8703, CE: 0.3418, Topo: 1.7616
# Epoch 27, Batch 90: Total Loss: 0.5775, CE: 0.2610, Topo: 1.0548
# Epoch 27, Batch 100: Total Loss: 2.7574, CE: 0.8817, Topo: 6.2525
# Epoch 27, Batch 110: Total Loss: 1.0935, CE: 0.2838, Topo: 2.6989
# Epoch 27, Batch 120: Total Loss: 1.2585, CE: 0.2841, Topo: 3.2480
# Epoch 27, Batch 130: Total Loss: 0.7384, CE: 0.2424, Topo: 1.6533
# Epoch 27, Batch 140: Total Loss: 3.6666, CE: 0.5341, Topo: 10.4418
# Epoch 27, Batch 150: Total Loss: 1.0787, CE: 0.5414, Topo: 1.7910
# Epoch 27/100:
#   Train - Total: 1.5813, CE: 0.4669, Topo: 3.7145
#   Val IoU: 0.6438
# ✅ Saved new best model with IoU: 0.6438
# Epoch 28, Batch 0: Total Loss: 1.6484, CE: 0.5591, Topo: 3.6309
# Epoch 28, Batch 10: Total Loss: 1.0866, CE: 0.3196, Topo: 2.5565
# Epoch 28, Batch 20: Total Loss: 3.5254, CE: 0.4179, Topo: 10.3581
# Epoch 28, Batch 30: Total Loss: 1.1589, CE: 0.5510, Topo: 2.0263
# Epoch 28, Batch 40: Total Loss: 0.5766, CE: 0.2245, Topo: 1.1737
# Epoch 28, Batch 50: Total Loss: 0.7688, CE: 0.2600, Topo: 1.6958
# Epoch 28, Batch 60: Total Loss: 0.8468, CE: 0.3471, Topo: 1.6658
# Epoch 28, Batch 70: Total Loss: 2.1403, CE: 0.6304, Topo: 5.0328
# Epoch 28, Batch 80: Total Loss: 0.7484, CE: 0.3115, Topo: 1.4563
# Epoch 28, Batch 90: Total Loss: 1.4427, CE: 0.4560, Topo: 3.2888
# Epoch 28, Batch 100: Total Loss: 0.8814, CE: 0.4134, Topo: 1.5600
# Epoch 28, Batch 110: Total Loss: 1.1350, CE: 0.3599, Topo: 2.5838
# Epoch 28, Batch 120: Total Loss: 0.6346, CE: 0.2387, Topo: 1.3197
# Epoch 28, Batch 130: Total Loss: 0.9487, CE: 0.3212, Topo: 2.0919
# Epoch 28, Batch 140: Total Loss: 1.0043, CE: 0.4904, Topo: 1.7129
# Epoch 28, Batch 150: Total Loss: 2.2364, CE: 0.6773, Topo: 5.1969
# Epoch 28/100:
#   Train - Total: 1.3529, CE: 0.4062, Topo: 3.1556
#   Val IoU: 0.6934
# ✅ Saved new best model with IoU: 0.6934
# Epoch 29, Batch 0: Total Loss: 0.5849, CE: 0.2503, Topo: 1.1154
# Epoch 29, Batch 10: Total Loss: 0.6060, CE: 0.1967, Topo: 1.3642
# Epoch 29, Batch 20: Total Loss: 1.5406, CE: 0.3594, Topo: 3.9372
# Epoch 29, Batch 30: Total Loss: 0.7978, CE: 0.2566, Topo: 1.8039
# Epoch 29, Batch 40: Total Loss: 0.6227, CE: 0.2514, Topo: 1.2377
# Epoch 29, Batch 50: Total Loss: 0.5468, CE: 0.2220, Topo: 1.0827
# Epoch 29, Batch 60: Total Loss: 1.0648, CE: 0.3672, Topo: 2.3255
# Epoch 29, Batch 70: Total Loss: 0.5349, CE: 0.1508, Topo: 1.2806
# Epoch 29, Batch 80: Total Loss: 1.4196, CE: 0.5518, Topo: 2.8926
# Epoch 29, Batch 90: Total Loss: 0.8895, CE: 0.2543, Topo: 2.1174
# Epoch 29, Batch 100: Total Loss: 0.5583, CE: 0.3043, Topo: 0.8466
# Epoch 29, Batch 110: Total Loss: 2.4407, CE: 0.3401, Topo: 7.0022
# Epoch 29, Batch 120: Total Loss: 1.2534, CE: 0.3553, Topo: 2.9939
# Epoch 29, Batch 130: Total Loss: 1.6314, CE: 0.2830, Topo: 4.4948
# Epoch 29, Batch 140: Total Loss: 2.3120, CE: 0.5236, Topo: 5.9614
# Epoch 29, Batch 150: Total Loss: 1.4216, CE: 0.4269, Topo: 3.3159
# Epoch 29/100:
#   Train - Total: 1.2869, CE: 0.3630, Topo: 3.0797
#   Val IoU: 0.7044
# ✅ Saved new best model with IoU: 0.7044
# Epoch 30, Batch 0: Total Loss: 1.0164, CE: 0.2733, Topo: 2.4769
# Epoch 30, Batch 10: Total Loss: 0.7654, CE: 0.2895, Topo: 1.5863
# Epoch 30, Batch 20: Total Loss: 1.3108, CE: 0.5048, Topo: 2.6865
# Epoch 30, Batch 30: Total Loss: 1.6269, CE: 0.2867, Topo: 4.4671
# Epoch 30, Batch 40: Total Loss: 0.3522, CE: 0.1084, Topo: 0.8124
# Epoch 30, Batch 50: Total Loss: 2.3995, CE: 0.4151, Topo: 6.6147
# Epoch 30, Batch 60: Total Loss: 0.8514, CE: 0.3498, Topo: 1.6722
# Epoch 30, Batch 70: Total Loss: 0.7029, CE: 0.2727, Topo: 1.4341
# Epoch 30, Batch 80: Total Loss: 0.5065, CE: 0.1873, Topo: 1.0640
# Epoch 30, Batch 90: Total Loss: 0.4116, CE: 0.1149, Topo: 0.9888
# Epoch 30, Batch 100: Total Loss: 0.9201, CE: 0.2894, Topo: 2.1022
# Epoch 30, Batch 110: Total Loss: 1.4566, CE: 0.3908, Topo: 3.5526
# Epoch 30, Batch 120: Total Loss: 1.9414, CE: 0.4619, Topo: 4.9316
# Epoch 30, Batch 130: Total Loss: 0.6667, CE: 0.1647, Topo: 1.6735
# Epoch 30, Batch 140: Total Loss: 0.2440, CE: 0.1164, Topo: 0.4253
# Epoch 30, Batch 150: Total Loss: 1.9401, CE: 0.5719, Topo: 4.5606
# Epoch 30/100:
#   Train - Total: 1.2003, CE: 0.3385, Topo: 2.8726
#   Val IoU: 0.7168
# ✅ Saved new best model with IoU: 0.7168
# Epoch 31, Batch 0: Total Loss: 0.5288, CE: 0.2025, Topo: 1.0877
# Epoch 31, Batch 10: Total Loss: 0.5771, CE: 0.2614, Topo: 1.0524
# Epoch 31, Batch 20: Total Loss: 1.5289, CE: 0.3127, Topo: 4.0541
# Epoch 31, Batch 30: Total Loss: 1.7346, CE: 0.6025, Topo: 3.7736
# Epoch 31, Batch 40: Total Loss: 0.7422, CE: 0.2430, Topo: 1.6642
# Epoch 31, Batch 50: Total Loss: 1.4933, CE: 0.2870, Topo: 4.0212
# Epoch 31, Batch 60: Total Loss: 0.7793, CE: 0.3382, Topo: 1.4702
# Epoch 31, Batch 70: Total Loss: 1.8445, CE: 0.4301, Topo: 4.7148
# Epoch 31, Batch 80: Total Loss: 1.4868, CE: 0.4078, Topo: 3.5968
# Epoch 31, Batch 90: Total Loss: 0.6522, CE: 0.2580, Topo: 1.3137
# Epoch 31, Batch 100: Total Loss: 1.0381, CE: 0.2726, Topo: 2.5516
# Epoch 31, Batch 110: Total Loss: 2.2168, CE: 0.5034, Topo: 5.7116
# Epoch 31, Batch 120: Total Loss: 1.4639, CE: 0.2225, Topo: 4.1381
# Epoch 31, Batch 130: Total Loss: 1.6031, CE: 0.3694, Topo: 4.1124
# Epoch 31, Batch 140: Total Loss: 2.1646, CE: 0.3469, Topo: 6.0591
# Epoch 31, Batch 150: Total Loss: 0.7385, CE: 0.3200, Topo: 1.3950
# Epoch 31/100:
#   Train - Total: 1.1369, CE: 0.3236, Topo: 2.7108
#   Val IoU: 0.7103
# Epoch 32, Batch 0: Total Loss: 0.9487, CE: 0.4057, Topo: 1.8102
# Epoch 32, Batch 10: Total Loss: 2.2016, CE: 0.4643, Topo: 5.7912
# Epoch 32, Batch 20: Total Loss: 0.7767, CE: 0.3312, Topo: 1.4849
# Epoch 32, Batch 30: Total Loss: 1.8474, CE: 0.4180, Topo: 4.7648
# Epoch 32, Batch 40: Total Loss: 0.3888, CE: 0.1702, Topo: 0.7287
# Epoch 32, Batch 50: Total Loss: 1.9424, CE: 0.4264, Topo: 5.0532
# Epoch 32, Batch 60: Total Loss: 0.6489, CE: 0.2274, Topo: 1.4050
# Epoch 32, Batch 70: Total Loss: 0.8395, CE: 0.2806, Topo: 1.8630
# Epoch 32, Batch 80: Total Loss: 0.7152, CE: 0.2305, Topo: 1.6157
# Epoch 32, Batch 90: Total Loss: 1.1937, CE: 0.2265, Topo: 3.2240
# Epoch 32, Batch 100: Total Loss: 0.7216, CE: 0.2045, Topo: 1.7238
# Epoch 32, Batch 110: Total Loss: 0.6429, CE: 0.2562, Topo: 1.2889
# Epoch 32, Batch 120: Total Loss: 0.5414, CE: 0.1996, Topo: 1.1396
# Epoch 32, Batch 130: Total Loss: 0.8743, CE: 0.2466, Topo: 2.0924
# Epoch 32, Batch 140: Total Loss: 2.1709, CE: 0.5591, Topo: 5.3725
# Epoch 32, Batch 150: Total Loss: 1.0884, CE: 0.4297, Topo: 2.1959
# Epoch 32/100:
#   Train - Total: 1.0615, CE: 0.3004, Topo: 2.5370
#   Val IoU: 0.7271
# ✅ Saved new best model with IoU: 0.7271
# Epoch 33, Batch 0: Total Loss: 2.8938, CE: 0.4871, Topo: 8.0223
# Epoch 33, Batch 10: Total Loss: 0.6807, CE: 0.2312, Topo: 1.4985
# Epoch 33, Batch 20: Total Loss: 0.9085, CE: 0.3733, Topo: 1.7840
# Epoch 33, Batch 30: Total Loss: 1.2740, CE: 0.2033, Topo: 3.5691
# Epoch 33, Batch 40: Total Loss: 0.4766, CE: 0.2199, Topo: 0.8558
# Epoch 33, Batch 50: Total Loss: 0.6089, CE: 0.1972, Topo: 1.3723
# Epoch 33, Batch 60: Total Loss: 0.6250, CE: 0.1992, Topo: 1.4193
# Epoch 33, Batch 70: Total Loss: 1.5019, CE: 0.2495, Topo: 4.1748
# Epoch 33, Batch 80: Total Loss: 0.2911, CE: 0.0770, Topo: 0.7138
# Epoch 33, Batch 90: Total Loss: 0.7176, CE: 0.1461, Topo: 1.9048
# Epoch 33, Batch 100: Total Loss: 1.9349, CE: 0.1894, Topo: 5.8185
# Epoch 33, Batch 110: Total Loss: 1.3433, CE: 0.5327, Topo: 2.7020
# Epoch 33, Batch 120: Total Loss: 0.8936, CE: 0.2821, Topo: 2.0383
# Epoch 33, Batch 130: Total Loss: 0.8227, CE: 0.2472, Topo: 1.9183
# Epoch 33, Batch 140: Total Loss: 1.0681, CE: 0.2854, Topo: 2.6089
# Epoch 33, Batch 150: Total Loss: 0.6147, CE: 0.2748, Topo: 1.1332
# Epoch 33/100:
#   Train - Total: 1.1129, CE: 0.2953, Topo: 2.7253
#   Val IoU: 0.7632
# ✅ Saved new best model with IoU: 0.7632
# Epoch 34, Batch 0: Total Loss: 0.4217, CE: 0.1425, Topo: 0.9308
# Epoch 34, Batch 10: Total Loss: 1.7386, CE: 0.4396, Topo: 4.3298
# Epoch 34, Batch 20: Total Loss: 0.8876, CE: 0.2372, Topo: 2.1681
# Epoch 34, Batch 30: Total Loss: 0.6244, CE: 0.1836, Topo: 1.4692
# Epoch 34, Batch 40: Total Loss: 0.6753, CE: 0.2816, Topo: 1.3122
# Epoch 34, Batch 50: Total Loss: 0.4792, CE: 0.1217, Topo: 1.1915
# Epoch 34, Batch 60: Total Loss: 0.4819, CE: 0.1541, Topo: 1.0925
# Epoch 34, Batch 70: Total Loss: 0.9294, CE: 0.3014, Topo: 2.0935
# Epoch 34, Batch 80: Total Loss: 0.3972, CE: 0.1671, Topo: 0.7668
# Epoch 34, Batch 90: Total Loss: 0.8244, CE: 0.2323, Topo: 1.9737
# Epoch 34, Batch 100: Total Loss: 0.2694, CE: 0.0941, Topo: 0.5842
# Epoch 34, Batch 110: Total Loss: 0.8612, CE: 0.1929, Topo: 2.2277
# Epoch 34, Batch 120: Total Loss: 0.4930, CE: 0.1944, Topo: 0.9952
# Epoch 34, Batch 130: Total Loss: 1.2456, CE: 0.2892, Topo: 3.1879
# Epoch 34, Batch 140: Total Loss: 1.5318, CE: 0.2609, Topo: 4.2362
# Epoch 34, Batch 150: Total Loss: 1.0715, CE: 0.2870, Topo: 2.6149
# Epoch 34/100:
#   Train - Total: 1.0076, CE: 0.2703, Topo: 2.4577
#   Val IoU: 0.7646
# ✅ Saved new best model with IoU: 0.7646
# Epoch 35, Batch 0: Total Loss: 0.8024, CE: 0.1996, Topo: 2.0097
# Epoch 35, Batch 10: Total Loss: 1.0210, CE: 0.2372, Topo: 2.6126
# Epoch 35, Batch 20: Total Loss: 0.6707, CE: 0.1403, Topo: 1.7682
# Epoch 35, Batch 30: Total Loss: 0.8932, CE: 0.2085, Topo: 2.2824
# Epoch 35, Batch 40: Total Loss: 0.6480, CE: 0.1414, Topo: 1.6887
# Epoch 35, Batch 50: Total Loss: 0.6042, CE: 0.1555, Topo: 1.4954
# Epoch 35, Batch 60: Total Loss: 0.7422, CE: 0.1857, Topo: 1.8549
# Epoch 35, Batch 70: Total Loss: 0.7616, CE: 0.2279, Topo: 1.7789
# Epoch 35, Batch 80: Total Loss: 1.2291, CE: 0.1796, Topo: 3.4983
# Epoch 35, Batch 90: Total Loss: 0.8934, CE: 0.2537, Topo: 2.1321
# Epoch 35, Batch 100: Total Loss: 0.4482, CE: 0.1438, Topo: 1.0147
# Epoch 35, Batch 110: Total Loss: 0.8247, CE: 0.2834, Topo: 1.8043
# Epoch 35, Batch 120: Total Loss: 0.5304, CE: 0.1581, Topo: 1.2408
# Epoch 35, Batch 130: Total Loss: 1.0757, CE: 0.3150, Topo: 2.5356
# Epoch 35, Batch 140: Total Loss: 1.7661, CE: 0.1939, Topo: 5.2406
# Epoch 35, Batch 150: Total Loss: 1.5146, CE: 0.4041, Topo: 3.7016
# Epoch 35/100:
#   Train - Total: 0.9302, CE: 0.2527, Topo: 2.2585
#   Val IoU: 0.7525
# Epoch 36, Batch 0: Total Loss: 1.1742, CE: 0.2658, Topo: 3.0280
# Epoch 36, Batch 10: Total Loss: 0.4273, CE: 0.1111, Topo: 1.0543
# Epoch 36, Batch 20: Total Loss: 0.5879, CE: 0.1771, Topo: 1.3693
# Epoch 36, Batch 30: Total Loss: 0.6604, CE: 0.1113, Topo: 1.8302
# Epoch 36, Batch 40: Total Loss: 0.7633, CE: 0.2397, Topo: 1.7455
# Epoch 36, Batch 50: Total Loss: 0.5290, CE: 0.1354, Topo: 1.3119
# Epoch 36, Batch 60: Total Loss: 0.9501, CE: 0.2740, Topo: 2.2536
# Epoch 36, Batch 70: Total Loss: 0.7935, CE: 0.2241, Topo: 1.8980
# Epoch 36, Batch 80: Total Loss: 0.8214, CE: 0.2184, Topo: 2.0100
# Epoch 36, Batch 90: Total Loss: 1.5074, CE: 0.2541, Topo: 4.1776
# Epoch 36, Batch 100: Total Loss: 0.7427, CE: 0.3093, Topo: 1.4445
# Epoch 36, Batch 110: Total Loss: 1.9365, CE: 0.5400, Topo: 4.6550
# Epoch 36, Batch 120: Total Loss: 0.5823, CE: 0.2389, Topo: 1.1447
# Epoch 36, Batch 130: Total Loss: 1.8728, CE: 0.3256, Topo: 5.1572
# Epoch 36, Batch 140: Total Loss: 0.6634, CE: 0.2515, Topo: 1.3730
# Epoch 36, Batch 150: Total Loss: 0.3890, CE: 0.1515, Topo: 0.7916
# Epoch 36/100:
#   Train - Total: 0.8601, CE: 0.2347, Topo: 2.0847
#   Val IoU: 0.7989
# ✅ Saved new best model with IoU: 0.7989
# Epoch 37, Batch 0: Total Loss: 0.8103, CE: 0.2486, Topo: 1.8724
# Epoch 37, Batch 10: Total Loss: 1.0006, CE: 0.3119, Topo: 2.2954
# Epoch 37, Batch 20: Total Loss: 0.6467, CE: 0.1947, Topo: 1.5068
# Epoch 37, Batch 30: Total Loss: 0.2608, CE: 0.0732, Topo: 0.6253
# Epoch 37, Batch 40: Total Loss: 0.7655, CE: 0.2144, Topo: 1.8369
# Epoch 37, Batch 50: Total Loss: 0.4564, CE: 0.1404, Topo: 1.0535
# Epoch 37, Batch 60: Total Loss: 1.9009, CE: 0.2820, Topo: 5.3964
# Epoch 37, Batch 70: Total Loss: 1.8676, CE: 0.2374, Topo: 5.4342
# Epoch 37, Batch 80: Total Loss: 0.7111, CE: 0.2144, Topo: 1.6556
# Epoch 37, Batch 90: Total Loss: 0.8845, CE: 0.2836, Topo: 2.0031
# Epoch 37, Batch 100: Total Loss: 1.5947, CE: 0.3643, Topo: 4.1013
# Epoch 37, Batch 110: Total Loss: 0.7482, CE: 0.2501, Topo: 1.6605
# Epoch 37, Batch 120: Total Loss: 0.6277, CE: 0.1799, Topo: 1.4925
# Epoch 37, Batch 130: Total Loss: 1.3033, CE: 0.2646, Topo: 3.4626
# Epoch 37, Batch 140: Total Loss: 0.7070, CE: 0.1383, Topo: 1.8958
# Epoch 37, Batch 150: Total Loss: 0.3860, CE: 0.1138, Topo: 0.9073
# Epoch 37/100:
#   Train - Total: 0.8137, CE: 0.2141, Topo: 1.9986
#   Val IoU: 0.8089
# ✅ Saved new best model with IoU: 0.8089
# Epoch 38, Batch 0: Total Loss: 0.9364, CE: 0.1535, Topo: 2.6095
# Epoch 38, Batch 10: Total Loss: 0.4823, CE: 0.1921, Topo: 0.9672
# Epoch 38, Batch 20: Total Loss: 0.8766, CE: 0.1579, Topo: 2.3958
# Epoch 38, Batch 30: Total Loss: 0.4482, CE: 0.1717, Topo: 0.9217
# Epoch 38, Batch 40: Total Loss: 0.1738, CE: 0.0548, Topo: 0.3969
# Epoch 38, Batch 50: Total Loss: 0.6045, CE: 0.2233, Topo: 1.2708
# Epoch 38, Batch 60: Total Loss: 0.2007, CE: 0.0963, Topo: 0.3480
# Epoch 38, Batch 70: Total Loss: 0.5264, CE: 0.1346, Topo: 1.3061
# Epoch 38, Batch 80: Total Loss: 0.3185, CE: 0.0802, Topo: 0.7946
# Epoch 38, Batch 90: Total Loss: 0.7795, CE: 0.1373, Topo: 2.1406
# Epoch 38, Batch 100: Total Loss: 0.5637, CE: 0.2657, Topo: 0.9931
# Epoch 38, Batch 110: Total Loss: 0.4785, CE: 0.1813, Topo: 0.9907
# Epoch 38, Batch 120: Total Loss: 0.5928, CE: 0.2276, Topo: 1.2174
# Epoch 38, Batch 130: Total Loss: 0.3621, CE: 0.1148, Topo: 0.8242
# Epoch 38, Batch 140: Total Loss: 0.7747, CE: 0.2497, Topo: 1.7497
# Epoch 38, Batch 150: Total Loss: 0.9864, CE: 0.3004, Topo: 2.2868
# Epoch 38/100:
#   Train - Total: 0.8227, CE: 0.2094, Topo: 2.0446
#   Val IoU: 0.8040
# Epoch 39, Batch 0: Total Loss: 0.6854, CE: 0.2131, Topo: 1.5743
# Epoch 39, Batch 10: Total Loss: 0.6609, CE: 0.2552, Topo: 1.3523
# Epoch 39, Batch 20: Total Loss: 0.4114, CE: 0.0966, Topo: 1.0493
# Epoch 39, Batch 30: Total Loss: 0.8040, CE: 0.2313, Topo: 1.9088
# Epoch 39, Batch 40: Total Loss: 0.4926, CE: 0.1060, Topo: 1.2886
# Epoch 39, Batch 50: Total Loss: 2.4442, CE: 0.3713, Topo: 6.9097
# Epoch 39, Batch 60: Total Loss: 0.5705, CE: 0.2288, Topo: 1.1391
# Epoch 39, Batch 70: Total Loss: 0.5283, CE: 0.2287, Topo: 0.9987
# Epoch 39, Batch 80: Total Loss: 0.7198, CE: 0.1936, Topo: 1.7543
# Epoch 39, Batch 90: Total Loss: 1.6417, CE: 0.2469, Topo: 4.6495
# Epoch 39, Batch 100: Total Loss: 1.2749, CE: 0.1664, Topo: 3.6949
# Epoch 39, Batch 110: Total Loss: 0.5015, CE: 0.1222, Topo: 1.2645
# Epoch 39, Batch 120: Total Loss: 1.1960, CE: 0.2391, Topo: 3.1897
# Epoch 39, Batch 130: Total Loss: 0.9897, CE: 0.2819, Topo: 2.3594
# Epoch 39, Batch 140: Total Loss: 0.9762, CE: 0.2692, Topo: 2.3567
# Epoch 39, Batch 150: Total Loss: 0.7464, CE: 0.2421, Topo: 1.6810
# Epoch 39/100:
#   Train - Total: 0.9550, CE: 0.2446, Topo: 2.3681
#   Val IoU: 0.8152
# ✅ Saved new best model with IoU: 0.8152
# Epoch 40, Batch 0: Total Loss: 0.6039, CE: 0.1605, Topo: 1.4777
# Epoch 40, Batch 10: Total Loss: 0.4919, CE: 0.1575, Topo: 1.1149
# Epoch 40, Batch 20: Total Loss: 1.4593, CE: 0.3295, Topo: 3.7659
# Epoch 40, Batch 30: Total Loss: 0.3158, CE: 0.0806, Topo: 0.7838
# Epoch 40, Batch 40: Total Loss: 0.4208, CE: 0.1543, Topo: 0.8882
# Epoch 40, Batch 50: Total Loss: 0.7450, CE: 0.0981, Topo: 2.1564
# Epoch 40, Batch 60: Total Loss: 0.5567, CE: 0.1816, Topo: 1.2503
# Epoch 40, Batch 70: Total Loss: 0.5230, CE: 0.1912, Topo: 1.1060
# Epoch 40, Batch 80: Total Loss: 0.5101, CE: 0.1387, Topo: 1.2380
# Epoch 40, Batch 90: Total Loss: 0.4040, CE: 0.1562, Topo: 0.8261
# Epoch 40, Batch 100: Total Loss: 0.4711, CE: 0.1320, Topo: 1.1302
# Epoch 40, Batch 110: Total Loss: 0.6235, CE: 0.2561, Topo: 1.2248
# Epoch 40, Batch 120: Total Loss: 0.8477, CE: 0.1498, Topo: 2.3263
# Epoch 40, Batch 130: Total Loss: 0.6668, CE: 0.1168, Topo: 1.8334
# Epoch 40, Batch 140: Total Loss: 0.8102, CE: 0.2024, Topo: 2.0261
# Epoch 40, Batch 150: Total Loss: 0.4085, CE: 0.1723, Topo: 0.7872
# Epoch 40/100:
#   Train - Total: 0.8378, CE: 0.2188, Topo: 2.0633
#   Val IoU: 0.7876
# Epoch 41, Batch 0: Total Loss: 0.5018, CE: 0.1447, Topo: 1.1903
# Epoch 41, Batch 10: Total Loss: 0.4126, CE: 0.1330, Topo: 0.9320
# Epoch 41, Batch 20: Total Loss: 0.4791, CE: 0.1551, Topo: 1.0800
# Epoch 41, Batch 30: Total Loss: 0.8176, CE: 0.2044, Topo: 2.0440
# Epoch 41, Batch 40: Total Loss: 0.3206, CE: 0.1606, Topo: 0.5335
# Epoch 41, Batch 50: Total Loss: 1.7923, CE: 0.3029, Topo: 4.9647
# Epoch 41, Batch 60: Total Loss: 0.8343, CE: 0.0896, Topo: 2.4826
# Epoch 41, Batch 70: Total Loss: 0.6213, CE: 0.1367, Topo: 1.6155
# Epoch 41, Batch 80: Total Loss: 0.6180, CE: 0.2297, Topo: 1.2946
# Epoch 41, Batch 90: Total Loss: 0.2121, CE: 0.0738, Topo: 0.4608
# Epoch 41, Batch 100: Total Loss: 0.8642, CE: 0.1962, Topo: 2.2267
# Epoch 41, Batch 110: Total Loss: 1.0294, CE: 0.1873, Topo: 2.8070
# Epoch 41, Batch 120: Total Loss: 0.7952, CE: 0.1778, Topo: 2.0582
# Epoch 41, Batch 130: Total Loss: 0.7638, CE: 0.2153, Topo: 1.8281
# Epoch 41, Batch 140: Total Loss: 0.8668, CE: 0.2606, Topo: 2.0210
# Epoch 41, Batch 150: Total Loss: 1.5755, CE: 0.2156, Topo: 4.5330
# Epoch 41/100:
#   Train - Total: 0.7419, CE: 0.1846, Topo: 1.8574
#   Val IoU: 0.8290
# ✅ Saved new best model with IoU: 0.8290
# 🔄 Unfrozen 60% of encoder layers
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[2], line 468
#     466 # ==================== MAIN EXECUTION ====================
#     467 if __name__ == "__main__":
# --> 468     trained_model, final_iou = train_high_iou_sam()
#     470     print(f"\n🎯 PHASE 1 COMPLETED with IoU: {final_iou:.4f}")
#     472     if final_iou >= 0.85:
#
# Cell In[2], line 374, in train_high_iou_sam()
#     371 images_resized = F.interpolate(images, size=1024, mode='bilinear', align_corners=False)
#     373 # Forward pass
# --> 374 logits = model(images_resized)
#     376 # Resize logits back to 256x256
#     377 logits = F.interpolate(logits, size=256, mode='bilinear', align_corners=False)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[2], line 256, in HighIoUSAMWrapper.forward(self, x)
#     254 def forward(self, x):
#     255     # Input should be 1024x1024 for SAM
# --> 256     image_embeddings = self.sam.image_encoder(x)
#     257     logits = self.segmentation_head(image_embeddings)
#     258     return logits
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/AMB/Proposed_3/SAM/segment-anything-main/segment_anything/modeling/image_encoder.py:112, in ImageEncoderViT.forward(self, x)
#     109     x = x + self.pos_embed
#     111 for blk in self.blocks:
# --> 112     x = blk(x)
#     114 x = self.neck(x.permute(0, 3, 1, 2))
#     116 return x
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/AMB/Proposed_3/SAM/segment-anything-main/segment_anything/modeling/image_encoder.py:174, in Block.forward(self, x)
#     171     H, W = x.shape[1], x.shape[2]
#     172     x, pad_hw = window_partition(x, self.window_size)
# --> 174 x = self.attn(x)
#     175 # Reverse window partition
#     176 if self.window_size > 0:
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/AMB/Proposed_3/SAM/segment-anything-main/segment_anything/modeling/image_encoder.py:234, in Attention.forward(self, x)
#     231 attn = (q * self.scale) @ k.transpose(-2, -1)
#     233 if self.use_rel_pos:
# --> 234     attn = add_decomposed_rel_pos(attn, q, self.rel_pos_h, self.rel_pos_w, (H, W), (H, W))
#     236 attn = attn.softmax(dim=-1)
#     237 x = (attn @ v).view(B, self.num_heads, H, W, -1).permute(0, 2, 3, 1, 4).reshape(B, H, W, -1)
#
# File ~/AMB/Proposed_3/SAM/segment-anything-main/segment_anything/modeling/image_encoder.py:358, in add_decomposed_rel_pos(attn, q, rel_pos_h, rel_pos_w, q_size, k_size)
#     354 rel_h = torch.einsum("bhwc,hkc->bhwk", r_q, Rh)
#     355 rel_w = torch.einsum("bhwc,wkc->bhwk", r_q, Rw)
#     357 attn = (
# --> 358     attn.view(B, q_h, q_w, k_h, k_w) + rel_h[:, :, :, :, None] + rel_w[:, :, :, None, :]
#     359 ).view(B, q_h * q_w, k_h * k_w)
#     361 return attn
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 3.00 GiB. GPU 0 has a total capacity of 23.67 GiB of which 1.01 GiB is free. Including non-PyTorch memory, this process has 22.26 GiB memory in use. Of the allocated memory 20.28 GiB is allocated by PyTorch, and 1.72 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
import torch
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from segment_anything import sam_model_registry
from torch.optim import Adam
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from scipy import ndimage

# ==================== CONFIGURATION ====================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Paths
train_image_dir = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_images'
train_mask_dir = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_1cmasks'
val_image_dir = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_images'
val_mask_dir =  '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_1cmasks'
sam_checkpoint = "/home/iiitdmk-param/Desktop/Research/3/Data/sam_vit_b.pth"
model_type = "vit_b"

# Training parameters - REDUCED BATCH SIZE
BATCH_SIZE = 2  # Reduced from 4 to 2 to fix OOM
NUM_EPOCHS = 100
LEARNING_RATE = 1e-4
NUM_CLASSES = 18

# Topological loss parameters
TOPO_LOSS_WEIGHT = 0.3  # Weight for topological loss

# ==================== CLASS INFORMATION ====================
CLASS_INFO = {
    0: {"name": "background", "rgb": [0, 0, 0]},
    1: {"name": "airplane", "rgb": [166, 202, 240]},
    2: {"name": "bare soil", "rgb": [128, 128, 0]},
    3: {"name": "buildings", "rgb": [0, 0, 128]},
    4: {"name": "cars", "rgb": [255, 0, 0]},
    5: {"name": "chaparral", "rgb": [0, 128, 0]},
    6: {"name": "court", "rgb": [128, 0, 0]},
    7: {"name": "dock", "rgb": [255, 233, 233]},
    8: {"name": "field", "rgb": [160, 160, 164]},
    9: {"name": "grass", "rgb": [0, 128, 128]},
    10: {"name": "mobile home", "rgb": [90, 87, 255]},
    11: {"name": "pavement", "rgb": [255, 255, 0]},
    12: {"name": "sand", "rgb": [255, 192, 0]},
    13: {"name": "sea", "rgb": [0, 0, 255]},
    14: {"name": "ship", "rgb": [255, 0, 192]},
    15: {"name": "tanks", "rgb": [128, 0, 128]},
    16: {"name": "trees", "rgb": [0, 255, 0]},
    17: {"name": "water", "rgb": [0, 255, 255]}
}

# ==================== TOPOLOGICAL LOSS ====================
class TopologicalLoss(nn.Module):
    def __init__(self, class_weights=None, eps=1e-8):
        """
        Topological loss for semantic segmentation
        Focuses on preserving connectivity and shape structure
        """
        super().__init__()
        self.eps = eps
        
        # Class-specific topological importance weights
        if class_weights is None:
            self.class_weights = {
                3: 1.0,   # buildings - high (solid, connected shapes)
                11: 1.2,  # pavement - very high (connectivity critical)
                13: 0.8,  # sea - medium (boundary smoothness)
                17: 0.8,  # water - medium (boundary smoothness)
                8: 0.5,   # field - low (some shape consistency)
                5: 0.4,   # chaparral - low
                9: 0.4,   # grass - low
                16: 0.4,  # trees - low
                # Other classes get default weight
            }
        else:
            self.class_weights = class_weights
            
        self.default_weight = 0.1

    def compute_component_loss(self, pred_binary, target_binary):
        """Compute loss for connected components (0D topology)"""
        if pred_binary.sum() == 0 and target_binary.sum() == 0:
            return torch.tensor(0.0, device=pred_binary.device)
        
        # Convert to numpy for connected component analysis
        pred_np = pred_binary.cpu().numpy().astype(np.uint8)
        target_np = target_binary.cpu().numpy().astype(np.uint8)
        
        # Count connected components
        pred_components, _ = ndimage.label(pred_np)
        target_components, _ = ndimage.label(target_np)
        
        pred_count = np.max(pred_components) if np.max(pred_components) > 0 else 0
        target_count = np.max(target_components) if np.max(target_components) > 0 else 0
        
        # Component count difference
        comp_diff = torch.abs(torch.tensor(pred_count - target_count, dtype=torch.float32, device=pred_binary.device))
        
        return comp_diff

    def compute_boundary_loss(self, pred_binary, target_binary):
        """Compute boundary consistency loss"""
        if pred_binary.sum() == 0 and target_binary.sum() == 0:
            return torch.tensor(0.0, device=pred_binary.device)
        
        # Convert to numpy for morphological operations
        pred_np = pred_binary.cpu().numpy().astype(np.uint8)
        target_np = target_binary.cpu().numpy().astype(np.uint8)
        
        # Compute boundaries using erosion
        kernel = np.ones((3, 3), np.uint8)
        pred_boundary = cv2.morphologyEx(pred_np, cv2.MORPH_GRADIENT, kernel)
        target_boundary = cv2.morphologyEx(target_np, cv2.MORPH_GRADIENT, kernel)
        
        # Boundary consistency
        boundary_intersection = np.logical_and(pred_boundary, target_boundary).sum()
        boundary_union = np.logical_or(pred_boundary, target_boundary).sum()
        
        if boundary_union == 0:
            return torch.tensor(0.0, device=pred_binary.device)
        
        boundary_iou = boundary_intersection / boundary_union
        boundary_loss = 1.0 - boundary_iou
        
        return torch.tensor(boundary_loss, dtype=torch.float32, device=pred_binary.device)

    def forward(self, pred_masks, target_masks):
        """
        Compute topological loss between predictions and targets
        
        Args:
            pred_masks: Tensor of shape [B, H, W] with class indices
            target_masks: Tensor of shape [B, H, W] with class indices
        """
        batch_size = pred_masks.shape[0]
        total_loss = 0.0
        valid_classes_count = 0
        
        for batch_idx in range(batch_size):
            pred_mask = pred_masks[batch_idx]
            target_mask = target_masks[batch_idx]
            
            # Get unique classes in this batch item
            unique_classes = torch.unique(torch.cat([pred_mask, target_mask]))
            
            for class_id in unique_classes:
                class_id = class_id.item()
                if class_id == 0:  # Skip background
                    continue
                    
                class_weight = self.class_weights.get(class_id, self.default_weight)
                if class_weight == 0:
                    continue
                
                # Extract binary masks for this class
                pred_binary = (pred_mask == class_id).float()
                target_binary = (target_mask == class_id).float()
                
                # Skip if both are empty
                if pred_binary.sum() == 0 and target_binary.sum() == 0:
                    continue
                
                class_loss = 0.0
                
                # 1. Component count loss
                comp_loss = self.compute_component_loss(pred_binary, target_binary)
                class_loss += comp_loss
                
                # 2. Boundary consistency loss
                boundary_loss = self.compute_boundary_loss(pred_binary, target_binary)
                class_loss += boundary_loss
                
                total_loss += class_weight * class_loss
                valid_classes_count += 1
        
        # Normalize by number of valid class comparisons
        if valid_classes_count > 0:
            total_loss = total_loss / valid_classes_count
        
        return total_loss

# ==================== COMBINED LOSS ====================
class CombinedLoss(nn.Module):
    def __init__(self, topo_weight=TOPO_LOSS_WEIGHT):
        super().__init__()
        self.ce_loss = nn.CrossEntropyLoss()
        self.topo_loss = TopologicalLoss()
        self.topo_weight = topo_weight
    
    def forward(self, logits, targets, pred_masks=None):
        # Standard cross entropy loss
        ce_loss = self.ce_loss(logits, targets)
        
        # Topological loss (if pred_masks are provided)
        if pred_masks is not None:
            topo_loss = self.topo_loss(pred_masks, targets)
            total_loss = ce_loss + self.topo_weight * topo_loss
            return total_loss, ce_loss, topo_loss
        else:
            return ce_loss, ce_loss, torch.tensor(0.0)

# ==================== SIMPLE DATA TRANSFORM ====================
class SimpleTransform:
    def __call__(self, image, mask):
        # Resize to 256x256 and normalize
        image = cv2.resize(image, (256, 256))
        mask = cv2.resize(mask, (256, 256), interpolation=cv2.INTER_NEAREST)
        
        # Normalize image
        image = image.astype(np.float32) / 255.0
        image = (image - np.array([0.485, 0.456, 0.406])) / np.array([0.229, 0.224, 0.225])
        
        # Convert to tensor
        image = torch.from_numpy(image).permute(2, 0, 1).float()
        mask = torch.from_numpy(mask).long()
        
        return image, mask

# ==================== MODEL ARCHITECTURE ====================
class HighIoUSAMWrapper(nn.Module):
    def __init__(self, sam_model, num_classes):
        super().__init__()
        self.sam = sam_model
        self.num_classes = num_classes
        
        # Simple segmentation head
        self.segmentation_head = nn.Sequential(
            nn.Conv2d(256, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, num_classes, 1)
        )
        
        # Freeze SAM encoder
        for param in self.sam.image_encoder.parameters():
            param.requires_grad = False
    
    def unfreeze_encoder(self, percentage=0.5):
        total_layers = len(list(self.sam.image_encoder.parameters()))
        layers_to_unfreeze = int(total_layers * percentage)
        
        for i, param in enumerate(self.sam.image_encoder.parameters()):
            if i >= (total_layers - layers_to_unfreeze):
                param.requires_grad = True
    
    def forward(self, x):
        # Input should be 1024x1024 for SAM
        image_embeddings = self.sam.image_encoder(x)
        logits = self.segmentation_head(image_embeddings)
        return logits

# ==================== DATASET ====================
class HighIoUDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        
        self.image_files = sorted([f for f in os.listdir(image_dir) 
                                 if f.endswith(('.png', '.jpg', '.jpeg', '.tif'))])
        
        print(f"Found {len(self.image_files)} images in {image_dir}")
    
    def __len__(self):
        return len(self.image_files)
    
    def __getitem__(self, idx):
        image_path = os.path.join(self.image_dir, self.image_files[idx])
        base_name = os.path.splitext(self.image_files[idx])[0]
        mask_path = os.path.join(self.mask_dir, base_name + '.png')
        
        # Load image
        image = cv2.imread(image_path)
        if image is None:
            raise ValueError(f"Could not load image: {image_path}")
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # Load mask
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        if mask is None:
            raise ValueError(f"Could not load mask: {mask_path}")
        
        # Apply transformations
        if self.transform:
            image, mask = self.transform(image, mask)
        else:
            # Default processing
            image = cv2.resize(image, (256, 256))
            mask = cv2.resize(mask, (256, 256), interpolation=cv2.INTER_NEAREST)
            image = torch.from_numpy(image).permute(2, 0, 1).float() / 255.0
            mask = torch.from_numpy(mask).long()
        
        return {'image': image, 'mask': mask}

# ==================== FIXED METRICS ====================
def calculate_iou(pred_mask, true_mask, num_classes):
    ious = []
    
    for class_id in range(num_classes):
        pred_inds = (pred_mask == class_id)
        target_inds = (true_mask == class_id)
        
        intersection = np.logical_and(pred_inds, target_inds).sum()
        union = np.logical_or(pred_inds, target_inds).sum()
        
        if union == 0:
            ious.append(float('nan'))
        else:
            ious.append(float(intersection / union))
    
    return np.nanmean(ious)

# ==================== MODIFIED TRAINING FUNCTION ====================
def train_high_iou_sam():
    print("=== PHASE 1: HIGH IoU SAM TRAINING WITH TOPOLOGICAL LOSS ===")
    print(f"Using batch size: {BATCH_SIZE} (reduced for memory)")
    print(f"Topological loss weight: {TOPO_LOSS_WEIGHT}")
    
    # Load SAM model
    print("Loading SAM model...")
    sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
    model = HighIoUSAMWrapper(sam, NUM_CLASSES).to(device)
    
    # Check if we have a saved model to continue from
    start_epoch = 0
    if os.path.exists('best_high_iou_sam.pth'):
        print("🔄 Found saved model! Continuing from checkpoint...")
        checkpoint = torch.load('topo_best_high_iou_sam.pth', map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        start_epoch = checkpoint['epoch'] + 1
        print(f"Continuing from epoch {start_epoch} with IoU: {checkpoint['iou']:.4f}")
    
    # Create datasets
    transform = SimpleTransform()
    train_dataset = HighIoUDataset(train_image_dir, train_mask_dir, transform)
    val_dataset = HighIoUDataset(val_image_dir, val_mask_dir, transform)
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
    
    print(f"Training samples: {len(train_dataset)}")
    print(f"Validation samples: {len(val_dataset)}")
    
    # Use combined loss with topological component
    criterion = CombinedLoss(topo_weight=TOPO_LOSS_WEIGHT)
    optimizer = Adam(model.parameters(), lr=LEARNING_RATE)
    scheduler = ReduceLROnPlateau(optimizer, mode='max', patience=5, factor=0.5, verbose=True)
    
    # Load optimizer state if continuing
    if os.path.exists('best_high_iou_sam.pth'):
        checkpoint = torch.load('best_high_iou_sam.pth', map_location=device)
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        best_iou = checkpoint['iou']
    else:
        best_iou = 0.0
    
    print("Starting training with topological loss...")
    for epoch in range(start_epoch, NUM_EPOCHS):
        # Training phase
        model.train()
        epoch_total_loss = 0
        epoch_ce_loss = 0
        epoch_topo_loss = 0
        num_batches = 0
        
        for batch_idx, batch in enumerate(train_loader):
            images = batch['image'].to(device)
            masks = batch['mask'].to(device)
            
            # Ensure masks are long type
            if masks.dtype != torch.long:
                masks = masks.long()
            
            optimizer.zero_grad()
            
            # Resize images to 1024x1024 for SAM
            images_resized = F.interpolate(images, size=1024, mode='bilinear', align_corners=False)
            
            # Forward pass
            logits = model(images_resized)
            
            # Resize logits back to 256x256
            logits = F.interpolate(logits, size=256, mode='bilinear', align_corners=False)
            
            # Get predicted masks for topological loss
            pred_masks = torch.argmax(logits, dim=1)
            
            # Compute combined loss
            total_loss, ce_loss, topo_loss = criterion(logits, masks, pred_masks)
            
            total_loss.backward()
            optimizer.step()
            
            epoch_total_loss += total_loss.item()
            epoch_ce_loss += ce_loss.item()
            epoch_topo_loss += topo_loss.item()
            num_batches += 1
            
            if batch_idx % 10 == 0:
                print(f'Epoch {epoch+1}, Batch {batch_idx}: '
                      f'Total Loss: {total_loss.item():.4f}, '
                      f'CE: {ce_loss.item():.4f}, '
                      f'Topo: {topo_loss.item():.4f}')
        
        avg_total_loss = epoch_total_loss / num_batches
        avg_ce_loss = epoch_ce_loss / num_batches
        avg_topo_loss = epoch_topo_loss / num_batches
        
        # Validation phase
        model.eval()
        val_iou = 0
        num_val_samples = 0
        
        with torch.no_grad():
            for val_batch in val_loader:
                images = val_batch['image'].to(device)
                masks = val_batch['mask'].to(device)
                
                if masks.dtype != torch.long:
                    masks = masks.long()
                
                images_resized = F.interpolate(images, size=1024, mode='bilinear', align_corners=False)
                logits = model(images_resized)
                logits = F.interpolate(logits, size=256, mode='bilinear', align_corners=False)
                pred_masks = torch.argmax(logits, dim=1)
                
                for i in range(pred_masks.shape[0]):
                    iou = calculate_iou(pred_masks[i].cpu().numpy(), masks[i].cpu().numpy(), NUM_CLASSES)
                    val_iou += iou
                    num_val_samples += 1
        
        avg_val_iou = val_iou / num_val_samples if num_val_samples > 0 else 0
        scheduler.step(avg_val_iou)
        
        print(f'Epoch {epoch+1}/{NUM_EPOCHS}:')
        print(f'  Train - Total: {avg_total_loss:.4f}, CE: {avg_ce_loss:.4f}, Topo: {avg_topo_loss:.4f}')
        print(f'  Val IoU: {avg_val_iou:.4f}')
        
        if avg_val_iou > best_iou:
            best_iou = avg_val_iou
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': avg_total_loss,
                'iou': best_iou,
                'ce_loss': avg_ce_loss,
                'topo_loss': avg_topo_loss,
            }, 'best_high_iou_sam.pth')
            print(f'✅ Saved new best model with IoU: {best_iou:.4f}')
        
        # Gradually unfreeze encoder (adjust based on current epoch)
        if epoch == 20 and epoch >= start_epoch:
            model.unfreeze_encoder(0.3)
            print("🔄 Unfrozen 30% of encoder layers")
        elif epoch == 40 and epoch >= start_epoch:
            model.unfreeze_encoder(0.6)
            print("🔄 Unfrozen 60% of encoder layers")
        elif epoch == 60 and epoch >= start_epoch:
            model.unfreeze_encoder(1.0)
            print("🔄 Unfrozen all encoder layers")
    
    print(f"=== TRAINING COMPLETED ===")
    print(f"Best validation IoU: {best_iou:.4f}")
    
    return model, best_iou

# ==================== MAIN EXECUTION ====================
if __name__ == "__main__":
    trained_model, final_iou = train_high_iou_sam()
    
    print(f"\n🎯 PHASE 1 COMPLETED with IoU: {final_iou:.4f}")
    
    if final_iou >= 0.85:
        print("✅ Ready for Phase 2: Weak data processing")
    else:
        print("❌ Need to improve Phase 1")
# Out:
# Using device: cuda
# === PHASE 1: HIGH IoU SAM TRAINING WITH TOPOLOGICAL LOSS ===
# Using batch size: 2 (reduced for memory)
# Topological loss weight: 0.3
# Loading SAM model...
# /home/iiitdmk-param/AMB/Proposed_3/SAM/segment-anything-main/segment_anything/build_sam.py:105: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(f)
# 🔄 Found saved model! Continuing from checkpoint...
# /tmp/ipykernel_1150332/1359389309.py:336: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('topo_best_high_iou_sam.pth', map_location=device)
# Continuing from epoch 41 with IoU: 0.8290
# Found 630 images in /home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_images
# Found 630 images in /home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_images
# Training samples: 630
# Validation samples: 630
# /home/iiitdmk-param/.local/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# /tmp/ipykernel_1150332/1359389309.py:360: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('best_high_iou_sam.pth', map_location=device)
# Starting training with topological loss...
# Epoch 42, Batch 0: Total Loss: 0.8060, CE: 0.1512, Topo: 2.1827
# Epoch 42, Batch 10: Total Loss: 2.2283, CE: 0.5965, Topo: 5.4394
# Epoch 42, Batch 20: Total Loss: 1.1897, CE: 0.3577, Topo: 2.7734
# Epoch 42, Batch 30: Total Loss: 0.8866, CE: 0.2116, Topo: 2.2502
# Epoch 42, Batch 40: Total Loss: 6.5577, CE: 0.5785, Topo: 19.9305
# Epoch 42, Batch 50: Total Loss: 0.5366, CE: 0.1660, Topo: 1.2353
# Epoch 42, Batch 60: Total Loss: 0.6547, CE: 0.2244, Topo: 1.4344
# Epoch 42, Batch 70: Total Loss: 0.3498, CE: 0.1073, Topo: 0.8085
# Epoch 42, Batch 80: Total Loss: 13.9463, CE: 0.7160, Topo: 44.1011
# Epoch 42, Batch 90: Total Loss: 0.2405, CE: 0.0636, Topo: 0.5894
# Epoch 42, Batch 100: Total Loss: 0.6201, CE: 0.4192, Topo: 0.6695
# Epoch 42, Batch 110: Total Loss: 1.3900, CE: 0.3480, Topo: 3.4735
# Epoch 42, Batch 120: Total Loss: 0.4789, CE: 0.1125, Topo: 1.2212
# Epoch 42, Batch 130: Total Loss: 0.9694, CE: 0.3315, Topo: 2.1265
# Epoch 42, Batch 140: Total Loss: 0.6820, CE: 0.2444, Topo: 1.4587
# Epoch 42, Batch 150: Total Loss: 0.2504, CE: 0.0798, Topo: 0.5688
# Epoch 42, Batch 160: Total Loss: 1.1007, CE: 0.2669, Topo: 2.7794
# Epoch 42, Batch 170: Total Loss: 1.1487, CE: 0.3621, Topo: 2.6222
# Epoch 42, Batch 180: Total Loss: 2.2994, CE: 0.8549, Topo: 4.8151
# Epoch 42, Batch 190: Total Loss: 1.1311, CE: 0.3646, Topo: 2.5550
# Epoch 42, Batch 200: Total Loss: 0.2093, CE: 0.0917, Topo: 0.3920
# Epoch 42, Batch 210: Total Loss: 0.3472, CE: 0.1380, Topo: 0.6973
# Epoch 42, Batch 220: Total Loss: 0.2040, CE: 0.0810, Topo: 0.4102
# Epoch 42, Batch 230: Total Loss: 0.7087, CE: 0.2383, Topo: 1.5680
# Epoch 42, Batch 240: Total Loss: 1.9066, CE: 0.5484, Topo: 4.5273
# Epoch 42, Batch 250: Total Loss: 0.6533, CE: 0.2099, Topo: 1.4777
# Epoch 42, Batch 260: Total Loss: 1.4781, CE: 0.2149, Topo: 4.2108
# Epoch 42, Batch 270: Total Loss: 0.6235, CE: 0.1399, Topo: 1.6121
# Epoch 42, Batch 280: Total Loss: 0.3153, CE: 0.1594, Topo: 0.5198
# Epoch 42, Batch 290: Total Loss: 0.5005, CE: 0.2612, Topo: 0.7978
# Epoch 42, Batch 300: Total Loss: 1.2201, CE: 0.4816, Topo: 2.4617
# Epoch 42, Batch 310: Total Loss: 0.8622, CE: 0.1149, Topo: 2.4908
# Epoch 42/100:
#   Train - Total: 1.1518, CE: 0.2898, Topo: 2.8732
#   Val IoU: 0.8347
# Epoch 43, Batch 0: Total Loss: 0.5058, CE: 0.2175, Topo: 0.9610
# Epoch 43, Batch 10: Total Loss: 1.2765, CE: 0.2773, Topo: 3.3306
# Epoch 43, Batch 20: Total Loss: 0.7233, CE: 0.1522, Topo: 1.9036
# Epoch 43, Batch 30: Total Loss: 0.8426, CE: 0.2130, Topo: 2.0988
# Epoch 43, Batch 40: Total Loss: 1.3811, CE: 0.3001, Topo: 3.6031
# Epoch 43, Batch 50: Total Loss: 0.2619, CE: 0.1014, Topo: 0.5349
# Epoch 43, Batch 60: Total Loss: 0.6647, CE: 0.1298, Topo: 1.7830
# Epoch 43, Batch 70: Total Loss: 1.6556, CE: 0.2402, Topo: 4.7178
# Epoch 43, Batch 80: Total Loss: 0.6876, CE: 0.3546, Topo: 1.1098
# Epoch 43, Batch 90: Total Loss: 2.4181, CE: 0.3161, Topo: 7.0069
# Epoch 43, Batch 100: Total Loss: 0.6883, CE: 0.2612, Topo: 1.4237
# Epoch 43, Batch 110: Total Loss: 1.0675, CE: 0.3965, Topo: 2.2368
# Epoch 43, Batch 120: Total Loss: 0.4140, CE: 0.0697, Topo: 1.1476
# Epoch 43, Batch 130: Total Loss: 0.7693, CE: 0.2150, Topo: 1.8476
# Epoch 43, Batch 140: Total Loss: 3.8481, CE: 0.4175, Topo: 11.4353
# Epoch 43, Batch 150: Total Loss: 2.2241, CE: 0.8322, Topo: 4.6396
# Epoch 43, Batch 160: Total Loss: 0.5925, CE: 0.2275, Topo: 1.2166
# Epoch 43, Batch 170: Total Loss: 0.9541, CE: 0.3676, Topo: 1.9550
# Epoch 43, Batch 180: Total Loss: 1.2291, CE: 0.4752, Topo: 2.5128
# Epoch 43, Batch 190: Total Loss: 1.1307, CE: 0.2563, Topo: 2.9149
# Epoch 43, Batch 200: Total Loss: 0.8678, CE: 0.3399, Topo: 1.7596
# Epoch 43, Batch 210: Total Loss: 0.5520, CE: 0.2097, Topo: 1.1407
# Epoch 43, Batch 220: Total Loss: 0.6013, CE: 0.2504, Topo: 1.1696
# Epoch 43, Batch 230: Total Loss: 1.8392, CE: 0.2114, Topo: 5.4261
# Epoch 43, Batch 240: Total Loss: 1.0244, CE: 0.3511, Topo: 2.2446
# Epoch 43, Batch 250: Total Loss: 0.5701, CE: 0.1800, Topo: 1.3003
# Epoch 43, Batch 260: Total Loss: 0.2695, CE: 0.0582, Topo: 0.7041
# Epoch 43, Batch 270: Total Loss: 1.0537, CE: 0.3311, Topo: 2.4085
# Epoch 43, Batch 280: Total Loss: 2.2158, CE: 0.2823, Topo: 6.4448
# Epoch 43, Batch 290: Total Loss: 0.8935, CE: 0.1947, Topo: 2.3295
# Epoch 43, Batch 300: Total Loss: 4.3723, CE: 0.3769, Topo: 13.3178
# Epoch 43, Batch 310: Total Loss: 0.8172, CE: 0.1130, Topo: 2.3472
# Epoch 43/100:
#   Train - Total: 1.0238, CE: 0.2684, Topo: 2.5180
#   Val IoU: 0.8336
# Epoch 44, Batch 0: Total Loss: 0.1906, CE: 0.1213, Topo: 0.2309
# Epoch 44, Batch 10: Total Loss: 2.5306, CE: 0.6195, Topo: 6.3703
# Epoch 44, Batch 20: Total Loss: 1.8131, CE: 0.4230, Topo: 4.6335
# Epoch 44, Batch 30: Total Loss: 0.7873, CE: 0.3348, Topo: 1.5082
# Epoch 44, Batch 40: Total Loss: 0.5123, CE: 0.1342, Topo: 1.2602
# Epoch 44, Batch 50: Total Loss: 1.2669, CE: 0.2938, Topo: 3.2437
# Epoch 44, Batch 60: Total Loss: 0.2983, CE: 0.1044, Topo: 0.6465
# Epoch 44, Batch 70: Total Loss: 3.7687, CE: 1.7943, Topo: 6.5811
# Epoch 44, Batch 80: Total Loss: 0.1472, CE: 0.0768, Topo: 0.2349
# Epoch 44, Batch 90: Total Loss: 0.6258, CE: 0.2074, Topo: 1.3948
# Epoch 44, Batch 100: Total Loss: 2.5239, CE: 0.5219, Topo: 6.6736
# Epoch 44, Batch 110: Total Loss: 2.7159, CE: 0.4161, Topo: 7.6662
# Epoch 44, Batch 120: Total Loss: 0.9319, CE: 0.1317, Topo: 2.6671
# Epoch 44, Batch 130: Total Loss: 1.3380, CE: 0.5649, Topo: 2.5770
# Epoch 44, Batch 140: Total Loss: 0.6253, CE: 0.1280, Topo: 1.6579
# Epoch 44, Batch 150: Total Loss: 1.1220, CE: 0.2737, Topo: 2.8277
# Epoch 44, Batch 160: Total Loss: 0.7215, CE: 0.1647, Topo: 1.8558
# Epoch 44, Batch 170: Total Loss: 1.7016, CE: 0.2043, Topo: 4.9911
# Epoch 44, Batch 180: Total Loss: 1.0101, CE: 0.2527, Topo: 2.5247
# Epoch 44, Batch 190: Total Loss: 1.1135, CE: 0.2735, Topo: 2.8000
# Epoch 44, Batch 200: Total Loss: 0.5446, CE: 0.2163, Topo: 1.0944
# Epoch 44, Batch 210: Total Loss: 1.4856, CE: 0.4776, Topo: 3.3602
# Epoch 44, Batch 220: Total Loss: 1.7502, CE: 0.7158, Topo: 3.4478
# Epoch 44, Batch 230: Total Loss: 0.6228, CE: 0.2011, Topo: 1.4059
# Epoch 44, Batch 240: Total Loss: 2.8810, CE: 0.5295, Topo: 7.8383
# Epoch 44, Batch 250: Total Loss: 1.1206, CE: 0.2151, Topo: 3.0183
# Epoch 44, Batch 260: Total Loss: 0.9572, CE: 0.3219, Topo: 2.1176
# Epoch 44, Batch 270: Total Loss: 0.4163, CE: 0.1508, Topo: 0.8849
# Epoch 44, Batch 280: Total Loss: 1.8400, CE: 0.2856, Topo: 5.1815
# Epoch 44, Batch 290: Total Loss: 0.3228, CE: 0.1073, Topo: 0.7183
# Epoch 44, Batch 300: Total Loss: 0.5818, CE: 0.2204, Topo: 1.2047
# Epoch 44, Batch 310: Total Loss: 0.3601, CE: 0.1469, Topo: 0.7107
# Epoch 44/100:
#   Train - Total: 1.0453, CE: 0.2546, Topo: 2.6359
#   Val IoU: 0.8328
# Epoch 45, Batch 0: Total Loss: 1.2234, CE: 0.2704, Topo: 3.1766
# Epoch 45, Batch 10: Total Loss: 0.4421, CE: 0.1233, Topo: 1.0626
# Epoch 45, Batch 20: Total Loss: 0.5091, CE: 0.1221, Topo: 1.2899
# Epoch 45, Batch 30: Total Loss: 0.6920, CE: 0.2418, Topo: 1.5007
# Epoch 45, Batch 40: Total Loss: 0.4754, CE: 0.0959, Topo: 1.2650
# Epoch 45, Batch 50: Total Loss: 0.5053, CE: 0.1016, Topo: 1.3457
# Epoch 45, Batch 60: Total Loss: 0.9075, CE: 0.2244, Topo: 2.2771
# Epoch 45, Batch 70: Total Loss: 3.8939, CE: 0.6443, Topo: 10.8320
# Epoch 45, Batch 80: Total Loss: 0.2415, CE: 0.0619, Topo: 0.5988
# Epoch 45, Batch 90: Total Loss: 0.1562, CE: 0.0657, Topo: 0.3018
# Epoch 45, Batch 100: Total Loss: 1.8728, CE: 0.2712, Topo: 5.3388
# Epoch 45, Batch 110: Total Loss: 0.4694, CE: 0.1328, Topo: 1.1221
# Epoch 45, Batch 120: Total Loss: 0.5158, CE: 0.1100, Topo: 1.3528
# Epoch 45, Batch 130: Total Loss: 0.8258, CE: 0.3158, Topo: 1.6999
# Epoch 45, Batch 140: Total Loss: 0.9459, CE: 0.3863, Topo: 1.8651
# Epoch 45, Batch 150: Total Loss: 0.8737, CE: 0.2734, Topo: 2.0010
# Epoch 45, Batch 160: Total Loss: 0.7973, CE: 0.2627, Topo: 1.7822
# Epoch 45, Batch 170: Total Loss: 0.4665, CE: 0.0920, Topo: 1.2483
# Epoch 45, Batch 180: Total Loss: 2.7794, CE: 0.6234, Topo: 7.1867
# Epoch 45, Batch 190: Total Loss: 0.6581, CE: 0.1556, Topo: 1.6748
# Epoch 45, Batch 200: Total Loss: 0.6900, CE: 0.2023, Topo: 1.6258
# Epoch 45, Batch 210: Total Loss: 0.5842, CE: 0.2066, Topo: 1.2588
# Epoch 45, Batch 220: Total Loss: 1.1822, CE: 0.3473, Topo: 2.7832
# Epoch 45, Batch 230: Total Loss: 0.4405, CE: 0.0840, Topo: 1.1881
# Epoch 45, Batch 240: Total Loss: 2.0106, CE: 0.4205, Topo: 5.3001
# Epoch 45, Batch 250: Total Loss: 0.9061, CE: 0.2810, Topo: 2.0837
# Epoch 45, Batch 260: Total Loss: 0.5247, CE: 0.1463, Topo: 1.2611
# Epoch 45, Batch 270: Total Loss: 0.3811, CE: 0.1736, Topo: 0.6916
# Epoch 45, Batch 280: Total Loss: 0.4433, CE: 0.1272, Topo: 1.0538
# Epoch 45, Batch 290: Total Loss: 1.0417, CE: 0.3210, Topo: 2.4024
# Epoch 45, Batch 300: Total Loss: 1.1711, CE: 0.3133, Topo: 2.8593
# Epoch 45, Batch 310: Total Loss: 0.5541, CE: 0.0942, Topo: 1.5329
# Epoch 45/100:
#   Train - Total: 0.9889, CE: 0.2315, Topo: 2.5248
#   Val IoU: 0.8342
# Epoch 46, Batch 0: Total Loss: 0.4941, CE: 0.1999, Topo: 0.9807
# Epoch 46, Batch 10: Total Loss: 0.4322, CE: 0.2034, Topo: 0.7626
# Epoch 46, Batch 20: Total Loss: 0.6689, CE: 0.1525, Topo: 1.7213
# Epoch 46, Batch 30: Total Loss: 0.5001, CE: 0.1284, Topo: 1.2391
# Epoch 46, Batch 40: Total Loss: 6.9057, CE: 2.3745, Topo: 15.1042
# Epoch 46, Batch 50: Total Loss: 8.2964, CE: 0.4616, Topo: 26.1160
# Epoch 46, Batch 60: Total Loss: 0.4231, CE: 0.1944, Topo: 0.7624
# Epoch 46, Batch 70: Total Loss: 0.5776, CE: 0.1778, Topo: 1.3325
# Epoch 46, Batch 80: Total Loss: 0.5518, CE: 0.2217, Topo: 1.1003
# Epoch 46, Batch 90: Total Loss: 0.3820, CE: 0.1021, Topo: 0.9332
# Epoch 46, Batch 100: Total Loss: 0.6387, CE: 0.1290, Topo: 1.6989
# Epoch 46, Batch 110: Total Loss: 0.3920, CE: 0.1813, Topo: 0.7021
# Epoch 46, Batch 120: Total Loss: 0.4763, CE: 0.0874, Topo: 1.2965
# Epoch 46, Batch 130: Total Loss: 0.5364, CE: 0.1285, Topo: 1.3595
# Epoch 46, Batch 140: Total Loss: 1.2881, CE: 0.3324, Topo: 3.1858
# Epoch 46, Batch 150: Total Loss: 0.4762, CE: 0.1168, Topo: 1.1981
# Epoch 46, Batch 160: Total Loss: 0.4221, CE: 0.1247, Topo: 0.9915
# Epoch 46, Batch 170: Total Loss: 0.9272, CE: 0.1670, Topo: 2.5337
# Epoch 46, Batch 180: Total Loss: 0.2188, CE: 0.0611, Topo: 0.5256
# Epoch 46, Batch 190: Total Loss: 0.5164, CE: 0.1589, Topo: 1.1914
# Epoch 46, Batch 200: Total Loss: 1.0033, CE: 0.3657, Topo: 2.1253
# Epoch 46, Batch 210: Total Loss: 0.5544, CE: 0.2006, Topo: 1.1792
# Epoch 46, Batch 220: Total Loss: 0.5865, CE: 0.1618, Topo: 1.4156
# Epoch 46, Batch 230: Total Loss: 0.7333, CE: 0.1978, Topo: 1.7851
# Epoch 46, Batch 240: Total Loss: 1.3406, CE: 0.2909, Topo: 3.4991
# Epoch 46, Batch 250: Total Loss: 0.3079, CE: 0.1253, Topo: 0.6086
# Epoch 46, Batch 260: Total Loss: 3.8715, CE: 0.1926, Topo: 12.2630
# Epoch 46, Batch 270: Total Loss: 0.4685, CE: 0.2005, Topo: 0.8932
# Epoch 46, Batch 280: Total Loss: 0.1464, CE: 0.0725, Topo: 0.2463
# Epoch 46, Batch 290: Total Loss: 0.6584, CE: 0.1919, Topo: 1.5549
# Epoch 46, Batch 300: Total Loss: 0.2371, CE: 0.0727, Topo: 0.5481
# Epoch 46, Batch 310: Total Loss: 0.6336, CE: 0.2135, Topo: 1.4004
# Epoch 46/100:
#   Train - Total: 0.9694, CE: 0.2313, Topo: 2.4604
#   Val IoU: 0.8299
# Epoch 47, Batch 0: Total Loss: 0.3718, CE: 0.1700, Topo: 0.6727
# Epoch 47, Batch 10: Total Loss: 0.5131, CE: 0.1578, Topo: 1.1843
# Epoch 47, Batch 20: Total Loss: 0.6970, CE: 0.2008, Topo: 1.6539
# Epoch 47, Batch 30: Total Loss: 1.2439, CE: 0.3990, Topo: 2.8164
# Epoch 47, Batch 40: Total Loss: 0.3038, CE: 0.0892, Topo: 0.7155
# Epoch 47, Batch 50: Total Loss: 0.7723, CE: 0.2978, Topo: 1.5818
# Epoch 47, Batch 60: Total Loss: 1.3594, CE: 0.3228, Topo: 3.4554
# Epoch 47, Batch 70: Total Loss: 0.5043, CE: 0.1721, Topo: 1.1072
# Epoch 47, Batch 80: Total Loss: 0.6377, CE: 0.2315, Topo: 1.3542
# Epoch 47, Batch 90: Total Loss: 0.2250, CE: 0.0655, Topo: 0.5317
# Epoch 47, Batch 100: Total Loss: 0.8499, CE: 0.2296, Topo: 2.0678
# Epoch 47, Batch 110: Total Loss: 0.7646, CE: 0.1987, Topo: 1.8863
# Epoch 47, Batch 120: Total Loss: 0.5094, CE: 0.2001, Topo: 1.0309
# Epoch 47, Batch 130: Total Loss: 0.2857, CE: 0.0833, Topo: 0.6747
# Epoch 47, Batch 140: Total Loss: 0.2641, CE: 0.1941, Topo: 0.2333
# Epoch 47, Batch 150: Total Loss: 0.6456, CE: 0.1589, Topo: 1.6225
# Epoch 47, Batch 160: Total Loss: 0.1731, CE: 0.0562, Topo: 0.3896
# Epoch 47, Batch 170: Total Loss: 0.5925, CE: 0.1285, Topo: 1.5465
# Epoch 47, Batch 180: Total Loss: 1.3838, CE: 0.3811, Topo: 3.3422
# Epoch 47, Batch 190: Total Loss: 0.1326, CE: 0.0458, Topo: 0.2895
# Epoch 47, Batch 200: Total Loss: 0.6513, CE: 0.1288, Topo: 1.7418
# Epoch 47, Batch 210: Total Loss: 0.6164, CE: 0.2166, Topo: 1.3326
# Epoch 47, Batch 220: Total Loss: 0.6482, CE: 0.4676, Topo: 0.6022
# Epoch 47, Batch 230: Total Loss: 1.6358, CE: 0.4051, Topo: 4.1024
# Epoch 47, Batch 240: Total Loss: 1.2159, CE: 0.5725, Topo: 2.1446
# Epoch 47, Batch 250: Total Loss: 0.3943, CE: 0.1573, Topo: 0.7897
# Epoch 47, Batch 260: Total Loss: 1.6901, CE: 0.2594, Topo: 4.7688
# Epoch 47, Batch 270: Total Loss: 1.0602, CE: 0.2887, Topo: 2.5716
# Epoch 47, Batch 280: Total Loss: 0.6114, CE: 0.0750, Topo: 1.7880
# Epoch 47, Batch 290: Total Loss: 0.3079, CE: 0.0913, Topo: 0.7222
# Epoch 47, Batch 300: Total Loss: 1.8047, CE: 0.3897, Topo: 4.7168
# Epoch 47, Batch 310: Total Loss: 0.7678, CE: 0.3081, Topo: 1.5324
# Epoch 47/100:
#   Train - Total: 1.0803, CE: 0.2412, Topo: 2.7968
#   Val IoU: 0.8360
# Epoch 48, Batch 0: Total Loss: 0.6100, CE: 0.2407, Topo: 1.2311
# Epoch 48, Batch 10: Total Loss: 2.9086, CE: 0.2980, Topo: 8.7019
# Epoch 48, Batch 20: Total Loss: 1.1270, CE: 0.1411, Topo: 3.2863
# Epoch 48, Batch 30: Total Loss: 0.5173, CE: 0.1456, Topo: 1.2389
# Epoch 48, Batch 40: Total Loss: 0.4964, CE: 0.2064, Topo: 0.9666
# Epoch 48, Batch 50: Total Loss: 0.7182, CE: 0.2008, Topo: 1.7246
# Epoch 48, Batch 60: Total Loss: 0.4093, CE: 0.1046, Topo: 1.0156
# Epoch 48, Batch 70: Total Loss: 0.7479, CE: 0.3006, Topo: 1.4912
# Epoch 48, Batch 80: Total Loss: 1.1517, CE: 0.2704, Topo: 2.9379
# Epoch 48, Batch 90: Total Loss: 0.8348, CE: 0.2064, Topo: 2.0945
# Epoch 48, Batch 100: Total Loss: 0.9556, CE: 0.2112, Topo: 2.4813
# Epoch 48, Batch 110: Total Loss: 0.5084, CE: 0.1091, Topo: 1.3311
# Epoch 48, Batch 120: Total Loss: 0.8341, CE: 0.2849, Topo: 1.8307
# Epoch 48, Batch 130: Total Loss: 0.6358, CE: 0.2110, Topo: 1.4161
# Epoch 48, Batch 140: Total Loss: 0.3464, CE: 0.2288, Topo: 0.3920
# Epoch 48, Batch 150: Total Loss: 0.6669, CE: 0.1213, Topo: 1.8186
# Epoch 48, Batch 160: Total Loss: 0.5279, CE: 0.1684, Topo: 1.1981
# Epoch 48, Batch 170: Total Loss: 3.2988, CE: 0.3249, Topo: 9.9131
# Epoch 48, Batch 180: Total Loss: 1.1712, CE: 0.3251, Topo: 2.8204
# Epoch 48, Batch 190: Total Loss: 1.5633, CE: 0.3184, Topo: 4.1498
# Epoch 48, Batch 200: Total Loss: 0.2461, CE: 0.1193, Topo: 0.4227
# Epoch 48, Batch 210: Total Loss: 0.4601, CE: 0.1602, Topo: 0.9995
# Epoch 48, Batch 220: Total Loss: 0.4081, CE: 0.1607, Topo: 0.8246
# Epoch 48, Batch 230: Total Loss: 0.7798, CE: 0.1275, Topo: 2.1743
# Epoch 48, Batch 240: Total Loss: 0.2407, CE: 0.0664, Topo: 0.5811
# Epoch 48, Batch 250: Total Loss: 0.8243, CE: 0.1285, Topo: 2.3195
# Epoch 48, Batch 260: Total Loss: 0.8941, CE: 0.2018, Topo: 2.3075
# Epoch 48, Batch 270: Total Loss: 2.7036, CE: 0.2812, Topo: 8.0747
# Epoch 48, Batch 280: Total Loss: 0.7420, CE: 0.1432, Topo: 1.9960
# Epoch 48, Batch 290: Total Loss: 1.3005, CE: 0.2796, Topo: 3.4029
# Epoch 48, Batch 300: Total Loss: 0.1984, CE: 0.0878, Topo: 0.3687
# Epoch 48, Batch 310: Total Loss: 0.3180, CE: 0.1162, Topo: 0.6726
# Epoch 48/100:
#   Train - Total: 1.0056, CE: 0.2471, Topo: 2.5282
#   Val IoU: 0.8326
# Epoch 49, Batch 0: Total Loss: 0.7668, CE: 0.2484, Topo: 1.7279
# Epoch 49, Batch 10: Total Loss: 1.6011, CE: 0.3775, Topo: 4.0785
# Epoch 49, Batch 20: Total Loss: 0.2816, CE: 0.0949, Topo: 0.6223
# Epoch 49, Batch 30: Total Loss: 0.4417, CE: 0.1710, Topo: 0.9024
# Epoch 49, Batch 40: Total Loss: 0.3332, CE: 0.0829, Topo: 0.8346
# Epoch 49, Batch 50: Total Loss: 0.7803, CE: 0.0875, Topo: 2.3094
# Epoch 49, Batch 60: Total Loss: 1.4080, CE: 0.2499, Topo: 3.8603
# Epoch 49, Batch 70: Total Loss: 0.2297, CE: 0.1170, Topo: 0.3757
# Epoch 49, Batch 80: Total Loss: 0.9674, CE: 0.2684, Topo: 2.3301
# Epoch 49, Batch 90: Total Loss: 0.2967, CE: 0.1061, Topo: 0.6354
# Epoch 49, Batch 100: Total Loss: 1.0154, CE: 0.1895, Topo: 2.7531
# Epoch 49, Batch 110: Total Loss: 0.4880, CE: 0.1061, Topo: 1.2731
# Epoch 49, Batch 120: Total Loss: 0.2878, CE: 0.1133, Topo: 0.5816
# Epoch 49, Batch 130: Total Loss: 0.9891, CE: 0.2412, Topo: 2.4930
# Epoch 49, Batch 140: Total Loss: 0.7267, CE: 0.1731, Topo: 1.8452
# Epoch 49, Batch 150: Total Loss: 0.5150, CE: 0.2046, Topo: 1.0346
# Epoch 49, Batch 160: Total Loss: 1.4412, CE: 0.3668, Topo: 3.5813
# Epoch 49, Batch 170: Total Loss: 0.2821, CE: 0.0461, Topo: 0.7868
# Epoch 49, Batch 180: Total Loss: 0.3938, CE: 0.1184, Topo: 0.9182
# Epoch 49, Batch 190: Total Loss: 0.5072, CE: 0.1359, Topo: 1.2378
# Epoch 49, Batch 200: Total Loss: 0.5376, CE: 0.0941, Topo: 1.4782
# Epoch 49, Batch 210: Total Loss: 0.4256, CE: 0.1145, Topo: 1.0369
# Epoch 49, Batch 220: Total Loss: 0.4620, CE: 0.1569, Topo: 1.0168
# Epoch 49, Batch 230: Total Loss: 0.3059, CE: 0.1084, Topo: 0.6583
# Epoch 49, Batch 240: Total Loss: 0.2519, CE: 0.1634, Topo: 0.2949
# Epoch 49, Batch 250: Total Loss: 2.3668, CE: 0.7742, Topo: 5.3086
# Epoch 49, Batch 260: Total Loss: 0.7026, CE: 0.1821, Topo: 1.7349
# Epoch 49, Batch 270: Total Loss: 0.1125, CE: 0.0865, Topo: 0.0867
# Epoch 49, Batch 280: Total Loss: 0.3988, CE: 0.0867, Topo: 1.0404
# Epoch 49, Batch 290: Total Loss: 0.8743, CE: 0.2477, Topo: 2.0885
# Epoch 49, Batch 300: Total Loss: 0.1337, CE: 0.0450, Topo: 0.2959
# Epoch 49, Batch 310: Total Loss: 0.8406, CE: 0.0962, Topo: 2.4812
# Epoch 49/100:
#   Train - Total: 0.9261, CE: 0.2181, Topo: 2.3600
#   Val IoU: 0.8308
# Epoch 50, Batch 0: Total Loss: 0.3870, CE: 0.1222, Topo: 0.8825
# Epoch 50, Batch 10: Total Loss: 0.9052, CE: 0.3414, Topo: 1.8793
# Epoch 50, Batch 20: Total Loss: 0.3663, CE: 0.2093, Topo: 0.5232
# Epoch 50, Batch 30: Total Loss: 3.8826, CE: 0.3628, Topo: 11.7329
# Epoch 50, Batch 40: Total Loss: 0.3423, CE: 0.0801, Topo: 0.8740
# Epoch 50, Batch 50: Total Loss: 0.9506, CE: 0.2636, Topo: 2.2899
# Epoch 50, Batch 60: Total Loss: 0.2608, CE: 0.0999, Topo: 0.5362
# Epoch 50, Batch 70: Total Loss: 0.3528, CE: 0.0724, Topo: 0.9348
# Epoch 50, Batch 80: Total Loss: 1.3547, CE: 0.3249, Topo: 3.4326
# Epoch 50, Batch 90: Total Loss: 0.6922, CE: 0.1627, Topo: 1.7649
# Epoch 50, Batch 100: Total Loss: 0.9151, CE: 0.2786, Topo: 2.1216
# Epoch 50, Batch 110: Total Loss: 0.4902, CE: 0.0962, Topo: 1.3135
# Epoch 50, Batch 120: Total Loss: 0.3733, CE: 0.0787, Topo: 0.9821
# Epoch 50, Batch 130: Total Loss: 1.6684, CE: 0.5939, Topo: 3.5819
# Epoch 50, Batch 140: Total Loss: 0.4187, CE: 0.1404, Topo: 0.9277
# Epoch 50, Batch 150: Total Loss: 0.3223, CE: 0.1166, Topo: 0.6857
# Epoch 50, Batch 160: Total Loss: 0.5246, CE: 0.1751, Topo: 1.1651
# Epoch 50, Batch 170: Total Loss: 1.1418, CE: 0.3460, Topo: 2.6526
# Epoch 50, Batch 180: Total Loss: 0.6142, CE: 0.1231, Topo: 1.6369
# Epoch 50, Batch 190: Total Loss: 4.3970, CE: 0.6670, Topo: 12.4332
# Epoch 50, Batch 200: Total Loss: 0.2715, CE: 0.0850, Topo: 0.6219
# Epoch 50, Batch 210: Total Loss: 0.7781, CE: 0.3240, Topo: 1.5139
# Epoch 50, Batch 220: Total Loss: 0.4308, CE: 0.1204, Topo: 1.0346
# Epoch 50, Batch 230: Total Loss: 0.5639, CE: 0.1242, Topo: 1.4656
# Epoch 50, Batch 240: Total Loss: 0.3793, CE: 0.1637, Topo: 0.7184
# Epoch 50, Batch 250: Total Loss: 0.3651, CE: 0.1353, Topo: 0.7662
# Epoch 50, Batch 260: Total Loss: 0.7394, CE: 0.2298, Topo: 1.6988
# Epoch 50, Batch 270: Total Loss: 0.4273, CE: 0.1315, Topo: 0.9860
# Epoch 50, Batch 280: Total Loss: 0.8302, CE: 0.1917, Topo: 2.1284
# Epoch 50, Batch 290: Total Loss: 0.6718, CE: 0.1989, Topo: 1.5766
# Epoch 50, Batch 300: Total Loss: 0.4172, CE: 0.1644, Topo: 0.8427
# Epoch 50, Batch 310: Total Loss: 1.6757, CE: 0.3838, Topo: 4.3065
# Epoch 50/100:
#   Train - Total: 0.8682, CE: 0.2173, Topo: 2.1696
#   Val IoU: 0.8370
# Epoch 51, Batch 0: Total Loss: 0.4533, CE: 0.1093, Topo: 1.1466
# Epoch 51, Batch 10: Total Loss: 0.1093, CE: 0.0719, Topo: 0.1248
# Epoch 51, Batch 20: Total Loss: 0.7135, CE: 0.1112, Topo: 2.0077
# Epoch 51, Batch 30: Total Loss: 0.5067, CE: 0.0869, Topo: 1.3996
# Epoch 51, Batch 40: Total Loss: 0.6292, CE: 0.1939, Topo: 1.4509
# Epoch 51, Batch 50: Total Loss: 0.3688, CE: 0.1206, Topo: 0.8273
# Epoch 51, Batch 60: Total Loss: 1.3734, CE: 0.3084, Topo: 3.5502
# Epoch 51, Batch 70: Total Loss: 0.6539, CE: 0.2080, Topo: 1.4864
# Epoch 51, Batch 80: Total Loss: 1.5911, CE: 0.2905, Topo: 4.3353
# Epoch 51, Batch 90: Total Loss: 1.4031, CE: 0.4652, Topo: 3.1265
# Epoch 51, Batch 100: Total Loss: 0.9258, CE: 0.3445, Topo: 1.9376
# Epoch 51, Batch 110: Total Loss: 4.5227, CE: 0.6204, Topo: 13.0076
# Epoch 51, Batch 120: Total Loss: 0.8752, CE: 0.2192, Topo: 2.1865
# Epoch 51, Batch 130: Total Loss: 0.1899, CE: 0.0717, Topo: 0.3943
# Epoch 51, Batch 140: Total Loss: 0.6480, CE: 0.1664, Topo: 1.6052
# Epoch 51, Batch 150: Total Loss: 1.9324, CE: 0.2374, Topo: 5.6501
# Epoch 51, Batch 160: Total Loss: 0.2507, CE: 0.1055, Topo: 0.4841
# Epoch 51, Batch 170: Total Loss: 0.5035, CE: 0.1235, Topo: 1.2669
# Epoch 51, Batch 180: Total Loss: 0.4206, CE: 0.0936, Topo: 1.0899
# Epoch 51, Batch 190: Total Loss: 1.0458, CE: 0.2765, Topo: 2.5641
# Epoch 51, Batch 200: Total Loss: 0.5593, CE: 0.2994, Topo: 0.8663
# Epoch 51, Batch 210: Total Loss: 0.2579, CE: 0.1188, Topo: 0.4635
# Epoch 51, Batch 220: Total Loss: 1.8823, CE: 0.2695, Topo: 5.3758
# Epoch 51, Batch 230: Total Loss: 1.0245, CE: 0.3202, Topo: 2.3475
# Epoch 51, Batch 240: Total Loss: 0.7124, CE: 0.1755, Topo: 1.7897
# Epoch 51, Batch 250: Total Loss: 1.0570, CE: 0.2346, Topo: 2.7413
# Epoch 51, Batch 260: Total Loss: 0.5495, CE: 0.1669, Topo: 1.2755
# Epoch 51, Batch 270: Total Loss: 0.3919, CE: 0.0850, Topo: 1.0232
# Epoch 51, Batch 280: Total Loss: 0.2657, CE: 0.1059, Topo: 0.5326
# Epoch 51, Batch 290: Total Loss: 0.4359, CE: 0.1385, Topo: 0.9913
# Epoch 51, Batch 300: Total Loss: 3.6878, CE: 0.5267, Topo: 10.5370
# Epoch 51, Batch 310: Total Loss: 1.0287, CE: 0.3809, Topo: 2.1593
# Epoch 51/100:
#   Train - Total: 0.8151, CE: 0.2030, Topo: 2.0404
#   Val IoU: 0.8353
# Epoch 52, Batch 0: Total Loss: 0.7812, CE: 0.2612, Topo: 1.7335
# Epoch 52, Batch 10: Total Loss: 0.9171, CE: 0.3184, Topo: 1.9957
# Epoch 52, Batch 20: Total Loss: 0.5737, CE: 0.1610, Topo: 1.3756
# Epoch 52, Batch 30: Total Loss: 0.7266, CE: 0.1995, Topo: 1.7570
# Epoch 52, Batch 40: Total Loss: 0.6283, CE: 0.1296, Topo: 1.6623
# Epoch 52, Batch 50: Total Loss: 0.8620, CE: 0.2450, Topo: 2.0567
# Epoch 52, Batch 60: Total Loss: 0.3599, CE: 0.1555, Topo: 0.6814
# Epoch 52, Batch 70: Total Loss: 0.3360, CE: 0.0683, Topo: 0.8924
# Epoch 52, Batch 80: Total Loss: 0.6888, CE: 0.1990, Topo: 1.6327
# Epoch 52, Batch 90: Total Loss: 0.3332, CE: 0.1414, Topo: 0.6392
# Epoch 52, Batch 100: Total Loss: 1.5205, CE: 0.4209, Topo: 3.6651
# Epoch 52, Batch 110: Total Loss: 0.8281, CE: 0.3234, Topo: 1.6824
# Epoch 52, Batch 120: Total Loss: 0.8547, CE: 0.1676, Topo: 2.2905
# Epoch 52, Batch 130: Total Loss: 0.7332, CE: 0.2386, Topo: 1.6487
# Epoch 52, Batch 140: Total Loss: 0.5090, CE: 0.1123, Topo: 1.3222
# Epoch 52, Batch 150: Total Loss: 2.9944, CE: 0.3266, Topo: 8.8926
# Epoch 52, Batch 160: Total Loss: 1.1642, CE: 0.2334, Topo: 3.1027
# Epoch 52, Batch 170: Total Loss: 0.2855, CE: 0.1154, Topo: 0.5671
# Epoch 52, Batch 180: Total Loss: 0.5085, CE: 0.1599, Topo: 1.1618
# Epoch 52, Batch 190: Total Loss: 1.2859, CE: 0.3234, Topo: 3.2084
# Epoch 52, Batch 200: Total Loss: 0.2560, CE: 0.1072, Topo: 0.4962
# Epoch 52, Batch 210: Total Loss: 0.8750, CE: 0.2507, Topo: 2.0809
# Epoch 52, Batch 220: Total Loss: 1.9548, CE: 0.2205, Topo: 5.7809
# Epoch 52, Batch 230: Total Loss: 0.9380, CE: 0.2512, Topo: 2.2893
# Epoch 52, Batch 240: Total Loss: 0.3853, CE: 0.0452, Topo: 1.1336
# Epoch 52, Batch 250: Total Loss: 0.3501, CE: 0.1135, Topo: 0.7885
# Epoch 52, Batch 260: Total Loss: 0.3111, CE: 0.1012, Topo: 0.6997
# Epoch 52, Batch 270: Total Loss: 0.8875, CE: 0.2843, Topo: 2.0107
# Epoch 52, Batch 280: Total Loss: 1.5491, CE: 0.2404, Topo: 4.3624
# Epoch 52, Batch 290: Total Loss: 0.5016, CE: 0.1371, Topo: 1.2150
# Epoch 52, Batch 300: Total Loss: 0.9898, CE: 0.1913, Topo: 2.6617
# Epoch 52, Batch 310: Total Loss: 1.1595, CE: 0.2830, Topo: 2.9216
# Epoch 52/100:
#   Train - Total: 1.0461, CE: 0.2283, Topo: 2.7260
#   Val IoU: 0.8366
# Epoch 53, Batch 0: Total Loss: 0.8345, CE: 0.3462, Topo: 1.6277
# Epoch 53, Batch 10: Total Loss: 2.3694, CE: 0.9349, Topo: 4.7816
# Epoch 53, Batch 20: Total Loss: 0.3462, CE: 0.0483, Topo: 0.9931
# Epoch 53, Batch 30: Total Loss: 0.3585, CE: 0.1277, Topo: 0.7694
# Epoch 53, Batch 40: Total Loss: 0.8211, CE: 0.2328, Topo: 1.9609
# Epoch 53, Batch 50: Total Loss: 3.1359, CE: 0.3961, Topo: 9.1327
# Epoch 53, Batch 60: Total Loss: 0.5713, CE: 0.1347, Topo: 1.4551
# Epoch 53, Batch 70: Total Loss: 0.4842, CE: 0.3040, Topo: 0.6006
# Epoch 53, Batch 80: Total Loss: 0.6803, CE: 0.2393, Topo: 1.4700
# Epoch 53, Batch 90: Total Loss: 0.4330, CE: 0.0955, Topo: 1.1250
# Epoch 53, Batch 100: Total Loss: 0.3610, CE: 0.1498, Topo: 0.7040
# Epoch 53, Batch 110: Total Loss: 0.7150, CE: 0.1901, Topo: 1.7496
# Epoch 53, Batch 120: Total Loss: 0.8607, CE: 0.2536, Topo: 2.0237
# Epoch 53, Batch 130: Total Loss: 1.1619, CE: 0.1772, Topo: 3.2824
# Epoch 53, Batch 140: Total Loss: 0.4924, CE: 0.1900, Topo: 1.0078
# Epoch 53, Batch 150: Total Loss: 0.5428, CE: 0.1118, Topo: 1.4367
# Epoch 53, Batch 160: Total Loss: 0.4125, CE: 0.1238, Topo: 0.9625
# Epoch 53, Batch 170: Total Loss: 4.0098, CE: 0.4384, Topo: 11.9045
# Epoch 53, Batch 180: Total Loss: 0.4843, CE: 0.1235, Topo: 1.2024
# Epoch 53, Batch 190: Total Loss: 0.7977, CE: 0.2743, Topo: 1.7447
# Epoch 53, Batch 200: Total Loss: 0.3900, CE: 0.1883, Topo: 0.6722
# Epoch 53, Batch 210: Total Loss: 0.2124, CE: 0.0771, Topo: 0.4512
# Epoch 53, Batch 220: Total Loss: 0.4847, CE: 0.0958, Topo: 1.2963
# Epoch 53, Batch 230: Total Loss: 0.3148, CE: 0.0864, Topo: 0.7611
# Epoch 53, Batch 240: Total Loss: 0.9086, CE: 0.3187, Topo: 1.9663
# Epoch 53, Batch 250: Total Loss: 0.5442, CE: 0.2481, Topo: 0.9868
# Epoch 53, Batch 260: Total Loss: 0.7521, CE: 0.2675, Topo: 1.6151
# Epoch 53, Batch 270: Total Loss: 0.6822, CE: 0.3749, Topo: 1.0243
# Epoch 53, Batch 280: Total Loss: 0.7829, CE: 0.1603, Topo: 2.0755
# Epoch 53, Batch 290: Total Loss: 0.4135, CE: 0.1393, Topo: 0.9140
# Epoch 53, Batch 300: Total Loss: 0.5256, CE: 0.1875, Topo: 1.1268
# Epoch 53, Batch 310: Total Loss: 0.7461, CE: 0.2550, Topo: 1.6371
# Epoch 53/100:
#   Train - Total: 0.8943, CE: 0.2128, Topo: 2.2715
#   Val IoU: 0.8348
# Epoch 54, Batch 0: Total Loss: 0.7468, CE: 0.2348, Topo: 1.7066
# Epoch 54, Batch 10: Total Loss: 1.0251, CE: 0.1802, Topo: 2.8165
# Epoch 54, Batch 20: Total Loss: 0.6837, CE: 0.2523, Topo: 1.4379
# Epoch 54, Batch 30: Total Loss: 0.4749, CE: 0.1335, Topo: 1.1379
# Epoch 54, Batch 40: Total Loss: 1.3634, CE: 0.4154, Topo: 3.1601
# Epoch 54, Batch 50: Total Loss: 0.4792, CE: 0.1940, Topo: 0.9507
# Epoch 54, Batch 60: Total Loss: 0.8030, CE: 0.1549, Topo: 2.1602
# Epoch 54, Batch 70: Total Loss: 0.4835, CE: 0.0771, Topo: 1.3545
# Epoch 54, Batch 80: Total Loss: 0.1318, CE: 0.0532, Topo: 0.2620
# Epoch 54, Batch 90: Total Loss: 0.2567, CE: 0.1175, Topo: 0.4641
# Epoch 54, Batch 100: Total Loss: 0.4304, CE: 0.1063, Topo: 1.0802
# Epoch 54, Batch 110: Total Loss: 0.9779, CE: 0.2756, Topo: 2.3411
# Epoch 54, Batch 120: Total Loss: 0.5999, CE: 0.1206, Topo: 1.5977
# Epoch 54, Batch 130: Total Loss: 0.2651, CE: 0.0892, Topo: 0.5863
# Epoch 54, Batch 140: Total Loss: 0.3614, CE: 0.1310, Topo: 0.7680
# Epoch 54, Batch 150: Total Loss: 0.3486, CE: 0.0950, Topo: 0.8455
# Epoch 54, Batch 160: Total Loss: 0.4385, CE: 0.0898, Topo: 1.1622
# Epoch 54, Batch 170: Total Loss: 0.5606, CE: 0.1723, Topo: 1.2942
# Epoch 54, Batch 180: Total Loss: 0.4600, CE: 0.1436, Topo: 1.0546
# Epoch 54, Batch 190: Total Loss: 0.2529, CE: 0.0866, Topo: 0.5542
# Epoch 54, Batch 200: Total Loss: 0.2950, CE: 0.1189, Topo: 0.5871
# Epoch 54, Batch 210: Total Loss: 0.7583, CE: 0.1089, Topo: 2.1647
# Epoch 54, Batch 220: Total Loss: 1.2601, CE: 0.2912, Topo: 3.2299
# Epoch 54, Batch 230: Total Loss: 0.9176, CE: 0.2400, Topo: 2.2587
# Epoch 54, Batch 240: Total Loss: 0.6039, CE: 0.1558, Topo: 1.4937
# Epoch 54, Batch 250: Total Loss: 0.7093, CE: 0.1567, Topo: 1.8418
# Epoch 54, Batch 260: Total Loss: 0.2589, CE: 0.0489, Topo: 0.7001
# Epoch 54, Batch 270: Total Loss: 0.9615, CE: 0.3639, Topo: 1.9919
# Epoch 54, Batch 280: Total Loss: 0.4552, CE: 0.1777, Topo: 0.9252
# Epoch 54, Batch 290: Total Loss: 0.3418, CE: 0.1078, Topo: 0.7799
# Epoch 54, Batch 300: Total Loss: 4.0307, CE: 0.7178, Topo: 11.0429
# Epoch 54, Batch 310: Total Loss: 1.1098, CE: 0.3019, Topo: 2.6930
# Epoch 54/100:
#   Train - Total: 0.8161, CE: 0.2091, Topo: 2.0235
#   Val IoU: 0.8361
# Epoch 55, Batch 0: Total Loss: 0.4071, CE: 0.0928, Topo: 1.0475
# Epoch 55, Batch 10: Total Loss: 0.2005, CE: 0.0838, Topo: 0.3889
# Epoch 55, Batch 20: Total Loss: 0.7027, CE: 0.4031, Topo: 0.9988
# Epoch 55, Batch 30: Total Loss: 0.5063, CE: 0.1119, Topo: 1.3145
# Epoch 55, Batch 40: Total Loss: 1.5198, CE: 0.2703, Topo: 4.1648
# Epoch 55, Batch 50: Total Loss: 0.5201, CE: 0.1869, Topo: 1.1107
# Epoch 55, Batch 60: Total Loss: 1.1550, CE: 0.4273, Topo: 2.4256
# Epoch 55, Batch 70: Total Loss: 0.4488, CE: 0.1770, Topo: 0.9060
# Epoch 55, Batch 80: Total Loss: 0.6593, CE: 0.0706, Topo: 1.9623
# Epoch 55, Batch 90: Total Loss: 0.2147, CE: 0.0814, Topo: 0.4442
# Epoch 55, Batch 100: Total Loss: 0.5604, CE: 0.1634, Topo: 1.3232
# Epoch 55, Batch 110: Total Loss: 0.4255, CE: 0.1655, Topo: 0.8665
# Epoch 55, Batch 120: Total Loss: 1.1414, CE: 0.2465, Topo: 2.9827
# Epoch 55, Batch 130: Total Loss: 0.5320, CE: 0.1302, Topo: 1.3395
# Epoch 55, Batch 140: Total Loss: 0.0657, CE: 0.0158, Topo: 0.1663
# Epoch 55, Batch 150: Total Loss: 0.3110, CE: 0.0819, Topo: 0.7636
# Epoch 55, Batch 160: Total Loss: 1.0054, CE: 0.4731, Topo: 1.7742
# Epoch 55, Batch 170: Total Loss: 0.7493, CE: 0.2111, Topo: 1.7942
# Epoch 55, Batch 180: Total Loss: 0.6262, CE: 0.2316, Topo: 1.3153
# Epoch 55, Batch 190: Total Loss: 1.6372, CE: 0.3227, Topo: 4.3819
# Epoch 55, Batch 200: Total Loss: 1.3853, CE: 0.3296, Topo: 3.5188
# Epoch 55, Batch 210: Total Loss: 0.0864, CE: 0.0186, Topo: 0.2260
# Epoch 55, Batch 220: Total Loss: 0.6485, CE: 0.1887, Topo: 1.5325
# Epoch 55, Batch 230: Total Loss: 0.3763, CE: 0.1723, Topo: 0.6800
# Epoch 55, Batch 240: Total Loss: 0.4791, CE: 0.1972, Topo: 0.9394
# Epoch 55, Batch 250: Total Loss: 1.0222, CE: 0.3478, Topo: 2.2481
# Epoch 55, Batch 260: Total Loss: 0.8158, CE: 0.2522, Topo: 1.8787
# Epoch 55, Batch 270: Total Loss: 0.4474, CE: 0.0799, Topo: 1.2251
# Epoch 55, Batch 280: Total Loss: 0.3740, CE: 0.1135, Topo: 0.8683
# Epoch 55, Batch 290: Total Loss: 0.4384, CE: 0.1794, Topo: 0.8633
# Epoch 55, Batch 300: Total Loss: 1.2707, CE: 0.1632, Topo: 3.6915
# Epoch 55, Batch 310: Total Loss: 0.4804, CE: 0.1429, Topo: 1.1250
# Epoch 55/100:
#   Train - Total: 0.8381, CE: 0.2052, Topo: 2.1096
#   Val IoU: 0.8349
# Epoch 56, Batch 0: Total Loss: 0.6623, CE: 0.1196, Topo: 1.8090
# Epoch 56, Batch 10: Total Loss: 0.4248, CE: 0.1343, Topo: 0.9682
# Epoch 56, Batch 20: Total Loss: 0.5064, CE: 0.0904, Topo: 1.3864
# Epoch 56, Batch 30: Total Loss: 0.1533, CE: 0.0426, Topo: 0.3688
# Epoch 56, Batch 40: Total Loss: 0.7678, CE: 0.2631, Topo: 1.6823
# Epoch 56, Batch 50: Total Loss: 1.1379, CE: 0.4820, Topo: 2.1863
# Epoch 56, Batch 60: Total Loss: 0.7831, CE: 0.1056, Topo: 2.2583
# Epoch 56, Batch 70: Total Loss: 0.6909, CE: 0.1345, Topo: 1.8548
# Epoch 56, Batch 80: Total Loss: 0.1593, CE: 0.0558, Topo: 0.3450
# Epoch 56, Batch 90: Total Loss: 0.7733, CE: 0.1048, Topo: 2.2284
# Epoch 56, Batch 100: Total Loss: 0.7283, CE: 0.2648, Topo: 1.5448
# Epoch 56, Batch 110: Total Loss: 0.2145, CE: 0.0937, Topo: 0.4027
# Epoch 56, Batch 120: Total Loss: 0.9396, CE: 0.3591, Topo: 1.9349
# Epoch 56, Batch 130: Total Loss: 0.5816, CE: 0.0973, Topo: 1.6142
# Epoch 56, Batch 140: Total Loss: 0.1229, CE: 0.0454, Topo: 0.2583
# Epoch 56, Batch 150: Total Loss: 0.4214, CE: 0.1668, Topo: 0.8488
# Epoch 56, Batch 160: Total Loss: 1.1651, CE: 0.2376, Topo: 3.0916
# Epoch 56, Batch 170: Total Loss: 0.2630, CE: 0.0511, Topo: 0.7062
# Epoch 56, Batch 180: Total Loss: 0.4234, CE: 0.0717, Topo: 1.1723
# Epoch 56, Batch 190: Total Loss: 0.9230, CE: 0.2818, Topo: 2.1373
# Epoch 56, Batch 200: Total Loss: 1.2443, CE: 0.4934, Topo: 2.5032
# Epoch 56, Batch 210: Total Loss: 1.3466, CE: 0.2704, Topo: 3.5874
# Epoch 56, Batch 220: Total Loss: 0.7030, CE: 0.0819, Topo: 2.0702
# Epoch 56, Batch 230: Total Loss: 0.2153, CE: 0.0813, Topo: 0.4466
# Epoch 56, Batch 240: Total Loss: 0.9236, CE: 0.1638, Topo: 2.5326
# Epoch 56, Batch 250: Total Loss: 0.5285, CE: 0.1622, Topo: 1.2209
# Epoch 56, Batch 260: Total Loss: 1.1458, CE: 0.1140, Topo: 3.4391
# Epoch 56, Batch 270: Total Loss: 0.7638, CE: 0.1937, Topo: 1.9002
# Epoch 56, Batch 280: Total Loss: 0.5550, CE: 0.1700, Topo: 1.2832
# Epoch 56, Batch 290: Total Loss: 1.2416, CE: 0.2689, Topo: 3.2424
# Epoch 56, Batch 300: Total Loss: 0.9364, CE: 0.3197, Topo: 2.0554
# Epoch 56, Batch 310: Total Loss: 0.2081, CE: 0.0672, Topo: 0.4697
# Epoch 56/100:
#   Train - Total: 0.8898, CE: 0.2106, Topo: 2.2638
#   Val IoU: 0.8355
# Epoch 57, Batch 0: Total Loss: 0.4997, CE: 0.1206, Topo: 1.2637
# Epoch 57, Batch 10: Total Loss: 1.0435, CE: 0.2503, Topo: 2.6439
# Epoch 57, Batch 20: Total Loss: 0.2474, CE: 0.0813, Topo: 0.5536
# Epoch 57, Batch 30: Total Loss: 0.3134, CE: 0.2377, Topo: 0.2523
# Epoch 57, Batch 40: Total Loss: 0.3244, CE: 0.0919, Topo: 0.7750
# Epoch 57, Batch 50: Total Loss: 0.8748, CE: 0.3082, Topo: 1.8886
# Epoch 57, Batch 60: Total Loss: 0.2976, CE: 0.1212, Topo: 0.5882
# Epoch 57, Batch 70: Total Loss: 0.2759, CE: 0.0938, Topo: 0.6069
# Epoch 57, Batch 80: Total Loss: 0.2297, CE: 0.0647, Topo: 0.5500
# Epoch 57, Batch 90: Total Loss: 0.5020, CE: 0.0953, Topo: 1.3557
# Epoch 57, Batch 100: Total Loss: 0.3608, CE: 0.1433, Topo: 0.7248
# Epoch 57, Batch 110: Total Loss: 0.9393, CE: 0.1020, Topo: 2.7910
# Epoch 57, Batch 120: Total Loss: 0.1285, CE: 0.1285, Topo: 0.0000
# Epoch 57, Batch 130: Total Loss: 0.5644, CE: 0.1059, Topo: 1.5281
# Epoch 57, Batch 140: Total Loss: 0.5997, CE: 0.1794, Topo: 1.4010
# Epoch 57, Batch 150: Total Loss: 0.2554, CE: 0.0930, Topo: 0.5415
# Epoch 57, Batch 160: Total Loss: 1.1554, CE: 0.0711, Topo: 3.6144
# Epoch 57, Batch 170: Total Loss: 0.5638, CE: 0.2434, Topo: 1.0678
# Epoch 57, Batch 180: Total Loss: 0.6718, CE: 0.2507, Topo: 1.4037
# Epoch 57, Batch 190: Total Loss: 0.9590, CE: 0.6609, Topo: 0.9935
# Epoch 57, Batch 200: Total Loss: 0.4173, CE: 0.1273, Topo: 0.9667
# Epoch 57, Batch 210: Total Loss: 1.4625, CE: 0.2372, Topo: 4.0843
# Epoch 57, Batch 220: Total Loss: 0.5601, CE: 0.1421, Topo: 1.3935
# Epoch 57, Batch 230: Total Loss: 0.7491, CE: 0.2219, Topo: 1.7576
# Epoch 57, Batch 240: Total Loss: 0.8083, CE: 0.1841, Topo: 2.0807
# Epoch 57, Batch 250: Total Loss: 0.5638, CE: 0.2449, Topo: 1.0629
# Epoch 57, Batch 260: Total Loss: 0.2820, CE: 0.0868, Topo: 0.6507
# Epoch 57, Batch 270: Total Loss: 0.8429, CE: 0.1478, Topo: 2.3169
# Epoch 57, Batch 280: Total Loss: 0.5575, CE: 0.2275, Topo: 1.0999
# Epoch 57, Batch 290: Total Loss: 0.6267, CE: 0.0831, Topo: 1.8119
# Epoch 57, Batch 300: Total Loss: 0.3402, CE: 0.1522, Topo: 0.6264
# Epoch 57, Batch 310: Total Loss: 0.8901, CE: 0.2056, Topo: 2.2815
# Epoch 57/100:
#   Train - Total: 0.8465, CE: 0.2112, Topo: 2.1174
#   Val IoU: 0.8362
# Epoch 58, Batch 0: Total Loss: 0.4487, CE: 0.1290, Topo: 1.0658
# Epoch 58, Batch 10: Total Loss: 0.4380, CE: 0.1009, Topo: 1.1236
# Epoch 58, Batch 20: Total Loss: 0.8138, CE: 0.1375, Topo: 2.2542
# Epoch 58, Batch 30: Total Loss: 0.3481, CE: 0.0967, Topo: 0.8380
# Epoch 58, Batch 40: Total Loss: 0.1533, CE: 0.0771, Topo: 0.2539
# Epoch 58, Batch 50: Total Loss: 1.0671, CE: 0.3727, Topo: 2.3149
# Epoch 58, Batch 60: Total Loss: 0.8083, CE: 0.3068, Topo: 1.6717
# Epoch 58, Batch 70: Total Loss: 0.6126, CE: 0.2854, Topo: 1.0909
# Epoch 58, Batch 80: Total Loss: 1.5210, CE: 0.2220, Topo: 4.3302
# Epoch 58, Batch 90: Total Loss: 0.8833, CE: 0.1485, Topo: 2.4492
# Epoch 58, Batch 100: Total Loss: 0.4042, CE: 0.1641, Topo: 0.8005
# Epoch 58, Batch 110: Total Loss: 0.3344, CE: 0.1004, Topo: 0.7801
# Epoch 58, Batch 120: Total Loss: 0.4692, CE: 0.2202, Topo: 0.8301
# Epoch 58, Batch 130: Total Loss: 0.4863, CE: 0.1483, Topo: 1.1266
# Epoch 58, Batch 140: Total Loss: 0.8444, CE: 0.1614, Topo: 2.2767
# Epoch 58, Batch 150: Total Loss: 1.8654, CE: 0.3455, Topo: 5.0664
# Epoch 58, Batch 160: Total Loss: 7.9478, CE: 3.1578, Topo: 15.9667
# Epoch 58, Batch 170: Total Loss: 0.5584, CE: 0.1489, Topo: 1.3650
# Epoch 58, Batch 180: Total Loss: 0.7910, CE: 0.2642, Topo: 1.7560
# Epoch 58, Batch 190: Total Loss: 0.5300, CE: 0.1974, Topo: 1.1085
# Epoch 58, Batch 200: Total Loss: 0.5003, CE: 0.2074, Topo: 0.9763
# Epoch 58, Batch 210: Total Loss: 0.2180, CE: 0.0620, Topo: 0.5199
# Epoch 58, Batch 220: Total Loss: 0.3041, CE: 0.0962, Topo: 0.6928
# Epoch 58, Batch 230: Total Loss: 0.2459, CE: 0.0895, Topo: 0.5214
# Epoch 58, Batch 240: Total Loss: 0.7043, CE: 0.3585, Topo: 1.1526
# Epoch 58, Batch 250: Total Loss: 0.7018, CE: 0.2007, Topo: 1.6705
# Epoch 58, Batch 260: Total Loss: 0.5593, CE: 0.1492, Topo: 1.3667
# Epoch 58, Batch 270: Total Loss: 0.4363, CE: 0.1323, Topo: 1.0134
# Epoch 58, Batch 280: Total Loss: 0.3036, CE: 0.0746, Topo: 0.7632
# Epoch 58, Batch 290: Total Loss: 1.9851, CE: 0.3706, Topo: 5.3816
# Epoch 58, Batch 300: Total Loss: 0.7985, CE: 0.1509, Topo: 2.1586
# Epoch 58, Batch 310: Total Loss: 2.9638, CE: 0.2434, Topo: 9.0680
# Epoch 58/100:
#   Train - Total: 0.8003, CE: 0.2067, Topo: 1.9788
#   Val IoU: 0.8368
# Epoch 59, Batch 0: Total Loss: 0.9296, CE: 0.2553, Topo: 2.2477
# Epoch 59, Batch 10: Total Loss: 1.0951, CE: 0.3905, Topo: 2.3485
# Epoch 59, Batch 20: Total Loss: 0.4380, CE: 0.1448, Topo: 0.9773
# Epoch 59, Batch 30: Total Loss: 0.5853, CE: 0.2574, Topo: 1.0928
# Epoch 59, Batch 40: Total Loss: 1.0956, CE: 0.2093, Topo: 2.9542
# Epoch 59, Batch 50: Total Loss: 0.3001, CE: 0.0670, Topo: 0.7769
# Epoch 59, Batch 60: Total Loss: 0.4199, CE: 0.1143, Topo: 1.0187
# Epoch 59, Batch 70: Total Loss: 0.4378, CE: 0.1340, Topo: 1.0126
# Epoch 59, Batch 80: Total Loss: 0.3060, CE: 0.0666, Topo: 0.7982
# Epoch 59, Batch 90: Total Loss: 1.0204, CE: 0.2868, Topo: 2.4452
# Epoch 59, Batch 100: Total Loss: 0.4947, CE: 0.2205, Topo: 0.9139
# Epoch 59, Batch 110: Total Loss: 1.0976, CE: 0.2271, Topo: 2.9014
# Epoch 59, Batch 120: Total Loss: 0.9076, CE: 0.3397, Topo: 1.8933
# Epoch 59, Batch 130: Total Loss: 1.0359, CE: 0.1860, Topo: 2.8328
# Epoch 59, Batch 140: Total Loss: 0.8052, CE: 0.1370, Topo: 2.2273
# Epoch 59, Batch 150: Total Loss: 0.3590, CE: 0.1066, Topo: 0.8411
# Epoch 59, Batch 160: Total Loss: 2.2366, CE: 0.2650, Topo: 6.5719
# Epoch 59, Batch 170: Total Loss: 1.0332, CE: 0.2968, Topo: 2.4546
# Epoch 59, Batch 180: Total Loss: 0.5904, CE: 0.1667, Topo: 1.4122
# Epoch 59, Batch 190: Total Loss: 0.5384, CE: 0.2182, Topo: 1.0673
# Epoch 59, Batch 200: Total Loss: 0.4267, CE: 0.1978, Topo: 0.7628
# Epoch 59, Batch 210: Total Loss: 0.4217, CE: 0.1426, Topo: 0.9303
# Epoch 59, Batch 220: Total Loss: 0.3684, CE: 0.1185, Topo: 0.8328
# Epoch 59, Batch 230: Total Loss: 1.4610, CE: 0.3571, Topo: 3.6796
# Epoch 59, Batch 240: Total Loss: 0.9174, CE: 0.1731, Topo: 2.4809
# Epoch 59, Batch 250: Total Loss: 0.3283, CE: 0.0808, Topo: 0.8249
# Epoch 59, Batch 260: Total Loss: 0.8579, CE: 0.1372, Topo: 2.4025
# Epoch 59, Batch 270: Total Loss: 0.4657, CE: 0.1094, Topo: 1.1878
# Epoch 59, Batch 280: Total Loss: 1.0930, CE: 0.2433, Topo: 2.8321
# Epoch 59, Batch 290: Total Loss: 0.6420, CE: 0.1331, Topo: 1.6965
# Epoch 59, Batch 300: Total Loss: 0.5806, CE: 0.1370, Topo: 1.4787
# Epoch 59, Batch 310: Total Loss: 0.7652, CE: 0.1949, Topo: 1.9010
# Epoch 59/100:
#   Train - Total: 0.8557, CE: 0.2013, Topo: 2.1813
#   Val IoU: 0.8386
# Epoch 60, Batch 0: Total Loss: 0.3099, CE: 0.0779, Topo: 0.7732
# Epoch 60, Batch 10: Total Loss: 0.3335, CE: 0.0932, Topo: 0.8009
# Epoch 60, Batch 20: Total Loss: 0.2563, CE: 0.1470, Topo: 0.3646
# Epoch 60, Batch 30: Total Loss: 0.2827, CE: 0.0621, Topo: 0.7352
# Epoch 60, Batch 40: Total Loss: 0.4086, CE: 0.1236, Topo: 0.9502
# Epoch 60, Batch 50: Total Loss: 0.7203, CE: 0.1937, Topo: 1.7555
# Epoch 60, Batch 60: Total Loss: 0.1151, CE: 0.0496, Topo: 0.2181
# Epoch 60, Batch 70: Total Loss: 0.6768, CE: 0.1246, Topo: 1.8409
# Epoch 60, Batch 80: Total Loss: 0.4318, CE: 0.0791, Topo: 1.1754
# Epoch 60, Batch 90: Total Loss: 0.4351, CE: 0.1746, Topo: 0.8685
# Epoch 60, Batch 100: Total Loss: 0.3798, CE: 0.0923, Topo: 0.9582
# Epoch 60, Batch 110: Total Loss: 0.4703, CE: 0.1133, Topo: 1.1901
# Epoch 60, Batch 120: Total Loss: 0.3900, CE: 0.1354, Topo: 0.8486
# Epoch 60, Batch 130: Total Loss: 0.8034, CE: 0.2798, Topo: 1.7454
# Epoch 60, Batch 140: Total Loss: 1.4592, CE: 0.2217, Topo: 4.1249
# Epoch 60, Batch 150: Total Loss: 0.7303, CE: 0.2492, Topo: 1.6034
# Epoch 60, Batch 160: Total Loss: 0.3368, CE: 0.0774, Topo: 0.8648
# Epoch 60, Batch 170: Total Loss: 0.4481, CE: 0.0487, Topo: 1.3315
# Epoch 60, Batch 180: Total Loss: 0.8773, CE: 0.3384, Topo: 1.7961
# Epoch 60, Batch 190: Total Loss: 1.0637, CE: 0.1388, Topo: 3.0829
# Epoch 60, Batch 200: Total Loss: 1.1701, CE: 0.1807, Topo: 3.2980
# Epoch 60, Batch 210: Total Loss: 0.4835, CE: 0.1414, Topo: 1.1403
# Epoch 60, Batch 220: Total Loss: 0.2069, CE: 0.0743, Topo: 0.4421
# Epoch 60, Batch 230: Total Loss: 0.3606, CE: 0.0736, Topo: 0.9566
# Epoch 60, Batch 240: Total Loss: 0.8001, CE: 0.1410, Topo: 2.1970
# Epoch 60, Batch 250: Total Loss: 0.4083, CE: 0.1167, Topo: 0.9721
# Epoch 60, Batch 260: Total Loss: 0.7184, CE: 0.1489, Topo: 1.8982
# Epoch 60, Batch 270: Total Loss: 1.7784, CE: 0.2160, Topo: 5.2079
# Epoch 60, Batch 280: Total Loss: 1.5393, CE: 0.2991, Topo: 4.1340
# Epoch 60, Batch 290: Total Loss: 0.5396, CE: 0.1724, Topo: 1.2239
# Epoch 60, Batch 300: Total Loss: 0.6689, CE: 0.1221, Topo: 1.8228
# Epoch 60, Batch 310: Total Loss: 0.2338, CE: 0.0682, Topo: 0.5520
# Epoch 60/100:
#   Train - Total: 0.8874, CE: 0.2103, Topo: 2.2567
#   Val IoU: 0.8332
# Epoch 61, Batch 0: Total Loss: 0.8827, CE: 0.2069, Topo: 2.2527
# Epoch 61, Batch 10: Total Loss: 0.5410, CE: 0.2421, Topo: 0.9963
# Epoch 61, Batch 20: Total Loss: 0.0915, CE: 0.0299, Topo: 0.2054
# Epoch 61, Batch 30: Total Loss: 0.6227, CE: 0.1620, Topo: 1.5357
# Epoch 61, Batch 40: Total Loss: 0.3917, CE: 0.1522, Topo: 0.7982
# Epoch 61, Batch 50: Total Loss: 1.6529, CE: 0.4304, Topo: 4.0749
# Epoch 61, Batch 60: Total Loss: 0.1974, CE: 0.0857, Topo: 0.3723
# Epoch 61, Batch 70: Total Loss: 0.4127, CE: 0.0853, Topo: 1.0916
# Epoch 61, Batch 80: Total Loss: 0.8436, CE: 0.2195, Topo: 2.0804
# Epoch 61, Batch 90: Total Loss: 0.4992, CE: 0.1793, Topo: 1.0664
# Epoch 61, Batch 100: Total Loss: 0.4573, CE: 0.0957, Topo: 1.2052
# Epoch 61, Batch 110: Total Loss: 0.4867, CE: 0.1429, Topo: 1.1462
# Epoch 61, Batch 120: Total Loss: 0.3735, CE: 0.1204, Topo: 0.8439
# Epoch 61, Batch 130: Total Loss: 0.4296, CE: 0.0974, Topo: 1.1073
# Epoch 61, Batch 140: Total Loss: 0.4964, CE: 0.0852, Topo: 1.3705
# Epoch 61, Batch 150: Total Loss: 0.1035, CE: 0.1035, Topo: 0.0000
# Epoch 61, Batch 160: Total Loss: 0.4445, CE: 0.1804, Topo: 0.8804
# Epoch 61, Batch 170: Total Loss: 0.6350, CE: 0.1456, Topo: 1.6313
# Epoch 61, Batch 180: Total Loss: 1.4786, CE: 0.1468, Topo: 4.4394
# Epoch 61, Batch 190: Total Loss: 0.7398, CE: 0.2188, Topo: 1.7367
# Epoch 61, Batch 200: Total Loss: 0.5270, CE: 0.1107, Topo: 1.3876
# Epoch 61, Batch 210: Total Loss: 1.0000, CE: 0.2704, Topo: 2.4321
# Epoch 61, Batch 220: Total Loss: 0.2143, CE: 0.0203, Topo: 0.6469
# Epoch 61, Batch 230: Total Loss: 0.6469, CE: 0.0727, Topo: 1.9141
# Epoch 61, Batch 240: Total Loss: 0.9102, CE: 0.4083, Topo: 1.6730
# Epoch 61, Batch 250: Total Loss: 0.3391, CE: 0.1172, Topo: 0.7396
# Epoch 61, Batch 260: Total Loss: 0.6664, CE: 0.2653, Topo: 1.3371
# Epoch 61, Batch 270: Total Loss: 0.3380, CE: 0.0880, Topo: 0.8335
# Epoch 61, Batch 280: Total Loss: 0.3133, CE: 0.1646, Topo: 0.4957
# Epoch 61, Batch 290: Total Loss: 0.2374, CE: 0.0779, Topo: 0.5320
# Epoch 61, Batch 300: Total Loss: 0.1768, CE: 0.0418, Topo: 0.4502
# Epoch 61, Batch 310: Total Loss: 0.8075, CE: 0.1498, Topo: 2.1927
# Epoch 61/100:
#   Train - Total: 0.7435, CE: 0.1853, Topo: 1.8607
#   Val IoU: 0.8360
# 🔄 Unfrozen all encoder layers
# Epoch 62, Batch 0: Total Loss: 0.7843, CE: 0.3043, Topo: 1.5999
# Epoch 62, Batch 10: Total Loss: 0.7311, CE: 0.1598, Topo: 1.9042
# Epoch 62, Batch 20: Total Loss: 3.0043, CE: 1.1576, Topo: 6.1555
# Epoch 62, Batch 30: Total Loss: 5.1290, CE: 2.7120, Topo: 8.0568
# Epoch 62, Batch 40: Total Loss: 6.2831, CE: 2.1989, Topo: 13.6142
# Epoch 62, Batch 50: Total Loss: 1.7337, CE: 0.5849, Topo: 3.8294
# Epoch 62, Batch 60: Total Loss: 4.7218, CE: 0.6478, Topo: 13.5799
# Epoch 62, Batch 70: Total Loss: 1.1992, CE: 0.4761, Topo: 2.4102
# Epoch 62, Batch 80: Total Loss: 2.2569, CE: 0.4875, Topo: 5.8981
# ...
# Epoch 93, Batch 250: Total Loss: 0.3031, CE: 0.0972, Topo: 0.6862
# Epoch 93, Batch 260: Total Loss: 0.2486, CE: 0.0712, Topo: 0.5912
# Epoch 93, Batch 270: Total Loss: 0.4290, CE: 0.1199, Topo: 1.0305
# Epoch 93, Batch 280: Total Loss: 0.1101, CE: 0.0301, Topo: 0.2668
# Epoch 93, Batch 290: Total Loss: 2.6116, CE: 0.2150, Topo: 7.9888
# Epoch 93, Batch 300: Total Loss: 0.1452, CE: 0.0543, Topo: 0.3029
# Epoch 93, Batch 310: Total Loss: 0.1663, CE: 0.0493, Topo: 0.3900
# Epoch 93/100:
#   Train - Total: 0.6529, CE: 0.1273, Topo: 1.7518
#   Val IoU: 0.8867
# Epoch 94, Batch 0: Total Loss: 0.1772, CE: 0.0458, Topo: 0.4382
# Epoch 94, Batch 10: Total Loss: 0.4302, CE: 0.0815, Topo: 1.1622
# Epoch 94, Batch 20: Total Loss: 0.1934, CE: 0.0474, Topo: 0.4866
# Epoch 94, Batch 30: Total Loss: 0.4430, CE: 0.1399, Topo: 1.0104
# Epoch 94, Batch 40: Total Loss: 0.1904, CE: 0.0401, Topo: 0.5010
# Epoch 94, Batch 50: Total Loss: 0.4632, CE: 0.1821, Topo: 0.9372
# Epoch 94, Batch 60: Total Loss: 0.3429, CE: 0.1260, Topo: 0.7230
# Epoch 94, Batch 70: Total Loss: 0.2113, CE: 0.0920, Topo: 0.3974
# Epoch 94, Batch 80: Total Loss: 0.3821, CE: 0.1263, Topo: 0.8527
# Epoch 94, Batch 90: Total Loss: 0.3907, CE: 0.0602, Topo: 1.1018
# Epoch 94, Batch 100: Total Loss: 0.4360, CE: 0.1507, Topo: 0.9512
# Epoch 94, Batch 110: Total Loss: 0.3329, CE: 0.0512, Topo: 0.9391
# Epoch 94, Batch 120: Total Loss: 0.2365, CE: 0.0919, Topo: 0.4821
# Epoch 94, Batch 130: Total Loss: 0.6140, CE: 0.3324, Topo: 0.9388
# Epoch 94, Batch 140: Total Loss: 0.2458, CE: 0.0327, Topo: 0.7101
# Epoch 94, Batch 150: Total Loss: 0.5910, CE: 0.0909, Topo: 1.6669
# Epoch 94, Batch 160: Total Loss: 0.6159, CE: 0.1180, Topo: 1.6597
# Epoch 94, Batch 170: Total Loss: 0.3862, CE: 0.1527, Topo: 0.7782
# Epoch 94, Batch 180: Total Loss: 0.4370, CE: 0.1027, Topo: 1.1144
# Epoch 94, Batch 190: Total Loss: 0.7678, CE: 0.1788, Topo: 1.9632
# Epoch 94, Batch 200: Total Loss: 0.3499, CE: 0.1381, Topo: 0.7060
# Epoch 94, Batch 210: Total Loss: 0.5381, CE: 0.1689, Topo: 1.2307
# Epoch 94, Batch 220: Total Loss: 0.3750, CE: 0.0946, Topo: 0.9346
# Epoch 94, Batch 230: Total Loss: 0.1647, CE: 0.0614, Topo: 0.3443
# Epoch 94, Batch 240: Total Loss: 0.1437, CE: 0.0343, Topo: 0.3648
# Epoch 94, Batch 250: Total Loss: 0.2282, CE: 0.0802, Topo: 0.4934
# Epoch 94, Batch 260: Total Loss: 0.1896, CE: 0.0578, Topo: 0.4393
# Epoch 94, Batch 270: Total Loss: 0.8788, CE: 0.2977, Topo: 1.9370
# Epoch 94, Batch 280: Total Loss: 0.4945, CE: 0.1125, Topo: 1.2733
# Epoch 94, Batch 290: Total Loss: 0.4910, CE: 0.1658, Topo: 1.0839
# Epoch 94, Batch 300: Total Loss: 0.3544, CE: 0.1098, Topo: 0.8151
# Epoch 94, Batch 310: Total Loss: 0.1504, CE: 0.0636, Topo: 0.2892
# Epoch 94/100:
#   Train - Total: 0.5708, CE: 0.1343, Topo: 1.4549
#   Val IoU: 0.8889
# Epoch 95, Batch 0: Total Loss: 0.4429, CE: 0.1640, Topo: 0.9296
# Epoch 95, Batch 10: Total Loss: 0.4918, CE: 0.1211, Topo: 1.2354
# Epoch 95, Batch 20: Total Loss: 0.2885, CE: 0.0525, Topo: 0.7867
# Epoch 95, Batch 30: Total Loss: 0.2156, CE: 0.0534, Topo: 0.5407
# Epoch 95, Batch 40: Total Loss: 0.3617, CE: 0.2023, Topo: 0.5315
# Epoch 95, Batch 50: Total Loss: 0.2079, CE: 0.0667, Topo: 0.4704
# Epoch 95, Batch 60: Total Loss: 0.5398, CE: 0.1667, Topo: 1.2436
# Epoch 95, Batch 70: Total Loss: 0.3968, CE: 0.0943, Topo: 1.0083
# Epoch 95, Batch 80: Total Loss: 0.2381, CE: 0.0746, Topo: 0.5450
# Epoch 95, Batch 90: Total Loss: 0.2975, CE: 0.1057, Topo: 0.6391
# Epoch 95, Batch 100: Total Loss: 0.6957, CE: 0.0753, Topo: 2.0680
# Epoch 95, Batch 110: Total Loss: 1.5178, CE: 0.2649, Topo: 4.1763
# Epoch 95, Batch 120: Total Loss: 0.2358, CE: 0.0870, Topo: 0.4960
# Epoch 95, Batch 130: Total Loss: 0.7464, CE: 0.3121, Topo: 1.4478
# Epoch 95, Batch 140: Total Loss: 0.3325, CE: 0.0714, Topo: 0.8704
# Epoch 95, Batch 150: Total Loss: 1.0736, CE: 0.1553, Topo: 3.0609
# Epoch 95, Batch 160: Total Loss: 0.1890, CE: 0.0690, Topo: 0.3999
# Epoch 95, Batch 170: Total Loss: 0.1054, CE: 0.0392, Topo: 0.2207
# Epoch 95, Batch 180: Total Loss: 0.3729, CE: 0.1102, Topo: 0.8755
# Epoch 95, Batch 190: Total Loss: 0.5628, CE: 0.1020, Topo: 1.5363
# Epoch 95, Batch 200: Total Loss: 0.1951, CE: 0.0393, Topo: 0.5196
# Epoch 95, Batch 210: Total Loss: 0.2151, CE: 0.0676, Topo: 0.4918
# Epoch 95, Batch 220: Total Loss: 0.2198, CE: 0.0889, Topo: 0.4364
# Epoch 95, Batch 230: Total Loss: 0.1305, CE: 0.0592, Topo: 0.2376
# Epoch 95, Batch 240: Total Loss: 0.3642, CE: 0.1652, Topo: 0.6631
# Epoch 95, Batch 250: Total Loss: 0.1740, CE: 0.0752, Topo: 0.3293
# Epoch 95, Batch 260: Total Loss: 0.2203, CE: 0.0461, Topo: 0.5808
# Epoch 95, Batch 270: Total Loss: 1.3293, CE: 0.2436, Topo: 3.6190
# Epoch 95, Batch 280: Total Loss: 0.2035, CE: 0.0668, Topo: 0.4556
# Epoch 95, Batch 290: Total Loss: 0.2731, CE: 0.0741, Topo: 0.6632
# Epoch 95, Batch 300: Total Loss: 1.1356, CE: 0.2504, Topo: 2.9508
# Epoch 95, Batch 310: Total Loss: 0.3623, CE: 0.1093, Topo: 0.8433
# Epoch 95/100:
#   Train - Total: 0.5527, CE: 0.1256, Topo: 1.4237
#   Val IoU: 0.8859
# Epoch 96, Batch 0: Total Loss: 0.4738, CE: 0.1414, Topo: 1.1079
# Epoch 96, Batch 10: Total Loss: 0.4203, CE: 0.0962, Topo: 1.0805
# Epoch 96, Batch 20: Total Loss: 0.1630, CE: 0.0545, Topo: 0.3620
# Epoch 96, Batch 30: Total Loss: 0.1297, CE: 0.0333, Topo: 0.3216
# Epoch 96, Batch 40: Total Loss: 0.4964, CE: 0.1236, Topo: 1.2427
# Epoch 96, Batch 50: Total Loss: 0.4197, CE: 0.1162, Topo: 1.0115
# Epoch 96, Batch 60: Total Loss: 0.4846, CE: 0.1098, Topo: 1.2495
# Epoch 96, Batch 70: Total Loss: 0.1474, CE: 0.0454, Topo: 0.3399
# Epoch 96, Batch 80: Total Loss: 0.6283, CE: 0.1730, Topo: 1.5176
# Epoch 96, Batch 90: Total Loss: 0.0695, CE: 0.0122, Topo: 0.1909
# Epoch 96, Batch 100: Total Loss: 2.0170, CE: 0.2342, Topo: 5.9429
# Epoch 96, Batch 110: Total Loss: 1.8085, CE: 0.2679, Topo: 5.1352
# Epoch 96, Batch 120: Total Loss: 0.4691, CE: 0.0870, Topo: 1.2738
# Epoch 96, Batch 130: Total Loss: 3.6583, CE: 0.2044, Topo: 11.5131
# Epoch 96, Batch 140: Total Loss: 0.4097, CE: 0.1401, Topo: 0.8985
# Epoch 96, Batch 150: Total Loss: 0.2563, CE: 0.0681, Topo: 0.6271
# Epoch 96, Batch 160: Total Loss: 2.4988, CE: 0.6757, Topo: 6.0772
# Epoch 96, Batch 170: Total Loss: 0.5358, CE: 0.0786, Topo: 1.5242
# Epoch 96, Batch 180: Total Loss: 0.4198, CE: 0.0792, Topo: 1.1353
# Epoch 96, Batch 190: Total Loss: 0.4409, CE: 0.0702, Topo: 1.2356
# Epoch 96, Batch 200: Total Loss: 0.0548, CE: 0.0277, Topo: 0.0904
# Epoch 96, Batch 210: Total Loss: 0.5489, CE: 0.1512, Topo: 1.3257
# Epoch 96, Batch 220: Total Loss: 0.4704, CE: 0.1533, Topo: 1.0569
# Epoch 96, Batch 230: Total Loss: 0.6353, CE: 0.1691, Topo: 1.5540
# Epoch 96, Batch 240: Total Loss: 0.4200, CE: 0.1684, Topo: 0.8384
# Epoch 96, Batch 250: Total Loss: 0.7581, CE: 0.1821, Topo: 1.9201
# Epoch 96, Batch 260: Total Loss: 0.4949, CE: 0.1452, Topo: 1.1654
# Epoch 96, Batch 270: Total Loss: 0.2260, CE: 0.0525, Topo: 0.5783
# Epoch 96, Batch 280: Total Loss: 0.0808, CE: 0.0239, Topo: 0.1899
# Epoch 96, Batch 290: Total Loss: 0.2573, CE: 0.0501, Topo: 0.6907
# Epoch 96, Batch 300: Total Loss: 0.0537, CE: 0.0089, Topo: 0.1494
# Epoch 96, Batch 310: Total Loss: 0.1618, CE: 0.0809, Topo: 0.2699
# Epoch 96/100:
#   Train - Total: 0.5752, CE: 0.1215, Topo: 1.5125
#   Val IoU: 0.8864
# Epoch 97, Batch 0: Total Loss: 0.4122, CE: 0.0590, Topo: 1.1773
# Epoch 97, Batch 10: Total Loss: 0.3245, CE: 0.1109, Topo: 0.7118
# Epoch 97, Batch 20: Total Loss: 0.2603, CE: 0.1145, Topo: 0.4860
# Epoch 97, Batch 30: Total Loss: 0.2686, CE: 0.0755, Topo: 0.6437
# Epoch 97, Batch 40: Total Loss: 0.8702, CE: 0.1684, Topo: 2.3394
# Epoch 97, Batch 50: Total Loss: 0.2274, CE: 0.1031, Topo: 0.4143
# Epoch 97, Batch 60: Total Loss: 2.6007, CE: 0.3876, Topo: 7.3771
# Epoch 97, Batch 70: Total Loss: 0.8781, CE: 0.1524, Topo: 2.4188
# Epoch 97, Batch 80: Total Loss: 0.7488, CE: 0.1625, Topo: 1.9541
# Epoch 97, Batch 90: Total Loss: 0.1205, CE: 0.0594, Topo: 0.2038
# Epoch 97, Batch 100: Total Loss: 0.9270, CE: 0.0934, Topo: 2.7785
# Epoch 97, Batch 110: Total Loss: 0.1357, CE: 0.0478, Topo: 0.2928
# Epoch 97, Batch 120: Total Loss: 0.1748, CE: 0.0575, Topo: 0.3911
# Epoch 97, Batch 130: Total Loss: 0.6259, CE: 0.1200, Topo: 1.6864
# Epoch 97, Batch 140: Total Loss: 0.4624, CE: 0.0543, Topo: 1.3605
# Epoch 97, Batch 150: Total Loss: 0.3713, CE: 0.0579, Topo: 1.0448
# Epoch 97, Batch 160: Total Loss: 0.6559, CE: 0.1007, Topo: 1.8506
# Epoch 97, Batch 170: Total Loss: 0.5448, CE: 0.1262, Topo: 1.3953
# Epoch 97, Batch 180: Total Loss: 2.0440, CE: 0.2384, Topo: 6.0186
# Epoch 97, Batch 190: Total Loss: 0.7283, CE: 0.2533, Topo: 1.5831
# Epoch 97, Batch 200: Total Loss: 0.4322, CE: 0.0884, Topo: 1.1458
# Epoch 97, Batch 210: Total Loss: 0.1496, CE: 0.0579, Topo: 0.3056
# Epoch 97, Batch 220: Total Loss: 0.4553, CE: 0.1033, Topo: 1.1734
# Epoch 97, Batch 230: Total Loss: 0.1795, CE: 0.0482, Topo: 0.4375
# Epoch 97, Batch 240: Total Loss: 0.4341, CE: 0.1285, Topo: 1.0186
# Epoch 97, Batch 250: Total Loss: 0.2076, CE: 0.0582, Topo: 0.4981
# Epoch 97, Batch 260: Total Loss: 0.1124, CE: 0.0639, Topo: 0.1617
# Epoch 97, Batch 270: Total Loss: 1.3993, CE: 0.2845, Topo: 3.7163
# Epoch 97, Batch 280: Total Loss: 0.3920, CE: 0.1171, Topo: 0.9163
# Epoch 97, Batch 290: Total Loss: 3.3327, CE: 1.0462, Topo: 7.6217
# Epoch 97, Batch 300: Total Loss: 0.9524, CE: 0.1199, Topo: 2.7748
# Epoch 97, Batch 310: Total Loss: 0.7231, CE: 0.1930, Topo: 1.7672
# Epoch 97/100:
#   Train - Total: 0.6099, CE: 0.1285, Topo: 1.6047
#   Val IoU: 0.8910
# Epoch 98, Batch 0: Total Loss: 0.2972, CE: 0.0995, Topo: 0.6590
# Epoch 98, Batch 10: Total Loss: 3.6258, CE: 0.3361, Topo: 10.9656
# Epoch 98, Batch 20: Total Loss: 0.3281, CE: 0.1422, Topo: 0.6196
# Epoch 98, Batch 30: Total Loss: 0.2880, CE: 0.1069, Topo: 0.6037
# Epoch 98, Batch 40: Total Loss: 0.2532, CE: 0.0462, Topo: 0.6901
# Epoch 98, Batch 50: Total Loss: 0.3315, CE: 0.1652, Topo: 0.5542
# Epoch 98, Batch 60: Total Loss: 0.7216, CE: 0.2723, Topo: 1.4975
# Epoch 98, Batch 70: Total Loss: 0.3825, CE: 0.0541, Topo: 1.0946
# Epoch 98, Batch 80: Total Loss: 0.6777, CE: 0.1049, Topo: 1.9091
# Epoch 98, Batch 90: Total Loss: 0.7998, CE: 0.1005, Topo: 2.3308
# Epoch 98, Batch 100: Total Loss: 0.1734, CE: 0.0699, Topo: 0.3449
# Epoch 98, Batch 110: Total Loss: 0.5907, CE: 0.1636, Topo: 1.4238
# Epoch 98, Batch 120: Total Loss: 3.1221, CE: 0.4320, Topo: 8.9670
# Epoch 98, Batch 130: Total Loss: 0.4515, CE: 0.1524, Topo: 0.9969
# Epoch 98, Batch 140: Total Loss: 0.2208, CE: 0.0805, Topo: 0.4678
# Epoch 98, Batch 150: Total Loss: 0.3313, CE: 0.1160, Topo: 0.7177
# Epoch 98, Batch 160: Total Loss: 0.4970, CE: 0.1372, Topo: 1.1993
# Epoch 98, Batch 170: Total Loss: 0.4327, CE: 0.1657, Topo: 0.8900
# Epoch 98, Batch 180: Total Loss: 0.5631, CE: 0.0957, Topo: 1.5580
# Epoch 98, Batch 190: Total Loss: 0.4456, CE: 0.1117, Topo: 1.1130
# Epoch 98, Batch 200: Total Loss: 5.0252, CE: 0.2026, Topo: 16.0755
# Epoch 98, Batch 210: Total Loss: 0.5061, CE: 0.1107, Topo: 1.3180
# Epoch 98, Batch 220: Total Loss: 0.2255, CE: 0.0675, Topo: 0.5265
# Epoch 98, Batch 230: Total Loss: 0.0745, CE: 0.0276, Topo: 0.1564
# Epoch 98, Batch 240: Total Loss: 0.2763, CE: 0.0766, Topo: 0.6656
# Epoch 98, Batch 250: Total Loss: 0.3009, CE: 0.0781, Topo: 0.7428
# Epoch 98, Batch 260: Total Loss: 0.0593, CE: 0.0161, Topo: 0.1442
# Epoch 98, Batch 270: Total Loss: 2.6026, CE: 0.1980, Topo: 8.0155
# Epoch 98, Batch 280: Total Loss: 0.4559, CE: 0.1219, Topo: 1.1132
# Epoch 98, Batch 290: Total Loss: 0.1746, CE: 0.0972, Topo: 0.2579
# Epoch 98, Batch 300: Total Loss: 0.4678, CE: 0.0888, Topo: 1.2634
# Epoch 98, Batch 310: Total Loss: 0.1169, CE: 0.0278, Topo: 0.2972
# Epoch 98/100:
#   Train - Total: 0.8212, CE: 0.1363, Topo: 2.2828
#   Val IoU: 0.8917
# Epoch 99, Batch 0: Total Loss: 0.7059, CE: 0.2285, Topo: 1.5913
# Epoch 99, Batch 10: Total Loss: 0.3499, CE: 0.1195, Topo: 0.7679
# Epoch 99, Batch 20: Total Loss: 0.2452, CE: 0.0478, Topo: 0.6578
# Epoch 99, Batch 30: Total Loss: 0.3447, CE: 0.0939, Topo: 0.8359
# Epoch 99, Batch 40: Total Loss: 0.3258, CE: 0.0777, Topo: 0.8271
# Epoch 99, Batch 50: Total Loss: 0.1406, CE: 0.0694, Topo: 0.2372
# Epoch 99, Batch 60: Total Loss: 0.4646, CE: 0.1208, Topo: 1.1461
# Epoch 99, Batch 70: Total Loss: 0.2389, CE: 0.0759, Topo: 0.5435
# Epoch 99, Batch 80: Total Loss: 0.2525, CE: 0.0631, Topo: 0.6312
# Epoch 99, Batch 90: Total Loss: 0.3971, CE: 0.1388, Topo: 0.8613
# Epoch 99, Batch 100: Total Loss: 0.3794, CE: 0.1307, Topo: 0.8291
# Epoch 99, Batch 110: Total Loss: 0.2256, CE: 0.0544, Topo: 0.5706
# Epoch 99, Batch 120: Total Loss: 0.3590, CE: 0.1114, Topo: 0.8254
# Epoch 99, Batch 130: Total Loss: 0.2465, CE: 0.0880, Topo: 0.5284
# Epoch 99, Batch 140: Total Loss: 0.3217, CE: 0.1719, Topo: 0.4991
# Epoch 99, Batch 150: Total Loss: 0.5048, CE: 0.1811, Topo: 1.0788
# Epoch 99, Batch 160: Total Loss: 0.7866, CE: 0.1550, Topo: 2.1054
# Epoch 99, Batch 170: Total Loss: 0.8362, CE: 0.1637, Topo: 2.2418
# Epoch 99, Batch 180: Total Loss: 0.2762, CE: 0.0632, Topo: 0.7098
# Epoch 99, Batch 190: Total Loss: 0.5166, CE: 0.0977, Topo: 1.3963
# Epoch 99, Batch 200: Total Loss: 1.8107, CE: 0.2323, Topo: 5.2612
# Epoch 99, Batch 210: Total Loss: 0.2303, CE: 0.0500, Topo: 0.6013
# Epoch 99, Batch 220: Total Loss: 0.1983, CE: 0.0582, Topo: 0.4668
# Epoch 99, Batch 230: Total Loss: 0.2644, CE: 0.1139, Topo: 0.5016
# Epoch 99, Batch 240: Total Loss: 0.3558, CE: 0.1108, Topo: 0.8165
# Epoch 99, Batch 250: Total Loss: 0.6703, CE: 0.1782, Topo: 1.6404
# Epoch 99, Batch 260: Total Loss: 0.1736, CE: 0.0732, Topo: 0.3347
# Epoch 99, Batch 270: Total Loss: 1.1105, CE: 0.2226, Topo: 2.9597
# Epoch 99, Batch 280: Total Loss: 0.3185, CE: 0.1412, Topo: 0.5909
# Epoch 99, Batch 290: Total Loss: 0.1639, CE: 0.0282, Topo: 0.4522
# Epoch 99, Batch 300: Total Loss: 0.7158, CE: 0.0933, Topo: 2.0749
# Epoch 99, Batch 310: Total Loss: 0.4980, CE: 0.1182, Topo: 1.2662
# Epoch 99/100:
#   Train - Total: 0.6269, CE: 0.1258, Topo: 1.6703
#   Val IoU: 0.8908
# Epoch 100, Batch 0: Total Loss: 0.4058, CE: 0.1124, Topo: 0.9780
# Epoch 100, Batch 10: Total Loss: 0.2994, CE: 0.0801, Topo: 0.7309
# Epoch 100, Batch 20: Total Loss: 0.3358, CE: 0.0741, Topo: 0.8724
# Epoch 100, Batch 30: Total Loss: 0.1927, CE: 0.0547, Topo: 0.4598
# Epoch 100, Batch 40: Total Loss: 0.2304, CE: 0.0309, Topo: 0.6650
# Epoch 100, Batch 50: Total Loss: 0.3188, CE: 0.0969, Topo: 0.7395
# Epoch 100, Batch 60: Total Loss: 0.3774, CE: 0.0865, Topo: 0.9695
# Epoch 100, Batch 70: Total Loss: 0.3862, CE: 0.0941, Topo: 0.9734
# Epoch 100, Batch 80: Total Loss: 0.3356, CE: 0.0714, Topo: 0.8805
# Epoch 100, Batch 90: Total Loss: 0.5481, CE: 0.1044, Topo: 1.4789
# Epoch 100, Batch 100: Total Loss: 3.9159, CE: 0.6563, Topo: 10.8654
# Epoch 100, Batch 110: Total Loss: 1.0349, CE: 0.1002, Topo: 3.1157
# Epoch 100, Batch 120: Total Loss: 0.2668, CE: 0.0602, Topo: 0.6884
# Epoch 100, Batch 130: Total Loss: 0.1597, CE: 0.0619, Topo: 0.3258
# Epoch 100, Batch 140: Total Loss: 0.2583, CE: 0.0423, Topo: 0.7202
# Epoch 100, Batch 150: Total Loss: 0.1582, CE: 0.0768, Topo: 0.2715
# Epoch 100, Batch 160: Total Loss: 0.3701, CE: 0.0913, Topo: 0.9292
# Epoch 100, Batch 170: Total Loss: 1.5662, CE: 0.3125, Topo: 4.1793
# Epoch 100, Batch 180: Total Loss: 0.2776, CE: 0.0983, Topo: 0.5976
# Epoch 100, Batch 190: Total Loss: 0.3185, CE: 0.0542, Topo: 0.8811
# Epoch 100, Batch 200: Total Loss: 0.5406, CE: 0.1772, Topo: 1.2113
# Epoch 100, Batch 210: Total Loss: 0.1980, CE: 0.0749, Topo: 0.4102
# Epoch 100, Batch 220: Total Loss: 1.6613, CE: 0.2335, Topo: 4.7591
# Epoch 100, Batch 230: Total Loss: 0.1917, CE: 0.0328, Topo: 0.5296
# Epoch 100, Batch 240: Total Loss: 0.2735, CE: 0.1110, Topo: 0.5417
# Epoch 100, Batch 250: Total Loss: 0.2234, CE: 0.1196, Topo: 0.3460
# Epoch 100, Batch 260: Total Loss: 0.4041, CE: 0.1372, Topo: 0.8897
# Epoch 100, Batch 270: Total Loss: 6.6371, CE: 2.4123, Topo: 14.0826
# Epoch 100, Batch 280: Total Loss: 0.2153, CE: 0.0688, Topo: 0.4884
# Epoch 100, Batch 290: Total Loss: 0.2430, CE: 0.0858, Topo: 0.5243
# Epoch 100, Batch 300: Total Loss: 0.2032, CE: 0.0522, Topo: 0.5032
# Epoch 100, Batch 310: Total Loss: 0.0859, CE: 0.0307, Topo: 0.1842
# Epoch 100/100:
#   Train - Total: 0.5292, CE: 0.1194, Topo: 1.3660
#   Val IoU: 0.8952
# === TRAINING COMPLETED ===
# Best validation IoU: 0.9108
#
# 🎯 PHASE 1 COMPLETED with IoU: 0.9108
# ✅ Ready for Phase 2: Weak data processing

# %%
import torch
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from segment_anything import sam_model_registry
from torch.optim import Adam
import torch.nn as nn
from glob import glob

# ==================== CONFIGURATION ====================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
test_image_dir = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/full_test_images'
initial_output_dir = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/topo_initial_predictions'
sam_checkpoint = "/home/iiitdmk-param/Desktop/sam_vit_b.pth"
model_type = "vit_b"
pretrained_model_path = 'best_high_iou_sam.pth'

# ==================== CLASS DEFINITIONS ====================
CLASS_INFO = {
    0: {"name": "background", "rgb": [0, 0, 0]},
    1: {"name": "airplane", "rgb": [166, 202, 240]},
    2: {"name": "bare soil", "rgb": [128, 128, 0]},
    3: {"name": "buildings", "rgb": [0, 0, 128]},
    4: {"name": "cars", "rgb": [255, 0, 0]},
    5: {"name": "chaparral", "rgb": [0, 128, 0]},
    6: {"name": "court", "rgb": [128, 0, 0]},
    7: {"name": "dock", "rgb": [255, 233, 233]},
    8: {"name": "field", "rgb": [160, 160, 164]},
    9: {"name": "grass", "rgb": [0, 128, 128]},
    10: {"name": "mobile home", "rgb": [90, 87, 255]},
    11: {"name": "pavement", "rgb": [255, 255, 0]},
    12: {"name": "sand", "rgb": [255, 192, 0]},
    13: {"name": "sea", "rgb": [0, 0, 255]},
    14: {"name": "ship", "rgb": [255, 0, 192]},
    15: {"name": "tanks", "rgb": [128, 0, 128]},
    16: {"name": "trees", "rgb": [0, 255, 0]},
    17: {"name": "water", "rgb": [0, 255, 255]}
}

NUM_CLASSES = len(CLASS_INFO)

# ==================== MODEL ARCHITECTURE ====================
class HighIoUSAMWrapper(nn.Module):
    def __init__(self, sam_model, num_classes):
        super().__init__()
        self.sam = sam_model
        self.num_classes = num_classes
        
        self.segmentation_head = nn.Sequential(
            nn.Conv2d(256, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, num_classes, 1)
        )
        
        for param in self.sam.parameters():
            param.requires_grad = False
    
    def forward(self, x):
        with torch.no_grad():
            image_embeddings = self.sam.image_encoder(x)
        logits = self.segmentation_head(image_embeddings)
        return logits

# ==================== LOAD PRE-TRAINED MODEL ====================
def load_pretrained_model(pretrained_path, sam_checkpoint, model_type, num_classes):
    print("🔄 Loading SAM base model...")
    sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
    
    print("🔄 Creating wrapper model...")
    model = HighIoUSAMWrapper(sam, num_classes)
    
    print(f"🔄 Loading pre-trained weights from {pretrained_path}...")
    
    if not os.path.exists(pretrained_path):
        raise FileNotFoundError(f"❌ Pre-trained model not found at: {pretrained_path}")
    
    checkpoint = torch.load(pretrained_path, map_location=device, weights_only=False)
    model.load_state_dict(checkpoint['model_state_dict'])
    
    epoch = checkpoint.get('epoch', 'Unknown')
    loss = checkpoint.get('loss', 'Unknown')
    iou = checkpoint.get('iou', 'Unknown')
    
    try:
        loss_str = f"{float(loss):.4f}" if loss != 'Unknown' else 'Unknown'
        iou_str = f"{float(iou):.4f}" if iou != 'Unknown' else 'Unknown'
        print(f"✅ Loaded model from epoch {epoch} with val loss: {loss_str}, IoU: {iou_str}")
    except (ValueError, TypeError):
        print(f"✅ Loaded model from epoch {epoch} with val loss: {loss}, IoU: {iou}")
    
    return model

# ==================== GET INITIAL PREDICTION ====================
def get_initial_prediction(model, image_rgb, original_size, device):
    """Get initial dense 1-channel prediction using your fine-tuned model"""
    # Preprocess image
    input_image = cv2.resize(image_rgb, (1024, 1024))
    input_image = input_image.astype(np.float32) / 255.0
    input_image = (input_image - np.array([0.485, 0.456, 0.406])) / np.array([0.229, 0.224, 0.225])
    
    input_image_tensor = torch.from_numpy(input_image).permute(2, 0, 1).float().to(device)
    input_image_tensor = input_image_tensor.unsqueeze(0)
    
    with torch.no_grad():
        logits = model(input_image_tensor)
        logits = torch.nn.functional.interpolate(
            logits, size=original_size, mode='bilinear', align_corners=False
        )
        predictions = torch.argmax(logits, dim=1).squeeze(0).cpu().numpy()
    
    return predictions

# ==================== SAVE INITIAL PREDICTIONS ====================
def save_initial_predictions(model, test_image_dir, output_dir, device='cuda'):
    """Save only initial predictions without any refinement"""
    os.makedirs(output_dir, exist_ok=True)
    model.eval()
    
    image_files = sorted([f for f in os.listdir(test_image_dir) if f.endswith(('.png', '.jpg', '.jpeg'))])
    
    print(f"📸 Found {len(image_files)} test images")
    print(f"💾 Saving initial predictions to: {output_dir}")
    
    for image_idx, image_file in enumerate(image_files, 1):
        image_path = os.path.join(test_image_dir, image_file)
        base_name = image_file.split('.')[0]
        
        # Load image
        image = cv2.imread(image_path)
        if image is None:
            print(f"❌ Could not load image: {image_file}")
            continue
            
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        original_size = image_rgb.shape[:2]
        
        #print(f"[{image_idx}/{len(image_files)}] Processing {image_file}...")
        
        # Get initial 1-channel prediction
        initial_prediction = get_initial_prediction(model, image_rgb, original_size, device)
        
        # Analyze initial prediction
        initial_classes = np.unique(initial_prediction)
        initial_class_names = [CLASS_INFO.get(cid, {"name": f"unknown_{cid}"})["name"] for cid in initial_classes]
        #print(f"  📊 Classes: {list(zip(initial_classes, initial_class_names))}")
        
        # Save initial prediction
        predictions_uint8 = initial_prediction.astype(np.uint8)
        output_path = os.path.join(output_dir, f'{image_file}')
        cv2.imwrite(output_path, predictions_uint8)
        #print(f"  ✅ Saved initial prediction: {output_path}")
    
    print("\n🎉 All initial predictions saved!")

# ==================== VISUALIZATION ====================
def visualize_predictions(predictions_folder, num_samples=9):
    """Visualize prediction masks with proper class colors"""
    image_files = sorted([f for f in os.listdir(predictions_folder) if f.endswith(('.png', '.jpg', '.jpeg'))])
    
    if not image_files:
        print("❌ No prediction files found for visualization")
        return
    
    num_images = min(len(image_files), num_samples)
    cols = 3
    rows = (num_images + cols - 1) // cols
    
    fig, axes = plt.subplots(rows, cols, figsize=(20, 6*rows))
    if rows > 1:
        axes = axes.flatten()
    else:
        axes = [axes] if cols == 1 else axes
    
    for i, image_file in enumerate(image_files[:num_images]):
        image_path = os.path.join(predictions_folder, image_file)
        mask = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        
        if mask is None:
            continue
        
        # Create colored mask using class RGB values
        colored_mask = np.zeros((mask.shape[0], mask.shape[1], 3), dtype=np.uint8)
        for class_id, info in CLASS_INFO.items():
            colored_mask[mask == class_id] = info["rgb"]
        
        axes[i].imshow(colored_mask)
        
        # Get unique classes in this mask
        unique_classes = np.unique(mask)
        class_names = [CLASS_INFO.get(cid, {"name": f"unknown_{cid}"})["name"] for cid in unique_classes]
        
        axes[i].set_title(f'{image_file}\nClasses: {", ".join(class_names)}', fontsize=10)
        axes[i].axis('off')
    
    # Hide unused subplots
    for j in range(i + 1, len(axes)):
        axes[j].axis('off')
    
    plt.tight_layout()
    plt.show()

# ==================== MAIN EXECUTION ====================
def main():
    print("🚀 Starting initial predictions...")
    
    # Load your pre-trained fine-tuned model
    model = load_pretrained_model(pretrained_model_path, sam_checkpoint, model_type, NUM_CLASSES)
    model = model.to(device)
    model.eval()
    
    # Save only initial predictions
    save_initial_predictions(model, test_image_dir, initial_output_dir, device)
    
    # Visualize predictions
    visualize_predictions(initial_output_dir)
    
    print("\n🎯 Initial predictions completed successfully!")

if __name__ == "__main__":
    main()
# Out:
# 🚀 Starting initial predictions...
# 🔄 Loading SAM base model...
# 🔄 Creating wrapper model...
# 🔄 Loading pre-trained weights from best_high_iou_sam.pth...
# ✅ Loaded model from epoch 94 with val loss: 0.0995, IoU: 0.9108
# 📸 Found 1319 test images
# 💾 Saving initial predictions to: /home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/topo_initial_predictions
#
# 🎉 All initial predictions saved!
# 🎯 Initial predictions completed successfully!

# %%
import os
import numpy as np
from PIL import Image

# Define the class information
CLASS_INFO = {
    0: {"name": "background", "rgb": [0, 0, 0]},
    1: {"name": "airplane", "rgb": [166, 202, 240]},
    2: {"name": "bare soil", "rgb": [128, 128, 0]},
    3: {"name": "buildings", "rgb": [0, 0, 128]},
    4: {"name": "cars", "rgb": [255, 0, 0]},
    5: {"name": "chaparral", "rgb": [0, 128, 0]},
    6: {"name": "court", "rgb": [128, 0, 0]},
    7: {"name": "dock", "rgb": [255, 233, 233]},
    8: {"name": "field", "rgb": [160, 160, 164]},
    9: {"name": "grass", "rgb": [0, 128, 128]},
    10: {"name": "mobile home", "rgb": [90, 87, 255]},
    11: {"name": "pavement", "rgb": [255, 255, 0]},
    12: {"name": "sand", "rgb": [255, 192, 0]},
    13: {"name": "sea", "rgb": [0, 0, 255]},
    14: {"name": "ship", "rgb": [255, 0, 192]},
    15: {"name": "tanks", "rgb": [128, 0, 128]},
    16: {"name": "trees", "rgb": [0, 255, 0]},
    17: {"name": "water", "rgb": [0, 255, 255]}
}

def calculate_detailed_miou(gt_folder, pred_folder, num_classes=18, ignore_index=None):
    """
    Calculate detailed mIoU with per-class results
    """
    
    gt_files = sorted([f for f in os.listdir(gt_folder) if f.endswith(('.png', '.jpg', '.jpeg', '.tiff'))])
    pred_files = sorted([f for f in os.listdir(pred_folder) if f.endswith(('.png', '.jpg', '.jpeg', '.tiff'))])
    
    assert len(gt_files) == len(pred_files), f"Number of files don't match: GT={len(gt_files)}, Pred={len(pred_files)}"
    
    # Initialize intersection and union arrays
    total_intersection = np.zeros(num_classes)
    total_union = np.zeros(num_classes)
    class_pixels = np.zeros(num_classes)  # For pixel accuracy
    
    print(f"Processing {len(gt_files)} images...")
    
    for i, (gt_file, pred_file) in enumerate(zip(gt_files, pred_files)):
        gt_path = os.path.join(gt_folder, gt_file)
        pred_path = os.path.join(pred_folder, pred_file)
        
        # Load 1-channel masks
        gt_mask = np.array(Image.open(gt_path))
        pred_mask = np.array(Image.open(pred_path))
        
        # Ensure masks have the same shape
        assert gt_mask.shape == pred_mask.shape, f"Shape mismatch: GT{gt_mask.shape} vs Pred{pred_mask.shape}"
        
        # Calculate IoU for each class
        for class_id in range(num_classes):
            if ignore_index is not None and class_id == ignore_index:
                continue
                
            gt_class = (gt_mask == class_id)
            pred_class = (pred_mask == class_id)
            
            intersection = np.logical_and(gt_class, pred_class).sum()
            union = np.logical_or(gt_class, pred_class).sum()
            
            total_intersection[class_id] += intersection
            total_union[class_id] += union
            class_pixels[class_id] += gt_class.sum()
        
        if (i + 1) % 100 == 0:
            print(f"Processed {i + 1}/{len(gt_files)} images")
    
    # Calculate IoU for each class
    iou_per_class = np.zeros(num_classes)
    for class_id in range(num_classes):
        if total_union[class_id] > 0:
            iou_per_class[class_id] = total_intersection[class_id] / total_union[class_id]
        else:
            iou_per_class[class_id] = np.nan
    
    # Calculate mIoU (mean over classes, ignoring NaN)
    valid_classes = ~np.isnan(iou_per_class)
    miou = np.mean(iou_per_class[valid_classes])
    
    # Calculate pixel accuracy
    pixel_accuracy = total_intersection.sum() / class_pixels.sum() if class_pixels.sum() > 0 else 0
    
    return miou, iou_per_class, pixel_accuracy

# Usage with detailed results
gt_folder = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/full_test_1cmasks'
pred_folder = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/topo_initial_predictions'
num_classes = 18

miou, iou_per_class, pixel_acc = calculate_detailed_miou(gt_folder, pred_folder, num_classes)

print("\n" + "="*50)
print("SEMANTIC SEGMENTATION RESULTS")
print("="*50)
print(f"mIoU: {miou:.4f}")
print(f"Pixel Accuracy: {pixel_acc:.4f}")
print("\nPer-class IoU:")
for class_id in range(num_classes):
    class_name = CLASS_INFO[class_id]["name"]
    iou = iou_per_class[class_id]
    if not np.isnan(iou):
        print(f"  {class_name:15}: {iou:.4f}")
    else:
        print(f"  {class_name:15}: No pixels")
# Out:
# Processing 1319 images...
# Processed 100/1319 images
# Processed 200/1319 images
# Processed 300/1319 images
# Processed 400/1319 images
# Processed 500/1319 images
# Processed 600/1319 images
# Processed 700/1319 images
# Processed 800/1319 images
# Processed 900/1319 images
# Processed 1000/1319 images
# Processed 1100/1319 images
# Processed 1200/1319 images
# Processed 1300/1319 images
#
# ==================================================
# SEMANTIC SEGMENTATION RESULTS
# ==================================================
# mIoU: 0.5842
# Pixel Accuracy: 0.7606
#
# Per-class IoU:
#   background     : No pixels
#   airplane       : 0.5540
#   bare soil      : 0.4217
#   buildings      : 0.6093
#   cars           : 0.7141
#   chaparral      : 0.6510
#   court          : 0.8227
#   dock           : 0.4354
#   field          : 0.1149
#   grass          : 0.6082
#   mobile home    : 0.4427
#   pavement       : 0.7401
#   sand           : 0.4199
#   sea            : 0.8436
#   ship           : 0.6435
#   tanks          : 0.6783
#   trees          : 0.5451
#   water          : 0.6861

# %%
import torch
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from segment_anything import sam_model_registry
from torch.optim import Adam
import torch.nn as nn
from glob import glob

# ==================== CONFIGURATION ====================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
test_image_dir = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/full_test_images'
point_annotation_dir = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/full_test_point_masks'
initial_predictions_dir = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/topo_initial_predictions'
refined_output_dir = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/topo_refined_predictions'
sam_checkpoint = "/home/iiitdmk-param/Desktop/sam_vit_b.pth"
model_type = "vit_b"
pretrained_model_path = 'best_high_iou_sam.pth'

# ==================== CLASS DEFINITIONS ====================
CLASS_INFO = {
    0: {"name": "background", "rgb": [0, 0, 0]},
    1: {"name": "airplane", "rgb": [166, 202, 240]},
    2: {"name": "bare soil", "rgb": [128, 128, 0]},
    3: {"name": "buildings", "rgb": [0, 0, 128]},
    4: {"name": "cars", "rgb": [255, 0, 0]},
    5: {"name": "chaparral", "rgb": [0, 128, 0]},
    6: {"name": "court", "rgb": [128, 0, 0]},
    7: {"name": "dock", "rgb": [255, 233, 233]},
    8: {"name": "field", "rgb": [160, 160, 164]},
    9: {"name": "grass", "rgb": [0, 128, 128]},
    10: {"name": "mobile home", "rgb": [90, 87, 255]},
    11: {"name": "pavement", "rgb": [255, 255, 0]},
    12: {"name": "sand", "rgb": [255, 192, 0]},
    13: {"name": "sea", "rgb": [0, 0, 255]},
    14: {"name": "ship", "rgb": [255, 0, 192]},
    15: {"name": "tanks", "rgb": [128, 0, 128]},
    16: {"name": "trees", "rgb": [0, 255, 0]},
    17: {"name": "water", "rgb": [0, 255, 255]}
}

NUM_CLASSES = len(CLASS_INFO)

# ==================== POINT ANNOTATION LOADING ====================
def load_point_annotations(point_annotation_dir, image_files):
    """Load RGB point annotations and convert to class coordinates, ignoring (100,100,100) pixels"""
    point_prompts = {}
    ignore_color = np.array([100, 100, 100])
    
    print("🔍 Loading point annotations...")
    
    for image_file in image_files:
        base_name = image_file.split('.')[0]
        point_path = os.path.join(point_annotation_dir, f"{base_name}.png")
        
        if os.path.exists(point_path):
            point_mask = cv2.imread(point_path)
            if point_mask is None:
                continue
                
            point_mask = cv2.cvtColor(point_mask, cv2.COLOR_BGR2RGB)
            original_size = point_mask.shape[:2]
            
            # Create ignore mask (pixels that are NOT ignore color)
            non_ignore_mask = ~np.all(point_mask == ignore_color, axis=-1)
            
            # Extract point prompts for each class
            class_points = {}
            
            for class_id, info in CLASS_INFO.items():
                if class_id == 0:  # Skip background
                    continue
                    
                target_color = np.array(info["rgb"])
                # Find pixels that match this class color AND are not ignore color
                mask = np.all(point_mask == target_color, axis=-1) & non_ignore_mask
                
                if np.any(mask):
                    # Get coordinates of points
                    y_coords, x_coords = np.where(mask)
                    points = list(zip(x_coords, y_coords))
                    class_points[class_id] = points
            
            point_prompts[base_name] = class_points
    
    return point_prompts

# ==================== MODEL ARCHITECTURE ====================
class HighIoUSAMWrapper(nn.Module):
    def __init__(self, sam_model, num_classes):
        super().__init__()
        self.sam = sam_model
        self.num_classes = num_classes
        
        self.segmentation_head = nn.Sequential(
            nn.Conv2d(256, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, num_classes, 1)
        )
        
        for param in self.sam.parameters():
            param.requires_grad = False
    
    def forward(self, x):
        with torch.no_grad():
            image_embeddings = self.sam.image_encoder(x)
        logits = self.segmentation_head(image_embeddings)
        return logits
    
    def get_sam_embedding(self, x):
        """Get SAM image embeddings for point refinement"""
        with torch.no_grad():
            return self.sam.image_encoder(x)
    
    def prompt_guided_prediction(self, image_embedding, point_coords, point_labels):
        """Use SAM's prompt encoder and mask decoder for point refinement"""
        sparse_embeddings, dense_embeddings = self.sam.prompt_encoder(
            points=(point_coords, point_labels),
            boxes=None,
            masks=None,
        )
        
        low_res_masks, iou_predictions = self.sam.mask_decoder(
            image_embeddings=image_embedding,
            image_pe=self.sam.prompt_encoder.get_dense_pe(),
            sparse_prompt_embeddings=sparse_embeddings,
            dense_prompt_embeddings=dense_embeddings,
            multimask_output=False,
        )
        
        return low_res_masks

# ==================== LOAD PRE-TRAINED MODEL ====================
def load_pretrained_model(pretrained_path, sam_checkpoint, model_type, num_classes):
    print("🔄 Loading SAM base model...")
    sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
    
    print("🔄 Creating wrapper model...")
    model = HighIoUSAMWrapper(sam, num_classes)
    
    print(f"🔄 Loading pre-trained weights from {pretrained_path}...")
    
    if not os.path.exists(pretrained_path):
        raise FileNotFoundError(f"❌ Pre-trained model not found at: {pretrained_path}")
    
    checkpoint = torch.load(pretrained_path, map_location=device, weights_only=False)
    model.load_state_dict(checkpoint['model_state_dict'])
    
    return model

# ==================== REFINEMENT FUNCTIONS ====================
def refine_with_points(model, image_rgb, initial_pred, class_points, original_size, device):
    """Refine initial prediction using point prompts with fine-tuned SAM"""
    refined_pred = initial_pred.copy()
    
    if not class_points:
        return refined_pred
    
    # Preprocess image for SAM
    input_image = cv2.resize(image_rgb, (1024, 1024))
    input_image = input_image.astype(np.float32) / 255.0
    input_image = (input_image - np.array([0.485, 0.456, 0.406])) / np.array([0.229, 0.224, 0.225])
    input_image_tensor = torch.from_numpy(input_image).permute(2, 0, 1).float().to(device)
    
    # Get image embedding from your fine-tuned SAM
    with torch.no_grad():
        image_embedding = model.get_sam_embedding(input_image_tensor.unsqueeze(0))
    
    # Process each class with point prompts
    total_refined_pixels = 0
    
    for class_id, points in class_points.items():
        if len(points) == 0:
            continue
            
        #print(f"    🎯 Refining {CLASS_INFO[class_id]['name']} with {len(points)} points...")
        class_refined_pixels = 0
        
        for point_idx, point in enumerate(points):
            x, y = point
            
            # Scale points to 1024x1024
            x_scale = 1024 / original_size[1]
            y_scale = 1024 / original_size[0]
            x_sam = int(x * x_scale)
            y_sam = int(y * y_scale)
            
            # Ensure coordinates are within bounds
            x_sam = max(0, min(x_sam, 1023))
            y_sam = max(0, min(y_sam, 1023))
            
            # Create point prompt
            point_coords = torch.tensor([[[x_sam, y_sam]]], device=device).float()
            point_labels = torch.tensor([[1]], device=device).long()
            
            # Get mask prediction from your fine-tuned SAM
            with torch.no_grad():
                low_res_masks = model.prompt_guided_prediction(
                    image_embedding, point_coords, point_labels
                )
                
                # Upscale mask to original size
                mask = torch.nn.functional.interpolate(
                    low_res_masks,
                    size=original_size,
                    mode="bilinear",
                    align_corners=False,
                )
                mask = mask.squeeze().cpu().numpy() > 0.0
            
            # Count how many pixels we're refining
            pixels_refined = np.sum(mask)
            class_refined_pixels += pixels_refined
            
            # OVERWRITE the entire region with the correct class ID
            refined_pred[mask] = class_id
        
        total_refined_pixels += class_refined_pixels
        #print(f"      ✅ {CLASS_INFO[class_id]['name']}: {class_refined_pixels} pixels refined")
    
    #print(f"    📊 Total refinement: {total_refined_pixels} pixels updated")
    return refined_pred

# ==================== REFINEMENT ONLY ====================
def refine_predictions_only(model, point_prompts, test_image_dir, initial_predictions_dir, refined_output_dir, device='cuda'):
    """Refine existing initial predictions using point prompts"""
    os.makedirs(refined_output_dir, exist_ok=True)
    model.eval()
    
    image_files = sorted([f for f in os.listdir(test_image_dir) if f.endswith(('.png', '.jpg', '.jpeg'))])
    
    print(f"📸 Found {len(image_files)} test images")
    print(f"💾 Loading initial predictions from: {initial_predictions_dir}")
    print(f"💾 Saving refined predictions to: {refined_output_dir}")
    
    for image_idx, image_file in enumerate(image_files, 1):
        image_path = os.path.join(test_image_dir, image_file)
        base_name = image_file.split('.')[0]
        
        # Load image
        image = cv2.imread(image_path)
        if image is None:
            print(f"❌ Could not load image: {image_file}")
            continue
            
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        original_size = image_rgb.shape[:2]
        
        # Load initial prediction
        initial_pred_path = os.path.join(initial_predictions_dir, image_file)
        if not os.path.exists(initial_pred_path):
            print(f"❌ Initial prediction not found: {initial_pred_path}")
            continue
            
        initial_prediction = cv2.imread(initial_pred_path, cv2.IMREAD_GRAYSCALE)
        if initial_prediction is None:
            print(f"❌ Could not load initial prediction: {initial_pred_path}")
            continue
        
        #print(f"[{image_idx}/{len(image_files)}] 🔄 Refining {image_file}...")
        
        # Analyze initial prediction
        initial_classes = np.unique(initial_prediction)
        initial_class_names = [CLASS_INFO.get(cid, {"name": f"unknown_{cid}"})["name"] for cid in initial_classes]
        #print(f"  📊 Initial classes: {list(zip(initial_classes, initial_class_names))}")
        
        # Refine with point prompts if available
        if base_name in point_prompts and point_prompts[base_name]:
            #print(f"  🔧 Refining with point annotations...")
            refined_prediction = refine_with_points(
                model, image_rgb, initial_prediction, point_prompts[base_name], original_size, device
            )
            refinement_type = "REFINED"
        else:
            refined_prediction = initial_prediction
            print(f"  ⚠️  No point annotations found, using initial prediction")
            refinement_type = "INITIAL"
        
        # Save refined prediction
        predictions_uint8 = refined_prediction.astype(np.uint8)
        output_path = os.path.join(refined_output_dir, f'{image_file}')
        cv2.imwrite(output_path, predictions_uint8)
        
        # Analyze final prediction
        final_classes = np.unique(refined_prediction)
        final_class_names = [CLASS_INFO.get(cid, {"name": f"unknown_{cid}"})["name"] for cid in final_classes]
        #print(f"  ✅ Saved {refinement_type} mask - Classes: {list(zip(final_classes, final_class_names))}")
    
    print("\n🎉 All refinements completed!")

# ==================== MAIN EXECUTION ====================
def main():
    print("🚀 Starting refinement of initial predictions...")
    
    # Load your pre-trained fine-tuned model
    model = load_pretrained_model(pretrained_model_path, sam_checkpoint, model_type, NUM_CLASSES)
    model = model.to(device)
    model.eval()
    
    # Load point annotations
    test_image_files = sorted([f for f in os.listdir(test_image_dir) if f.endswith(('.png', '.jpg', '.jpeg'))])
    point_prompts = load_point_annotations(point_annotation_dir, test_image_files)
    
    # Refine existing initial predictions
    refine_predictions_only(model, point_prompts, test_image_dir, initial_predictions_dir, refined_output_dir, device)
    
    print("\n🎯 Refinement completed successfully!")

if __name__ == "__main__":
    main()
# Out:
# 🚀 Starting refinement of initial predictions...
# 🔄 Loading SAM base model...
# 🔄 Creating wrapper model...
# 🔄 Loading pre-trained weights from best_high_iou_sam.pth...
# 🔍 Loading point annotations...
# 📸 Found 1319 test images
# 💾 Loading initial predictions from: /home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/topo_initial_predictions
# 💾 Saving refined predictions to: /home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/topo_refined_predictions
#
# 🎉 All refinements completed!
#
# 🎯 Refinement completed successfully!

# %%
import os
import numpy as np
from PIL import Image

# Define the class information
CLASS_INFO = {
    0: {"name": "background", "rgb": [0, 0, 0]},
    1: {"name": "airplane", "rgb": [166, 202, 240]},
    2: {"name": "bare soil", "rgb": [128, 128, 0]},
    3: {"name": "buildings", "rgb": [0, 0, 128]},
    4: {"name": "cars", "rgb": [255, 0, 0]},
    5: {"name": "chaparral", "rgb": [0, 128, 0]},
    6: {"name": "court", "rgb": [128, 0, 0]},
    7: {"name": "dock", "rgb": [255, 233, 233]},
    8: {"name": "field", "rgb": [160, 160, 164]},
    9: {"name": "grass", "rgb": [0, 128, 128]},
    10: {"name": "mobile home", "rgb": [90, 87, 255]},
    11: {"name": "pavement", "rgb": [255, 255, 0]},
    12: {"name": "sand", "rgb": [255, 192, 0]},
    13: {"name": "sea", "rgb": [0, 0, 255]},
    14: {"name": "ship", "rgb": [255, 0, 192]},
    15: {"name": "tanks", "rgb": [128, 0, 128]},
    16: {"name": "trees", "rgb": [0, 255, 0]},
    17: {"name": "water", "rgb": [0, 255, 255]}
}

def calculate_detailed_miou(gt_folder, pred_folder, num_classes=18, ignore_index=None):
    """
    Calculate detailed mIoU with per-class results
    """
    
    gt_files = sorted([f for f in os.listdir(gt_folder) if f.endswith(('.png', '.jpg', '.jpeg', '.tiff'))])
    pred_files = sorted([f for f in os.listdir(pred_folder) if f.endswith(('.png', '.jpg', '.jpeg', '.tiff'))])
    
    assert len(gt_files) == len(pred_files), f"Number of files don't match: GT={len(gt_files)}, Pred={len(pred_files)}"
    
    # Initialize intersection and union arrays
    total_intersection = np.zeros(num_classes)
    total_union = np.zeros(num_classes)
    class_pixels = np.zeros(num_classes)  # For pixel accuracy
    
    print(f"Processing {len(gt_files)} images...")
    
    for i, (gt_file, pred_file) in enumerate(zip(gt_files, pred_files)):
        gt_path = os.path.join(gt_folder, gt_file)
        pred_path = os.path.join(pred_folder, pred_file)
        
        # Load 1-channel masks
        gt_mask = np.array(Image.open(gt_path))
        pred_mask = np.array(Image.open(pred_path))
        
        # Ensure masks have the same shape
        assert gt_mask.shape == pred_mask.shape, f"Shape mismatch: GT{gt_mask.shape} vs Pred{pred_mask.shape}"
        
        # Calculate IoU for each class
        for class_id in range(num_classes):
            if ignore_index is not None and class_id == ignore_index:
                continue
                
            gt_class = (gt_mask == class_id)
            pred_class = (pred_mask == class_id)
            
            intersection = np.logical_and(gt_class, pred_class).sum()
            union = np.logical_or(gt_class, pred_class).sum()
            
            total_intersection[class_id] += intersection
            total_union[class_id] += union
            class_pixels[class_id] += gt_class.sum()
        
        if (i + 1) % 100 == 0:
            print(f"Processed {i + 1}/{len(gt_files)} images")
    
    # Calculate IoU for each class
    iou_per_class = np.zeros(num_classes)
    for class_id in range(num_classes):
        if total_union[class_id] > 0:
            iou_per_class[class_id] = total_intersection[class_id] / total_union[class_id]
        else:
            iou_per_class[class_id] = np.nan
    
    # Calculate mIoU (mean over classes, ignoring NaN)
    valid_classes = ~np.isnan(iou_per_class)
    miou = np.mean(iou_per_class[valid_classes])
    
    # Calculate pixel accuracy
    pixel_accuracy = total_intersection.sum() / class_pixels.sum() if class_pixels.sum() > 0 else 0
    
    return miou, iou_per_class, pixel_accuracy

# Usage with detailed results
gt_folder = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/full_test_1cmasks'
pred_folder = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/topo_refined_predictions'
num_classes = 18

miou, iou_per_class, pixel_acc = calculate_detailed_miou(gt_folder, pred_folder, num_classes)

print("\n" + "="*50)
print("SEMANTIC SEGMENTATION RESULTS")
print("="*50)
print(f"mIoU: {miou:.4f}")
print(f"Pixel Accuracy: {pixel_acc:.4f}")
print("\nPer-class IoU:")
for class_id in range(num_classes):
    class_name = CLASS_INFO[class_id]["name"]
    iou = iou_per_class[class_id]
    if not np.isnan(iou):
        print(f"  {class_name:15}: {iou:.4f}")
    else:
        print(f"  {class_name:15}: No pixels")
# Out:
# Processing 1319 images...
# Processed 100/1319 images
# Processed 200/1319 images
# Processed 300/1319 images
# Processed 400/1319 images
# Processed 500/1319 images
# Processed 600/1319 images
# Processed 700/1319 images
# Processed 800/1319 images
# Processed 900/1319 images
# Processed 1000/1319 images
# Processed 1100/1319 images
# Processed 1200/1319 images
# Processed 1300/1319 images
#
# ==================================================
# SEMANTIC SEGMENTATION RESULTS
# ==================================================
# mIoU: 0.5933
# Pixel Accuracy: 0.7610
#
# Per-class IoU:
#   background     : No pixels
#   airplane       : 0.6375
#   bare soil      : 0.3991
#   buildings      : 0.6261
#   cars           : 0.6785
#   chaparral      : 0.4451
#   court          : 0.7790
#   dock           : 0.4952
#   field          : 0.2379
#   grass          : 0.6352
#   mobile home    : 0.5383
#   pavement       : 0.7250
#   sand           : 0.5111
#   sea            : 0.8511
#   ship           : 0.5603
#   tanks          : 0.6791
#   trees          : 0.5545
#   water          : 0.7338

# %%
# confidence_calculator.py
import numpy as np
import cv2
from scipy import ndimage
import os
from glob import glob
import pandas as pd
from collections import Counter

CLASS_INFO = {
    0: {"name": "background", "rgb": [0, 0, 0]},
    1: {"name": "airplane", "rgb": [166, 202, 240]},
    2: {"name": "bare soil", "rgb": [128, 128, 0]},
    3: {"name": "buildings", "rgb": [0, 0, 128]},
    4: {"name": "cars", "rgb": [255, 0, 0]},
    5: {"name": "chaparral", "rgb": [0, 128, 0]},
    6: {"name": "court", "rgb": [128, 0, 0]},
    7: {"name": "dock", "rgb": [255, 233, 233]},
    8: {"name": "field", "rgb": [160, 160, 164]},
    9: {"name": "grass", "rgb": [0, 128, 128]},
    10: {"name": "mobile home", "rgb": [90, 87, 255]},
    11: {"name": "pavement", "rgb": [255, 255, 0]},
    12: {"name": "sand", "rgb": [255, 192, 0]},
    13: {"name": "sea", "rgb": [0, 0, 255]},
    14: {"name": "ship", "rgb": [255, 0, 192]},
    15: {"name": "tanks", "rgb": [128, 0, 128]},
    16: {"name": "trees", "rgb": [0, 255, 0]},
    17: {"name": "water", "rgb": [0, 255, 255]}
}

class ColorMapManager:
    def __init__(self, class_info):
        self.class_info = class_info
        self.num_classes = len(class_info)
        
        # Create mapping from RGB to class ID
        self.rgb_to_class = {}
        for class_id, info in class_info.items():
            rgb_tuple = tuple(info["rgb"])
            self.rgb_to_class[rgb_tuple] = class_id
    
    def get_class_name(self, class_id):
        """Get class name for a class ID"""
        return self.class_info.get(class_id, {}).get("name", f"unknown_{class_id}")
    
    def get_class_color(self, class_id):
        """Get RGB color for a class ID"""
        return self.class_info.get(class_id, {}).get("rgb", [0, 0, 0])
    
    def rgb_to_class_id(self, rgb_pixel):
        """Convert RGB pixel to class ID"""
        rgb_tuple = tuple(rgb_pixel)
        return self.rgb_to_class.get(rgb_tuple, 0)  # Default to background

class PointMaskAnalyzer:
    def __init__(self, class_info):
        self.class_info = class_info
        self.color_map = ColorMapManager(class_info)
    
    def analyze_point_mask(self, mask_path):
        """Analyze what classes are present in a point mask"""
        # Try loading as both RGB and 1-channel
        mask_rgb = cv2.imread(mask_path)
        if mask_rgb is None:
            raise ValueError(f"Could not load mask from {mask_path}")
        
        mask_rgb = cv2.cvtColor(mask_rgb, cv2.COLOR_BGR2RGB)
        
        # Check if it's 1-channel or RGB
        if len(mask_rgb.shape) == 2:
            # 1-channel mask
            unique_vals = np.unique(mask_rgb)
            print(f"1-channel mask - Unique values: {unique_vals}")
            return self._analyze_1channel_mask(mask_rgb)
        else:
            # RGB mask
            return self._analyze_rgb_mask(mask_rgb)
    
    def _analyze_1channel_mask(self, mask):
        """Analyze 1-channel point mask"""
        unique_vals = np.unique(mask)
        class_counts = {}
        
        print(f"Found {len(unique_vals)} unique values in 1-channel mask: {unique_vals}")
        
        for val in unique_vals:
            if val == 100:  # Special background value
                class_counts[100] = {"name": "special_background_100", "count": np.sum(mask == val)}
            elif 0 <= val <= 17:  # Valid class IDs
                class_name = self.color_map.get_class_name(val)
                class_counts[val] = {"name": class_name, "count": np.sum(mask == val)}
            else:
                class_counts[val] = {"name": f"unknown_{val}", "count": np.sum(mask == val)}
        
        return class_counts
    
    def _analyze_rgb_mask(self, mask_rgb):
        """Analyze RGB point mask"""
        h, w = mask_rgb.shape[:2]
        unique_colors = {}
        
        for y in range(h):
            for x in range(w):
                pixel = tuple(mask_rgb[y, x])
                if pixel not in unique_colors:
                    unique_colors[pixel] = 0
                unique_colors[pixel] += 1
        
        print(f"Found {len(unique_colors)} unique colors in RGB mask")
        
        class_counts = {}
        for color, count in unique_colors.items():
            if color == (100, 100, 100):
                class_counts[100] = {"name": "special_background_100", "count": count}
            else:
                class_id = self.color_map.rgb_to_class_id(color)
                class_name = self.color_map.get_class_name(class_id)
                class_counts[class_id] = {"name": class_name, "count": count}
        
        return class_counts
    
    def analyze_all_point_masks(self, annotations_dir):
        """Analyze all point masks to understand the data"""
        mask_paths = glob(os.path.join(annotations_dir, "*.png")) + glob(os.path.join(annotations_dir, "*.jpg"))
        all_analyses = {}
        
        print("Analyzing point masks to understand class distributions...")
        for mask_path in mask_paths:
            base_name = os.path.basename(mask_path)
            try:
                analysis = self.analyze_point_mask(mask_path)
                all_analyses[base_name] = analysis
                
                # Print summary for this mask
                valid_classes = [cid for cid in analysis.keys() if 0 <= cid <= 17]
                special_bg = 100 in analysis
                print(f"  {base_name}: {len(valid_classes)} valid classes, special_bg_100: {special_bg}")
                
            except Exception as e:
                print(f"Error analyzing {base_name}: {e}")
        
        # Overall statistics
        all_classes_found = set()
        for analysis in all_analyses.values():
            all_classes_found.update(analysis.keys())
        
        valid_classes = [c for c in all_classes_found if 0 <= c <= 17]
        print(f"\n=== POINT MASK ANALYSIS SUMMARY ===")
        print(f"Total masks analyzed: {len(all_analyses)}")
        print(f"All unique values found: {sorted(all_classes_found)}")
        print(f"Valid class IDs (0-17): {sorted(valid_classes)}")
        print(f"Special background (100) present: {100 in all_classes_found}")
        
        return all_analyses

class PointAnnotationProcessor:
    def __init__(self, class_info):
        self.class_info = class_info
        self.color_map = ColorMapManager(class_info)
        # First we need to analyze to determine background value
        self.background_value = None
    
    def determine_background_value(self, annotations_dir):
        """Analyze point masks to determine the background value"""
        analyzer = PointMaskAnalyzer(self.class_info)
        analysis = analyzer.analyze_all_point_masks(annotations_dir)
        
        # Check if special background 100 exists
        has_special_bg = any(100 in mask_analysis for mask_analysis in analysis.values())
        
        if has_special_bg:
            self.background_value = 100
            print("Using special background value: 100")
        else:
            self.background_value = 0
            print("Using default background value: 0")
        
        return self.background_value
    
    def load_point_annotations_from_mask(self, mask_path):
        """Load point annotations from 1-channel mask"""
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        if mask is None:
            raise ValueError(f"Could not load mask from {mask_path}")
        
        points = []
        
        # Find all non-background pixels as points
        non_background_coords = np.where(mask != self.background_value)
        
        for y, x in zip(non_background_coords[0], non_background_coords[1]):
            class_id = mask[y, x]
            # Only include valid class IDs (1-17, skip background 0)
            if 1 <= class_id <= 17:
                class_name = self.color_map.get_class_name(class_id)
                points.append([int(x), int(y), int(class_id), class_name])
        
        return points
    
    def load_all_point_annotations(self, annotations_dir):
        """Load all point annotations from directory"""
        # First determine background value
        self.determine_background_value(annotations_dir)
        
        annotations = {}
        mask_paths = glob(os.path.join(annotations_dir, "*.png")) + glob(os.path.join(annotations_dir, "*.jpg"))
        
        for mask_path in mask_paths:
            base_name = os.path.basename(mask_path)
            try:
                points = self.load_point_annotations_from_mask(mask_path)
                annotations[base_name] = points
                if len(points) > 0:
                    print(f"  {base_name}: {len(points)} points")
            except Exception as e:
                print(f"Error loading point annotations from {base_name}: {e}")
        
        print(f"Loaded point annotations for {len(annotations)} images")
        return annotations

class MaskQualityAnalyzer:
    def __init__(self, class_info):
        self.class_info = class_info
        self.num_classes = len(class_info)
        self.color_map = ColorMapManager(class_info)
    
    def load_mask(self, mask_path):
        """Load 1-channel mask with class IDs 0-17"""
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        if mask is None:
            raise ValueError(f"Could not load mask from {mask_path}")
        return mask.astype(np.uint8)
    
    def analyze_multi_class_mask(self, mask):
        """Analyze the quality of multi-class mask (no GT needed)"""
        boundary_score = self.calculate_boundary_quality(mask)
        coherence_score = self.calculate_region_coherence(mask)
        cleanliness_score = self.calculate_cleanliness(mask)
        
        overall_quality = 0.4 * boundary_score + 0.3 * coherence_score + 0.3 * cleanliness_score
        
        # Count classes present with their names
        classes_present = []
        class_distribution = {}
        
        for class_id in range(self.num_classes):
            pixel_count = np.sum(mask == class_id)
            if pixel_count > 0:
                classes_present.append(class_id)
                class_name = self.color_map.get_class_name(class_id)
                class_distribution[class_id] = {
                    'name': class_name,
                    'pixel_count': pixel_count,
                    'percentage': (pixel_count / mask.size) * 100
                }
        
        return {
            'boundary_score': boundary_score,
            'coherence_score': coherence_score,
            'cleanliness_score': cleanliness_score,
            'overall_quality': overall_quality,
            'classes_present': classes_present,
            'num_classes_present': len(classes_present),
            'class_distribution': class_distribution
        }
    
    def calculate_boundary_quality(self, mask):
        """Calculate smoothness of boundaries between different classes"""
        boundary_map = np.zeros_like(mask, dtype=bool)
        h, w = mask.shape
        
        for i in range(1, h-1):
            for j in range(1, w-1):
                current_class = mask[i, j]
                if (mask[i-1, j] != current_class or mask[i+1, j] != current_class or 
                    mask[i, j-1] != current_class or mask[i, j+1] != current_class):
                    boundary_map[i, j] = True
        
        boundary_pixels = np.sum(boundary_map)
        if boundary_pixels == 0:
            return 0.0
        
        labeled, num_boundary_regions = ndimage.label(boundary_map)
        fragmentation = num_boundary_regions / boundary_pixels if boundary_pixels > 0 else 0
        return 1.0 / (1.0 + fragmentation * 10)
    
    def calculate_region_coherence(self, mask):
        """Check if regions of same class are coherent/connected"""
        total_coherence = 0
        classes_checked = 0
        
        for class_id in range(1, self.num_classes):  # Skip background
            class_mask = (mask == class_id).astype(np.uint8)
            if np.sum(class_mask) > 0:
                labeled, num_regions = ndimage.label(class_mask)
                if num_regions > 0:
                    region_sizes = [np.sum(labeled == i) for i in range(1, num_regions + 1)]
                    largest_region = max(region_sizes)
                    total_pixels = np.sum(class_mask)
                    coherence = largest_region / total_pixels if total_pixels > 0 else 0
                    total_coherence += coherence
                    classes_checked += 1
        
        return total_coherence / classes_checked if classes_checked > 0 else 0
    
    def calculate_cleanliness(self, mask):
        """Check for small isolated regions that might be noise"""
        total_cleanliness = 0
        classes_checked = 0
        
        for class_id in range(1, self.num_classes):  # Skip background
            class_mask = (mask == class_id).astype(np.uint8)
            if np.sum(class_mask) > 0:
                labeled, num_regions = ndimage.label(class_mask)
                if num_regions > 0:
                    region_sizes = [np.sum(labeled == i) for i in range(1, num_regions + 1)]
                    total_pixels = np.sum(class_mask)
                    small_regions = sum(1 for size in region_sizes if size < total_pixels * 0.01)
                    cleanliness = 1.0 - min(small_regions * 0.1, 0.5)
                    total_cleanliness += cleanliness
                    classes_checked += 1
        
        return total_cleanliness / classes_checked if classes_checked > 0 else 1.0

class ConfidenceDataPreparer:
    def __init__(self, class_info):
        self.class_info = class_info
        self.num_classes = len(class_info)
        self.analyzer = MaskQualityAnalyzer(class_info)
        self.point_processor = PointAnnotationProcessor(class_info)
    
    def prepare_pseudo_data(self, images_dir: str, masks_dir: str, point_annotations_dir: str):
        """Prepare ONLY pseudo data with calculated confidence scores"""
        pseudo_data = []
        point_annotations = self.point_processor.load_all_point_annotations(point_annotations_dir)
        
        # Get all image files
        image_extensions = ['*.png', '*.jpg', '*.jpeg', '*.bmp', '*.tiff']
        image_paths = []
        for ext in image_extensions:
            image_paths.extend(glob(os.path.join(images_dir, ext)))
            image_paths.extend(glob(os.path.join(images_dir, ext.upper())))
        
        print(f"Found {len(image_paths)} pseudo images")
        
        for img_path in image_paths:
            base_name = os.path.basename(img_path)
            # Try different mask naming conventions
            mask_candidates = [
                base_name,
                base_name.replace('.jpg', '.png').replace('.jpeg', '.png'),
                f"mask_{base_name}",
                base_name.replace('.jpg', '_mask.png').replace('.jpeg', '_mask.png'),
            ]
            
            mask_path = None
            for mask_name in mask_candidates:
                potential_path = os.path.join(masks_dir, mask_name)
                if os.path.exists(potential_path):
                    mask_path = potential_path
                    break
            
            if mask_path is None:
                print(f"Warning: Could not find mask for {base_name}")
                continue
            
            try:
                # Load RGB image
                image = cv2.imread(img_path)
                
                # Load 1-channel mask
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                
                if image is not None and mask is not None:
                    # Ensure mask is in valid range (0-17)
                    mask = np.clip(mask, 0, self.num_classes - 1)
                    
                    # Calculate confidence (ONE-TIME calculation)
                    quality_analysis = self.analyzer.analyze_multi_class_mask(mask)
                    confidence = quality_analysis['overall_quality']
                    
                    # Get point annotations
                    points = point_annotations.get(base_name, [])
                    
                    # Get class distribution string
                    class_dist_str = ", ".join([f"{self.analyzer.color_map.get_class_name(cid)}" 
                                              for cid in quality_analysis['classes_present']])
                    
                    # Create result dictionary
                    result = {
                        'image_name': base_name,
                        'image_path': img_path,
                        'mask_path': mask_path,
                        'confidence': confidence,
                        'boundary_score': quality_analysis['boundary_score'],
                        'coherence_score': quality_analysis['coherence_score'],
                        'cleanliness_score': quality_analysis['cleanliness_score'],
                        'num_classes_present': quality_analysis['num_classes_present'],
                        'classes_present': class_dist_str,
                        'num_point_annotations': len(points),
                        'quality_category': 'Good' if confidence >= 0.7 else 'Fair' if confidence >= 0.5 else 'Bad'
                    }
                    
                    pseudo_data.append(result)
                    
            except Exception as e:
                print(f"Error processing {base_name}: {e}")
        
        return pseudo_data
    
    def save_to_csv(self, pseudo_data, output_path):
        """Save prepared data to CSV file"""
        df = pd.DataFrame(pseudo_data)
        
        # Reorder columns for better readability
        columns_order = [
            'image_name', 'confidence', 'quality_category', 
            'boundary_score', 'coherence_score', 'cleanliness_score',
            'num_classes_present', 'classes_present', 'num_point_annotations',
            'image_path', 'mask_path'
        ]
        
        # Only include columns that exist
        existing_columns = [col for col in columns_order if col in df.columns]
        df = df[existing_columns]
        
        df.to_csv(output_path, index=False)
        
        print(f"Saved confidence data to: {output_path}")
        print(f"Total pseudo samples: {len(pseudo_data)}")
        
        if pseudo_data:
            confidences = [x['confidence'] for x in pseudo_data]
            print(f"Confidence Statistics:")
            print(f"  Range: {min(confidences):.3f} to {max(confidences):.3f}")
            print(f"  Mean: {np.mean(confidences):.3f}")
            print(f"  Good (>=0.7): {len([c for c in confidences if c >= 0.7])}")
            print(f"  Fair (0.5-0.7): {len([c for c in confidences if 0.5 <= c < 0.7])}")
            print(f"  Bad (<0.5): {len([c for c in confidences if c < 0.5])}")

def main():
    # ========== CONFIGURE ONLY THESE ==========
    PSEUDO_IMAGES_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/full_test_images'
    PSEUDO_MASKS_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/topo_refined_predictions'
    POINT_ANNOTATIONS_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/full_point_1cmasks'
    OUTPUT_CSV_PATH = "pseudo_confidence_scores.csv"
    
    # Use your actual class info
    CLASS_INFO = {
        0: {"name": "background", "rgb": [0, 0, 0]},
        1: {"name": "airplane", "rgb": [166, 202, 240]},
        2: {"name": "bare soil", "rgb": [128, 128, 0]},
        3: {"name": "buildings", "rgb": [0, 0, 128]},
        4: {"name": "cars", "rgb": [255, 0, 0]},
        5: {"name": "chaparral", "rgb": [0, 128, 0]},
        6: {"name": "court", "rgb": [128, 0, 0]},
        7: {"name": "dock", "rgb": [255, 233, 233]},
        8: {"name": "field", "rgb": [160, 160, 164]},
        9: {"name": "grass", "rgb": [0, 128, 128]},
        10: {"name": "mobile home", "rgb": [90, 87, 255]},
        11: {"name": "pavement", "rgb": [255, 255, 0]},
        12: {"name": "sand", "rgb": [255, 192, 0]},
        13: {"name": "sea", "rgb": [0, 0, 255]},
        14: {"name": "ship", "rgb": [255, 0, 192]},
        15: {"name": "tanks", "rgb": [128, 0, 128]},
        16: {"name": "trees", "rgb": [0, 255, 0]},
        17: {"name": "water", "rgb": [0, 255, 255]}
    }
    
    # Initialize preparer with your class info
    print("Initializing ConfidenceDataPreparer...")
    preparer = ConfidenceDataPreparer(CLASS_INFO)
    
    # Prepare ONLY pseudo data
    print("Calculating confidence for pseudo data...")
    pseudo_data = preparer.prepare_pseudo_data(PSEUDO_IMAGES_DIR, PSEUDO_MASKS_DIR, POINT_ANNOTATIONS_DIR)
    
    # Save to CSV
    preparer.save_to_csv(pseudo_data, OUTPUT_CSV_PATH)
    
    print("Confidence calculation completed!")

if __name__ == "__main__":
    main()
# Out:
# Initializing ConfidenceDataPreparer...
# Calculating confidence for pseudo data...
# Analyzing point masks to understand class distributions...
# Found 4 unique colors in RGB mask
#   freew_310.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1934.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1890.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   freew_384.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   tenni_1029.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   overp_1526.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   parki_294.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2041.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   parki_224.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1250.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   spars_154.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   stora_591.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_676.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   stora_571.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   stora_572.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1849.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   golfc_69.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_454.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_805.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   overp_1542.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   tenni_1034.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   dense_1433.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   golfc_15.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   freew_339.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   tenni_1005.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_703.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   river_1353.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1722.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1185.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   dense_1458.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   spars_193.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   freew_354.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_859.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1976.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1929.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   freew_394.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   river_1359.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   tenni_1036.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_2000.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1936.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   spars_124.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1759.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   dense_1465.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   stora_542.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   baseb_979.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   build_1650.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   overp_1584.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   mobil_710.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   harbo_487.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1283.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   stora_548.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   tenni_1071.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_482.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1935.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_480.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_675.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_405.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   tenni_1020.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   baseb_995.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_448.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   mediu_1201.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1168.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   dense_1432.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   overp_1520.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_500.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_863.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   parki_278.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   stora_530.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1980.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_409.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1875.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_745.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   freew_330.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2013.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   overp_1587.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1770.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   stora_535.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_894.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   build_1661.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   airpl_875.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   mediu_1299.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   golfc_75.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1187.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_489.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   baseb_966.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1119.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_880.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   spars_182.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   mediu_1219.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1910.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   runwa_1879.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   stora_518.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2065.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   build_1644.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_470.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   dense_1460.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   river_1325.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   stora_584.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_476.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   overp_1544.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   stora_506.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   stora_520.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   river_1321.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   overp_1545.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   build_1674.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   tenni_1066.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   overp_1572.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_800.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1113.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   dense_1462.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   build_1606.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   golfc_36.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   build_1651.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_841.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   dense_1487.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   build_1637.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   river_1330.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   airpl_808.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2001.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   river_1390.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   river_1344.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   spars_185.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   baseb_991.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1812.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1226.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1783.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   overp_1568.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   build_1647.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   river_1322.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1198.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   spars_195.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   freew_322.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_446.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   inter_2044.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   build_1614.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   spars_113.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   stora_556.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_408.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_751.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_437.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   river_1347.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   inter_2092.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1896.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_772.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   parki_210.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1958.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   mobil_785.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   baseb_947.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1971.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_419.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_756.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1844.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_810.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1835.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1877.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   golfc_83.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_783.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   stora_549.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1840.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_687.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2078.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   parki_226.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_486.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_603.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   golfc_53.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2055.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   tenni_1075.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   golfc_74.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_784.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   dense_1451.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1753.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   golfc_70.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1947.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_445.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1979.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1743.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   overp_1541.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   tenni_1015.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   golfc_63.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   build_1648.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1955.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1771.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   airpl_801.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   inter_2009.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2042.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   fores_609.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1858.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_632.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   river_1338.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   build_1625.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   dense_1406.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   mobil_777.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   parki_205.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   inter_2056.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_708.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   golfc_80.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   mediu_1205.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   spars_191.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_451.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1968.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   spars_121.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_760.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   freew_391.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1884.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   baseb_940.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   spars_145.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   golfc_55.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   build_1642.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   spars_183.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_696.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   golfc_88.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   tenni_1035.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   freew_303.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   build_1622.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   baseb_999.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   overp_1598.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2069.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   river_1318.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1816.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1784.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   tenni_1089.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_755.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   freew_314.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   stora_577.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   baseb_911.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   stora_501.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   freew_375.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1926.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   mobil_781.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1916.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1919.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   dense_1482.png: 1 valid classes, special_bg_100: False
# Found 8 unique colors in RGB mask
#   tenni_1072.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_868.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2088.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   river_1312.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_464.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   baseb_958.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_764.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   spars_118.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1824.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   dense_1450.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1989.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   spars_175.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   golfc_97.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   inter_2023.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   tenni_1052.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   tenni_1027.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   freew_313.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   build_1646.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   airpl_856.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   mobil_709.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   golfc_12.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1819.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_463.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1199.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1215.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1285.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1881.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_802.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   golfc_94.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1948.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1286.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   inter_2086.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   golfc_24.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   stora_566.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   mediu_1281.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   mediu_1253.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_893.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1758.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   build_1683.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   golfc_49.png: 1 valid classes, special_bg_100: False
# Found 8 unique colors in RGB mask
#   tenni_1054.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1101.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   golfc_28.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1165.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   mediu_1241.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   inter_2072.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   golfc_99.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   parki_249.png: 1 valid classes, special_bg_100: False
# Found 8 unique colors in RGB mask
#   river_1362.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   baseb_985.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2100.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_653.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   tenni_1080.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   dense_1495.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   baseb_916.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   baseb_977.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   stora_519.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1801.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   golfc_51.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   river_1368.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   spars_166.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_634.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_661.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   spars_194.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   tenni_1007.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   parki_289.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   baseb_918.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1856.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_620.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   baseb_996.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   spars_115.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   dense_1470.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   river_1387.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1928.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   river_1320.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   baseb_926.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   golfc_58.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   build_1665.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   stora_545.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1992.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   baseb_953.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1813.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   river_1389.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_666.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   river_1301.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   freew_378.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   spars_128.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_444.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   parki_204.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   baseb_922.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   tenni_1048.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   golfc_1.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1728.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1855.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1258.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   chapa_1764.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   inter_2084.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_890.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   inter_2076.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1937.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   inter_2025.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   mediu_1266.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   tenni_1021.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_420.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_611.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1837.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1781.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   dense_1448.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1173.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   build_1670.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   river_1334.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   agric_1962.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   freew_367.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_735.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2026.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1793.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1240.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   overp_1501.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_867.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   mobil_732.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1735.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   harbo_493.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_803.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   golfc_72.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   parki_256.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   parki_288.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   baseb_973.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2068.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1171.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   river_1332.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   spars_155.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   baseb_952.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2046.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1719.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1147.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1727.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   tenni_1046.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   river_1398.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   river_1365.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1717.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   spars_156.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_813.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1949.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   river_1309.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   mobil_752.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   freew_326.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   build_1663.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_424.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1246.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1892.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_739.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   stora_588.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   airpl_827.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_651.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   build_1689.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   runwa_1891.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   mediu_1294.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   parki_215.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   freew_309.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   dense_1452.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1745.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2089.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_652.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1132.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_707.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   stora_598.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   freew_316.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1953.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   freew_311.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1133.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   freew_398.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   river_1341.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   baseb_932.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1828.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   build_1693.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   parki_222.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   harbo_402.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   mobil_786.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   golfc_76.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1295.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   freew_341.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   mobil_788.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1107.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   golfc_5.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_638.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   parki_243.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1730.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   dense_1492.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   spars_140.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1834.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1721.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_775.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   tenni_1002.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_717.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   mobil_727.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   golfc_4.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   tenni_1040.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1911.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   stora_505.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_641.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   build_1645.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   stora_541.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_614.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1136.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   build_1634.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   beach_1143.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   spars_125.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1845.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   baseb_971.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   mobil_773.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   parki_219.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1214.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_740.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1913.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   baseb_938.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1778.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   dense_1443.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   beach_1161.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   stora_546.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   overp_1504.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   stora_578.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   overp_1594.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   mediu_1236.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   spars_165.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   dense_1445.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   river_1364.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1207.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   inter_2040.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1749.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   inter_2032.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1769.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_627.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1860.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1256.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   tenni_1058.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   airpl_811.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   overp_1557.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_704.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   overp_1549.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   overp_1519.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1206.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   parki_217.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   freew_344.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   baseb_929.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   harbo_494.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   spars_135.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   spars_172.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1777.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   golfc_22.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   parki_300.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   tenni_1049.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   freew_365.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1776.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   baseb_994.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   baseb_981.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   stora_582.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   golfc_8.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   airpl_820.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   overp_1537.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   river_1385.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   airpl_823.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1814.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   freew_350.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   build_1649.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   overp_1535.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   dense_1496.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_659.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   inter_2019.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1900.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_743.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   parki_201.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   build_1687.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   stora_537.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   overp_1529.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   mobil_787.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   overp_1540.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mobil_757.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   mediu_1270.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1981.png: 1 valid classes, special_bg_100: False
# Found 6 unique colors in RGB mask
#   baseb_936.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   river_1356.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   airpl_848.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1748.png: 1 valid classes, special_bg_100: False
# Found 5 unique colors in RGB mask
#   spars_200.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   fores_698.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1894.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   parki_239.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   runwa_1898.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   river_1394.png: 1 valid classes, special_bg_100: False
# Found 7 unique colors in RGB mask
#   spars_143.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   chapa_1780.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   overp_1554.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   dense_1439.png: 1 valid classes, special_bg_100: False
# Found 4 unique colors in RGB mask
#   airpl_888.png: 1 valid classes, special_bg_100: False
# Found 2 unique colors in RGB mask
#   agric_1963.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1853.png: 1 valid classes, special_bg_100: False
# Found 3 unique colors in RGB mask
#   runwa_1873.png: 1 valid classes, special_bg_100: False
# ...
#   beach_1195.png: 10 points
#   freew_305.png: 65 points
#   parki_251.png: 170 points
#   mediu_1287.png: 105 points
#   beach_1128.png: 10 points
#   stora_513.png: 20 points
#   runwa_1823.png: 10 points
#   overp_1521.png: 60 points
#   mobil_768.png: 260 points
#   airpl_838.png: 30 points
#   freew_348.png: 79 points
#   baseb_988.png: 45 points
#   runwa_1878.png: 15 points
#   stora_581.png: 25 points
#   runwa_1833.png: 15 points
#   agric_1988.png: 5 points
#   baseb_951.png: 85 points
#   beach_1179.png: 10 points
#   beach_1127.png: 10 points
#   parki_258.png: 115 points
#   agric_1930.png: 5 points
#   dense_1493.png: 175 points
#   fores_647.png: 5 points
#   harbo_425.png: 35 points
#   parki_231.png: 110 points
#   golfc_57.png: 80 points
#   airpl_824.png: 45 points
#   runwa_1808.png: 5 points
#   stora_514.png: 45 points
#   harbo_412.png: 20 points
#   stora_595.png: 165 points
#   freew_346.png: 120 points
#   overp_1510.png: 55 points
#   baseb_942.png: 40 points
#   dense_1466.png: 102 points
#   mediu_1217.png: 150 points
#   harbo_499.png: 74 points
#   beach_1106.png: 10 points
#   runwa_1857.png: 15 points
#   freew_363.png: 237 points
#   dense_1431.png: 150 points
#   harbo_411.png: 25 points
#   beach_1122.png: 10 points
#   airpl_876.png: 60 points
#   inter_2071.png: 65 points
#   beach_1112.png: 10 points
#   build_1611.png: 97 points
#   dense_1419.png: 150 points
#   fores_650.png: 5 points
#   agric_1965.png: 5 points
#   chapa_1744.png: 937 points
#   overp_1543.png: 30 points
#   build_1632.png: 95 points
#   spars_114.png: 152 points
#   dense_1430.png: 100 points
#   inter_2073.png: 130 points
#   agric_1974.png: 5 points
#   runwa_1862.png: 15 points
#   mediu_1274.png: 149 points
#   parki_233.png: 130 points
#   chapa_1787.png: 505 points
#   build_1653.png: 35 points
#   beach_1131.png: 10 points
#   stora_587.png: 10 points
#   spars_120.png: 65 points
#   stora_533.png: 35 points
#   mobil_776.png: 192 points
#   chapa_1794.png: 565 points
#   runwa_1820.png: 15 points
#   inter_2039.png: 175 points
#   spars_101.png: 105 points
#   golfc_67.png: 25 points
#   mediu_1234.png: 195 points
#   golfc_60.png: 30 points
#   parki_206.png: 125 points
#   harbo_479.png: 132 points
#   overp_1507.png: 110 points
#   fores_646.png: 5 points
#   dense_1499.png: 130 points
#   river_1392.png: 30 points
#   chapa_1751.png: 685 points
#   stora_593.png: 50 points
#   mediu_1245.png: 155 points
#   mediu_1238.png: 291 points
#   build_1655.png: 35 points
#   mediu_1232.png: 215 points
#   fores_700.png: 5 points
#   chapa_1734.png: 486 points
#   baseb_943.png: 40 points
#   inter_2012.png: 130 points
#   parki_207.png: 110 points
#   mediu_1262.png: 151 points
#   tenni_1079.png: 180 points
#   chapa_1798.png: 377 points
#   chapa_1701.png: 838 points
#   stora_552.png: 25 points
#   build_1641.png: 10 points
#   tenni_1074.png: 140 points
#   inter_2002.png: 145 points
#   golfc_81.png: 35 points
#   agric_1921.png: 5 points
#   spars_153.png: 50 points
#   spars_142.png: 75 points
#   fores_619.png: 5 points
#   overp_1527.png: 40 points
#   stora_557.png: 35 points
#   mobil_792.png: 212 points
#   dense_1455.png: 105 points
#   harbo_458.png: 141 points
#   airpl_847.png: 30 points
#   mediu_1261.png: 185 points
#   airpl_897.png: 90 points
#   fores_657.png: 5 points
#   golfc_59.png: 65 points
#   chapa_1795.png: 381 points
#   mobil_799.png: 387 points
#   overp_1518.png: 30 points
#   river_1354.png: 20 points
#   agric_1966.png: 5 points
#   river_1314.png: 15 points
#   mediu_1268.png: 245 points
#   agric_1967.png: 5 points
#   agric_1945.png: 5 points
#   tenni_1085.png: 20 points
#   stora_597.png: 50 points
#   agric_1956.png: 5 points
#   spars_179.png: 65 points
#   mediu_1292.png: 155 points
#   beach_1151.png: 10 points
#   baseb_945.png: 91 points
#   chapa_1710.png: 678 points
#   stora_504.png: 85 points
#   river_1349.png: 45 points
#   golfc_42.png: 55 points
#   baseb_904.png: 20 points
#   stora_563.png: 75 points
#   overp_1511.png: 45 points
#   freew_376.png: 70 points
#   overp_1522.png: 80 points
#   golfc_33.png: 35 points
#   build_1690.png: 95 points
#   baseb_937.png: 25 points
#   airpl_831.png: 90 points
#   freew_396.png: 116 points
#   chapa_1711.png: 654 points
#   parki_248.png: 155 points
#   inter_2079.png: 75 points
#   dense_1477.png: 40 points
#   river_1376.png: 30 points
#   dense_1459.png: 115 points
#   freew_328.png: 80 points
#   tenni_1004.png: 95 points
#   airpl_840.png: 55 points
#   parki_285.png: 25 points
#   airpl_834.png: 35 points
#   agric_1906.png: 5 points
#   harbo_478.png: 164 points
#   build_1697.png: 15 points
#   agric_1901.png: 10 points
#   baseb_993.png: 65 points
#   tenni_1043.png: 150 points
#   freew_334.png: 55 points
#   baseb_968.png: 10 points
#   mediu_1218.png: 110 points
#   beach_1189.png: 10 points
#   golfc_92.png: 70 points
#   mediu_1300.png: 155 points
#   overp_1516.png: 40 points
#   fores_645.png: 5 points
#   freew_319.png: 65 points
#   stora_565.png: 100 points
#   harbo_413.png: 25 points
#   runwa_1865.png: 5 points
#   build_1682.png: 40 points
#   parki_252.png: 70 points
#   airpl_819.png: 35 points
#   freew_304.png: 90 points
#   airpl_825.png: 50 points
#   chapa_1775.png: 581 points
#   runwa_1843.png: 15 points
#   tenni_1031.png: 125 points
#   river_1348.png: 95 points
#   stora_576.png: 90 points
#   beach_1154.png: 10 points
#   freew_383.png: 45 points
#   spars_163.png: 70 points
#   chapa_1713.png: 632 points
#   mediu_1276.png: 155 points
#   beach_1124.png: 10 points
#   baseb_913.png: 60 points
#   freew_372.png: 100 points
#   airpl_837.png: 49 points
#   dense_1488.png: 230 points
#   tenni_1100.png: 85 points
#   parki_213.png: 105 points
#   stora_574.png: 25 points
#   fores_649.png: 5 points
#   stora_536.png: 50 points
#   dense_1441.png: 95 points
#   fores_694.png: 5 points
#   baseb_902.png: 35 points
#   runwa_1827.png: 15 points
#   inter_2027.png: 110 points
#   spars_144.png: 65 points
#   river_1361.png: 65 points
#   chapa_1772.png: 751 points
#   stora_512.png: 40 points
#   chapa_1766.png: 5 points
#   harbo_462.png: 191 points
#   airpl_809.png: 105 points
#   beach_1125.png: 10 points
#   tenni_1044.png: 70 points
#   river_1370.png: 30 points
#   river_1335.png: 40 points
#   overp_1596.png: 30 points
#   tenni_1014.png: 50 points
#   build_1616.png: 30 points
#   beach_1123.png: 10 points
#   runwa_1839.png: 15 points
#   runwa_1830.png: 15 points
#   tenni_1039.png: 115 points
#   mediu_1252.png: 205 points
#   mobil_749.png: 151 points
#   tenni_1006.png: 120 points
#   agric_1927.png: 5 points
#   dense_1453.png: 40 points
#   golfc_40.png: 45 points
#   beach_1153.png: 10 points
#   tenni_1064.png: 80 points
#   tenni_1098.png: 130 points
#   agric_1944.png: 5 points
#   golfc_54.png: 65 points
#   river_1395.png: 15 points
#   freew_329.png: 50 points
#   golfc_87.png: 113 points
#   beach_1134.png: 10 points
#   overp_1508.png: 45 points
#   build_1695.png: 50 points
#   runwa_1826.png: 15 points
#   baseb_931.png: 25 points
#   golfc_93.png: 60 points
#   stora_539.png: 25 points
#   spars_132.png: 50 points
#   spars_149.png: 50 points
#   river_1358.png: 65 points
#   river_1367.png: 25 points
#   parki_276.png: 90 points
#   airpl_879.png: 20 points
#   mediu_1224.png: 135 points
#   chapa_1763.png: 5 points
#   build_1688.png: 20 points
#   dense_1469.png: 120 points
#   fores_658.png: 5 points
#   airpl_862.png: 40 points
#   airpl_865.png: 100 points
#   mediu_1208.png: 102 points
#   agric_1987.png: 5 points
#   baseb_915.png: 25 points
#   inter_2006.png: 100 points
#   golfc_61.png: 65 points
#   agric_1973.png: 5 points
#   agric_1972.png: 5 points
#   baseb_984.png: 20 points
#   fores_629.png: 5 points
#   build_1668.png: 40 points
#   build_1659.png: 65 points
#   chapa_1797.png: 425 points
#   beach_1146.png: 10 points
#   baseb_935.png: 15 points
#   golfc_85.png: 55 points
#   river_1351.png: 35 points
#   baseb_933.png: 35 points
#   spars_116.png: 503 points
#   airpl_829.png: 52 points
#   airpl_855.png: 90 points
#   agric_1957.png: 5 points
#   spars_198.png: 25 points
#   parki_260.png: 135 points
#   runwa_1825.png: 15 points
#   mobil_723.png: 220 points
#   parki_261.png: 220 points
#   spars_133.png: 60 points
#   overp_1531.png: 100 points
#   dense_1414.png: 95 points
#   runwa_1859.png: 15 points
#   overp_1548.png: 30 points
#   fores_623.png: 5 points
#   mobil_766.png: 155 points
#   agric_1990.png: 5 points
#   baseb_956.png: 45 points
#   harbo_439.png: 50 points
#   inter_2057.png: 125 points
#   inter_2003.png: 144 points
#   harbo_455.png: 63 points
#   river_1340.png: 55 points
#   overp_1530.png: 100 points
#   spars_102.png: 80 points
#   golfc_13.png: 98 points
#   freew_335.png: 45 points
#   beach_1191.png: 10 points
#   overp_1553.png: 80 points
#   tenni_1069.png: 115 points
#   chapa_1720.png: 637 points
#   river_1302.png: 60 points
#   airpl_864.png: 65 points
#   chapa_1738.png: 746 points
#   harbo_447.png: 105 points
#   mobil_795.png: 376 points
#   mediu_1235.png: 178 points
#   fores_667.png: 5 points
#   harbo_490.png: 81 points
#   golfc_11.png: 50 points
#   parki_237.png: 395 points
#   golfc_30.png: 25 points
#   chapa_1708.png: 460 points
#   golfc_77.png: 53 points
#   beach_1104.png: 10 points
#   baseb_948.png: 140 points
#   mobil_759.png: 255 points
#   spars_123.png: 40 points
#   freew_371.png: 105 points
#   mediu_1249.png: 189 points
#   dense_1436.png: 290 points
#   beach_1144.png: 10 points
#   golfc_29.png: 20 points
#   overp_1503.png: 80 points
#   mobil_770.png: 212 points
#   parki_241.png: 184 points
#   fores_639.png: 5 points
#   agric_1907.png: 5 points
#   beach_1170.png: 10 points
#   build_1675.png: 65 points
#   dense_1497.png: 288 points
#   build_1656.png: 25 points
#   agric_1998.png: 5 points
#   parki_274.png: 65 points
#   dense_1481.png: 100 points
#   parki_230.png: 105 points
#   harbo_495.png: 81 points
#   harbo_467.png: 104 points
#   harbo_468.png: 128 points
#   fores_685.png: 5 points
#   stora_573.png: 85 points
#   build_1662.png: 70 points
#   build_1608.png: 15 points
#   inter_2097.png: 165 points
#   beach_1102.png: 10 points
#   river_1377.png: 55 points
#   parki_296.png: 295 points
#   parki_281.png: 85 points
#   parki_254.png: 135 points
#   build_1602.png: 25 points
#   runwa_1872.png: 5 points
#   golfc_32.png: 10 points
#   chapa_1742.png: 367 points
#   chapa_1768.png: 642 points
#   fores_602.png: 5 points
#   mobil_705.png: 302 points
#   harbo_477.png: 118 points
#   fores_622.png: 5 points
#   fores_643.png: 5 points
#   agric_1933.png: 5 points
#   tenni_1018.png: 110 points
#   agric_1986.png: 5 points
#   mediu_1277.png: 162 points
#   inter_2005.png: 85 points
#   stora_568.png: 25 points
#   mobil_718.png: 312 points
#   tenni_1033.png: 85 points
#   river_1328.png: 25 points
#   golfc_71.png: 45 points
#   chapa_1716.png: 963 points
#   inter_2059.png: 115 points
#   freew_370.png: 123 points
#   runwa_1802.png: 10 points
#   freew_315.png: 60 points
#   tenni_1083.png: 197 points
#   mediu_1296.png: 205 points
#   spars_106.png: 70 points
#   chapa_1773.png: 523 points
#   tenni_1055.png: 144 points
#   dense_1426.png: 75 points
#   build_1610.png: 70 points
#   chapa_1779.png: 459 points
#   baseb_907.png: 20 points
#   baseb_912.png: 10 points
#   tenni_1056.png: 140 points
#   harbo_415.png: 25 points
#   freew_385.png: 40 points
#   parki_266.png: 116 points
#   overp_1577.png: 50 points
#   agric_1970.png: 5 points
#   baseb_941.png: 75 points
#   overp_1565.png: 50 points
#   baseb_986.png: 20 points
#   stora_592.png: 80 points
#   spars_107.png: 35 points
#   dense_1424.png: 145 points
#   airpl_885.png: 40 points
#   freew_337.png: 85 points
#   river_1352.png: 45 points
#   golfc_45.png: 40 points
#   overp_1505.png: 80 points
#   harbo_430.png: 45 points
#   spars_157.png: 70 points
#   stora_516.png: 70 points
#   spars_158.png: 45 points
#   chapa_1782.png: 865 points
#   fores_648.png: 5 points
#   fores_633.png: 5 points
#   spars_181.png: 55 points
#   agric_1912.png: 5 points
#   beach_1180.png: 10 points
#   fores_617.png: 5 points
#   dense_1420.png: 40 points
#   baseb_983.png: 60 points
#   dense_1491.png: 171 points
#   harbo_469.png: 111 points
#   beach_1188.png: 10 points
#   inter_2018.png: 145 points
#   fores_663.png: 5 points
#   runwa_1807.png: 25 points
#   harbo_432.png: 40 points
#   baseb_978.png: 25 points
#   chapa_1739.png: 663 points
#   baseb_989.png: 50 points
#   runwa_1809.png: 15 points
#   airpl_878.png: 30 points
#   dense_1468.png: 20 points
#   parki_255.png: 292 points
#   overp_1523.png: 60 points
#   runwa_1831.png: 15 points
#   tenni_1082.png: 28 points
#   inter_2035.png: 145 points
#   river_1380.png: 25 points
#   mediu_1280.png: 104 points
#   chapa_1732.png: 512 points
#   tenni_1087.png: 105 points
#   airpl_835.png: 54 points
#   harbo_416.png: 20 points
#   dense_1403.png: 105 points
#   parki_263.png: 130 points
#   chapa_1786.png: 690 points
#   spars_103.png: 65 points
#   runwa_1876.png: 15 points
#   inter_2099.png: 165 points
#   harbo_429.png: 25 points
#   beach_1116.png: 10 points
#   runwa_1842.png: 15 points
#   dense_1437.png: 360 points
#   beach_1192.png: 10 points
#   mobil_796.png: 195 points
#   harbo_423.png: 25 points
#   mediu_1221.png: 240 points
#   stora_559.png: 105 points
#   fores_656.png: 5 points
#   river_1391.png: 25 points
#   golfc_91.png: 75 points
#   mediu_1210.png: 130 points
#   chapa_1704.png: 565 points
#   airpl_898.png: 95 points
#   baseb_910.png: 15 points
#   fores_662.png: 5 points
#   river_1386.png: 15 points
#   golfc_18.png: 35 points
#   stora_558.png: 95 points
#   stora_580.png: 25 points
#   airpl_814.png: 70 points
#   mobil_737.png: 190 points
#   parki_271.png: 178 points
#   airpl_826.png: 54 points
#   dense_1461.png: 40 points
#   build_1617.png: 30 points
#   freew_320.png: 60 points
#   mediu_1223.png: 170 points
#   mobil_750.png: 145 points
#   mediu_1228.png: 162 points
#   tenni_1003.png: 80 points
#   build_1666.png: 5 points
#   fores_668.png: 5 points
#   mediu_1289.png: 80 points
#   fores_690.png: 5 points
#   tenni_1025.png: 70 points
#   freew_312.png: 95 points
#   chapa_1712.png: 559 points
#   beach_1176.png: 10 points
#   spars_112.png: 100 points
#   parki_292.png: 160 points
#   build_1640.png: 40 points
#   inter_2081.png: 245 points
#   inter_2043.png: 175 points
#   runwa_1870.png: 15 points
#   parki_244.png: 75 points
#   harbo_431.png: 20 points
#   parki_272.png: 55 points
#   tenni_1041.png: 95 points
#   harbo_461.png: 137 points
#   chapa_1705.png: 481 points
#   parki_259.png: 95 points
#   beach_1184.png: 10 points
#   dense_1456.png: 80 points
#   harbo_475.png: 104 points
#   golfc_68.png: 25 points
#   beach_1140.png: 20 points
#   river_1382.png: 30 points
#   agric_1942.png: 5 points
#   baseb_901.png: 20 points
#   inter_2091.png: 110 points
#   stora_527.png: 50 points
#   dense_1472.png: 235 points
#   spars_164.png: 50 points
#   overp_1560.png: 70 points
#   runwa_1821.png: 10 points
#   overp_1552.png: 55 points
#   spars_134.png: 50 points
#   river_1346.png: 60 points
#   mediu_1230.png: 165 points
#   chapa_1800.png: 650 points
#   beach_1152.png: 10 points
#   golfc_56.png: 105 points
#   baseb_959.png: 80 points
#   chapa_1796.png: 565 points
#   tenni_1047.png: 100 points
#   chapa_1741.png: 875 points
#   agric_1993.png: 5 points
#   fores_601.png: 5 points
#   stora_579.png: 15 points
#   freew_317.png: 75 points
#   overp_1555.png: 95 points
#   mediu_1244.png: 166 points
#   mobil_765.png: 195 points
#   baseb_944.png: 30 points
#   mobil_754.png: 210 points
#   harbo_465.png: 114 points
#   harbo_483.png: 112 points
#   mobil_713.png: 225 points
#   parki_245.png: 140 points
#   mediu_1297.png: 180 points
#   baseb_946.png: 25 points
#   golfc_86.png: 120 points
#   tenni_1050.png: 220 points
#   spars_167.png: 95 points
#   freew_381.png: 145 points
#   beach_1178.png: 10 points
#   fores_637.png: 5 points
#   agric_1994.png: 5 points
#   overp_1581.png: 65 points
#   airpl_869.png: 90 points
#   stora_596.png: 111 points
#   dense_1447.png: 135 points
#   freew_387.png: 75 points
#   chapa_1760.png: 731 points
#   chapa_1767.png: 5 points
#   build_1681.png: 120 points
#   river_1383.png: 15 points
#   golfc_16.png: 35 points
#   chapa_1792.png: 434 points
#   mobil_730.png: 230 points
#   overp_1546.png: 70 points
#   mediu_1290.png: 95 points
#   airpl_866.png: 75 points
#   mobil_734.png: 280 points
#   tenni_1063.png: 110 points
#   build_1624.png: 5 points
#   beach_1193.png: 10 points
#   beach_1148.png: 10 points
# Loaded point annotations for 2100 images
# Found 1319 pseudo images
# Saved confidence data to: pseudo_confidence_scores.csv
# Total pseudo samples: 1319
# Confidence Statistics:
#   Range: 0.518 to 0.995
#   Mean: 0.725
#   Good (>=0.7): 791
#   Fair (0.5-0.7): 528
#   Bad (<0.5): 0
# Confidence calculation completed!

# %%
# cutmix_sam_trainer.py
import torch
import numpy as np
import random
from typing import List, Tuple, Optional
import cv2
import os
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from segment_anything import sam_model_registry
from torch.optim import Adam
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from scipy import ndimage

# ==================== CONFIGURATION ====================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Paths - UPDATE THESE
REAL_IMAGES_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_images'  # 630 real images
REAL_MASKS_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_1cmasks'   # 630 real masks
PSEUDO_IMAGES_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/full_test_images'  # 1300 pseudo images
PSEUDO_MASKS_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/topo_refined_predictions'    # 1300 pseudo masks
CONFIDENCE_CSV_PATH = "pseudo_confidence_scores.csv"  # From Script 1
sam_checkpoint = "/home/iiitdmk-param/Desktop/Research/3/Data/sam_vit_b.pth"
model_type = "vit_b"

# Training parameters
BATCH_SIZE = 4
NUM_EPOCHS = 100
LEARNING_RATE = 1e-4
NUM_CLASSES = 18
TOPO_LOSS_WEIGHT = 0.3

# CutMix parameters
MINORITY_CLASSES = [1, 4, 7, 10, 14, 15]  # airplane, cars, dock, mobile home, ship, tanks

# ==================== CLASS INFORMATION ====================
CLASS_INFO = {
    0: {"name": "background", "rgb": [0, 0, 0]},
    1: {"name": "airplane", "rgb": [166, 202, 240]},
    2: {"name": "bare soil", "rgb": [128, 128, 0]},
    3: {"name": "buildings", "rgb": [0, 0, 128]},
    4: {"name": "cars", "rgb": [255, 0, 0]},
    5: {"name": "chaparral", "rgb": [0, 128, 0]},
    6: {"name": "court", "rgb": [128, 0, 0]},
    7: {"name": "dock", "rgb": [255, 233, 233]},
    8: {"name": "field", "rgb": [160, 160, 164]},
    9: {"name": "grass", "rgb": [0, 128, 128]},
    10: {"name": "mobile home", "rgb": [90, 87, 255]},
    11: {"name": "pavement", "rgb": [255, 255, 0]},
    12: {"name": "sand", "rgb": [255, 192, 0]},
    13: {"name": "sea", "rgb": [0, 0, 255]},
    14: {"name": "ship", "rgb": [255, 0, 192]},
    15: {"name": "tanks", "rgb": [128, 0, 128]},
    16: {"name": "trees", "rgb": [0, 255, 0]},
    17: {"name": "water", "rgb": [0, 255, 255]}
}

# ==================== CUTMIX CLASS ====================
class ConfidenceGuidedCutMix:
    def __init__(self, 
                 real_images_dir: str,
                 real_masks_dir: str, 
                 pseudo_images_dir: str,
                 pseudo_masks_dir: str,
                 confidence_csv_path: str,
                 minority_classes: List[int] = None):
        
        self.num_classes = len(CLASS_INFO)
        self.minority_classes = minority_classes or []
        
        # Load real data (630 images)
        self.real_data = self._load_real_data(real_images_dir, real_masks_dir)
        
        # Load pseudo data (1300 images) with confidence
        self.pseudo_data = self._load_pseudo_data(pseudo_images_dir, pseudo_masks_dir, confidence_csv_path)
        
        print(f"Loaded {len(self.real_data)} real samples")
        print(f"Loaded {len(self.pseudo_data)} pseudo samples with pre-computed confidence")
        
        # Training phase parameters
        self.phase = 1
        self.phase_parameters = {
            1: {'max_cut_ratio': 0.2, 'min_cut_ratio': 0.1, 'source_type': 'real_only', 'cutmix_prob': 0.6},
            2: {'max_cut_ratio': 0.4, 'min_cut_ratio': 0.2, 'source_type': 'mixed', 'cutmix_prob': 0.8},
            3: {'max_cut_ratio': 0.5, 'min_cut_ratio': 0.3, 'source_type': 'any', 'cutmix_prob': 0.9}
        }
    
    def _load_real_data(self, images_dir: str, masks_dir: str):
        """Load real data (630 images) for CutMix donors"""
        real_data = []
        image_paths = glob(os.path.join(images_dir, "*.png")) + glob(os.path.join(images_dir, "*.jpg"))
        
        print(f"Loading real data from {images_dir}...")
        
        for img_path in image_paths:
            base_name = os.path.basename(img_path)
            mask_name = base_name.replace('.jpg', '.png').replace('.jpeg', '.png')
            mask_path = os.path.join(masks_dir, mask_name)
            
            if os.path.exists(mask_path):
                try:
                    # Load RGB image
                    image = cv2.imread(img_path)
                    # Load 1-channel mask
                    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                    
                    if image is not None and mask is not None:
                        mask = np.clip(mask, 0, self.num_classes - 1)
                        real_data.append((image, mask, base_name))
                except Exception as e:
                    print(f"Error loading real data {base_name}: {e}")
        
        return real_data
    
    def _load_pseudo_data(self, images_dir: str, masks_dir: str, csv_path: str):
        """Load pseudo data (1300 images) with confidence from CSV"""
        # First load the CSV to get confidence scores
        df = pd.read_csv(csv_path)
        confidence_dict = {}
        for _, row in df.iterrows():
            confidence_dict[row['image_name']] = row['confidence']
        
        pseudo_data = []
        image_paths = glob(os.path.join(images_dir, "*.png")) + glob(os.path.join(images_dir, "*.jpg"))
        
        print(f"Loading pseudo data from {images_dir}...")
        
        for img_path in image_paths:
            base_name = os.path.basename(img_path)
            mask_name = base_name.replace('.jpg', '.png').replace('.jpeg', '.png')
            mask_path = os.path.join(masks_dir, mask_name)
            
            if os.path.exists(mask_path):
                try:
                    # Load RGB image
                    image = cv2.imread(img_path)
                    # Load 1-channel mask
                    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                    
                    if image is not None and mask is not None:
                        mask = np.clip(mask, 0, self.num_classes - 1)
                        
                        # Get confidence from CSV
                        confidence = confidence_dict.get(base_name, 0.5)  # Default if not found
                        
                        # For point annotations, use empty for now
                        points = []
                        
                        pseudo_data.append((image, mask, confidence, base_name, points))
                        
                except Exception as e:
                    print(f"Error loading pseudo data {base_name}: {e}")
        
        # Sort by confidence (high to low)
        pseudo_data.sort(key=lambda x: x[2], reverse=True)
        
        # Print confidence distribution
        confidences = [x[2] for x in pseudo_data]
        #print(f"Pseudo data confidence - Min: {min(confidences):.3f}, Max: {max(confidences):.3f}, Mean: {np.mean(confidences):.3f}")
        
        return pseudo_data
    
    def set_phase(self, phase: int):
        """Set current training phase (1, 2, or 3)"""
        self.phase = phase
        params = self.phase_parameters[phase]
        #print(f"CutMix Phase {phase} activated: {params}")
    
    def get_donor_sample(self):
        """Get donor sample based on current phase"""
        params = self.phase_parameters[self.phase]
        
        if params['source_type'] == 'real_only':
            return random.choice(self.real_data)
        elif params['source_type'] == 'mixed':
            if random.random() < 0.7:
                return random.choice(self.real_data)
            else:
                high_conf_count = max(1, len(self.pseudo_data) // 3)
                high_conf_samples = self.pseudo_data[:high_conf_count]
                return random.choice(high_conf_samples) if high_conf_samples else random.choice(self.real_data)
        else:
            if random.random() < 0.6:
                return random.choice(self.real_data)
            else:
                return random.choice(self.pseudo_data)
    
    def find_minority_class_regions(self, mask: np.ndarray) -> List[Tuple]:
        """Find bounding boxes around minority class instances"""
        if not self.minority_classes:
            return []
        
        regions = []
        for class_id in self.minority_classes:
            class_mask = (mask == class_id).astype(np.uint8)
            
            if np.sum(class_mask) > 0:
                contours, _ = cv2.findContours(class_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                for contour in contours:
                    if cv2.contourArea(contour) > 50:
                        x, y, w, h = cv2.boundingRect(contour)
                        pad = 5
                        x = max(0, x - pad)
                        y = max(0, y - pad)
                        w = min(mask.shape[1] - x, w + 2 * pad)
                        h = min(mask.shape[0] - y, h + 2 * pad)
                        regions.append((x, y, w, h, class_id))
        
        return regions
    
    def create_protection_zones(self, points: List, image_shape: Tuple, radius: int = 10) -> np.ndarray:
        """Create protection masks around point annotations"""
        protection_mask = np.zeros(image_shape[:2], dtype=np.uint8)
        
        for point in points:
            if len(point) >= 3:
                x, y, class_id = point
                x = max(0, min(int(x), image_shape[1] - 1))
                y = max(0, min(int(y), image_shape[0] - 1))
                cv2.circle(protection_mask, (x, y), radius, 1, -1)
        
        return protection_mask
    
    def calculate_cutmix_region(self, donor_mask: np.ndarray, recipient_info: Tuple, protection_mask: np.ndarray) -> Optional[Tuple]:
        params = self.phase_parameters[self.phase]
        h, w = donor_mask.shape
        
        minority_regions = self.find_minority_class_regions(donor_mask)
        
        if minority_regions and random.random() < 0.8:
            x, y, region_w, region_h, class_id = random.choice(minority_regions)
        else:
            min_size = int(params['min_cut_ratio'] * min(h, w))
            max_size = int(params['max_cut_ratio'] * min(h, w))
            region_size = random.randint(min_size, max_size)
            x = random.randint(0, w - region_size)
            y = random.randint(0, h - region_size)
            region_w = region_size
            region_h = region_size
        
        if x < 0 or y < 0 or x + region_w > w or y + region_h > h:
            return None
        
        if self.phase == 1:
            region_mask = np.zeros_like(protection_mask)
            region_mask[y:y+region_h, x:x+region_w] = 1
            if np.sum(region_mask * protection_mask) > 0:
                return None
        elif self.phase == 2:
            region_mask = np.zeros_like(protection_mask)
            region_mask[y:y+region_h, x:x+region_w] = 1
            overlap_ratio = np.sum(region_mask * protection_mask) / np.sum(region_mask)
            if overlap_ratio > 0.2:
                return None
        
        return (x, y, region_w, region_h)
    
    def apply_confidence_aware_blending(self, donor_region_mask: np.ndarray, recipient_region_mask: np.ndarray, recipient_confidence: float) -> np.ndarray:
        blended_mask = recipient_region_mask.copy()
        
        if recipient_confidence < 0.3:
            blended_mask = donor_region_mask.copy()
        elif recipient_confidence < 0.7:
            replace_prob = 1.0 - recipient_confidence
            for i in range(blended_mask.shape[0]):
                for j in range(blended_mask.shape[1]):
                    if random.random() < replace_prob:
                        blended_mask[i, j] = donor_region_mask[i, j]
        else:
            for i in range(blended_mask.shape[0]):
                for j in range(blended_mask.shape[1]):
                    if donor_region_mask[i, j] in self.minority_classes:
                        if random.random() < 0.3:
                            blended_mask[i, j] = donor_region_mask[i, j]
        
        return blended_mask
    
    def apply_cutmix(self, recipient_idx: int) -> Tuple[np.ndarray, np.ndarray, bool]:
        recipient_img, recipient_mask, confidence, name, points = self.pseudo_data[recipient_idx]
        donor_sample = self.get_donor_sample()
        
        if len(donor_sample) == 3:
            donor_img, donor_mask, donor_name = donor_sample
        else:
            donor_img, donor_mask, _, donor_name, _ = donor_sample
        
        if donor_img.shape[:2] != recipient_img.shape[:2]:
            donor_img = cv2.resize(donor_img, (recipient_img.shape[1], recipient_img.shape[0]))
            donor_mask = cv2.resize(donor_mask, (recipient_img.shape[1], recipient_img.shape[0]), 
                                  interpolation=cv2.INTER_NEAREST)
        
        protection_mask = self.create_protection_zones(points, recipient_img.shape[:2])
        cutmix_params = self.calculate_cutmix_region(donor_mask, self.pseudo_data[recipient_idx], protection_mask)
        
        if cutmix_params is None:
            return recipient_img, recipient_mask, False
        
        x, y, w, h = cutmix_params
        donor_region_mask = donor_mask[y:y+h, x:x+w]
        donor_region_img = donor_img[y:y+h, x:x+w]
        recipient_region_mask = recipient_mask[y:y+h, x:x+w]
        
        blended_mask = self.apply_confidence_aware_blending(donor_region_mask, recipient_region_mask, confidence)
        
        result_img = recipient_img.copy()
        result_mask = recipient_mask.copy()
        result_img[y:y+h, x:x+w] = donor_region_img
        result_mask[y:y+h, x:x+w] = blended_mask
        
        return result_img, result_mask, True
    
    def get_cutmix_batch(self, batch_size: int = 8) -> Tuple[List, List]:
        """Generate a training batch with CutMix augmentation"""
        batch_images = []
        batch_masks = []
        
        params = self.phase_parameters[self.phase]
        cutmix_prob = params['cutmix_prob']
        cutmix_applied_count = 0
        
        for _ in range(batch_size):
            recipient_idx = random.randint(0, len(self.pseudo_data) - 1)
            
            if random.random() < cutmix_prob:
                aug_img, aug_mask, applied = self.apply_cutmix(recipient_idx)
                if applied:
                    cutmix_applied_count += 1
                else:
                    aug_img, aug_mask, _, _, _ = self.pseudo_data[recipient_idx]
            else:
                aug_img, aug_mask, _, _, _ = self.pseudo_data[recipient_idx]
            
            batch_images.append(aug_img)
            batch_masks.append(aug_mask)
        
        #print(f"CutMix applied to {cutmix_applied_count}/{batch_size} samples")
        return batch_images, batch_masks

# ==================== TOPOLOGICAL LOSS ====================
class TopologicalLoss(nn.Module):
    def __init__(self, class_weights=None, eps=1e-8):
        super().__init__()
        self.eps = eps
        
        if class_weights is None:
            self.class_weights = {
                3: 1.0,   # buildings
                11: 1.2,  # pavement
                13: 0.8,  # sea
                17: 0.8,  # water
                8: 0.5,   # field
                5: 0.4,   # chaparral
                9: 0.4,   # grass
                16: 0.4,  # trees
            }
        else:
            self.class_weights = class_weights
            
        self.default_weight = 0.1

    def compute_component_loss(self, pred_binary, target_binary):
        if pred_binary.sum() == 0 and target_binary.sum() == 0:
            return torch.tensor(0.0, device=pred_binary.device)
        
        pred_np = pred_binary.cpu().numpy().astype(np.uint8)
        target_np = target_binary.cpu().numpy().astype(np.uint8)
        
        pred_components, _ = ndimage.label(pred_np)
        target_components, _ = ndimage.label(target_np)
        
        pred_count = np.max(pred_components) if np.max(pred_components) > 0 else 0
        target_count = np.max(target_components) if np.max(target_components) > 0 else 0
        
        comp_diff = torch.abs(torch.tensor(pred_count - target_count, dtype=torch.float32, device=pred_binary.device))
        return comp_diff

    def compute_boundary_loss(self, pred_binary, target_binary):
        if pred_binary.sum() == 0 and target_binary.sum() == 0:
            return torch.tensor(0.0, device=pred_binary.device)
        
        pred_np = pred_binary.cpu().numpy().astype(np.uint8)
        target_np = target_binary.cpu().numpy().astype(np.uint8)
        
        kernel = np.ones((3, 3), np.uint8)
        pred_boundary = cv2.morphologyEx(pred_np, cv2.MORPH_GRADIENT, kernel)
        target_boundary = cv2.morphologyEx(target_np, cv2.MORPH_GRADIENT, kernel)
        
        boundary_intersection = np.logical_and(pred_boundary, target_boundary).sum()
        boundary_union = np.logical_or(pred_boundary, target_boundary).sum()
        
        if boundary_union == 0:
            return torch.tensor(0.0, device=pred_binary.device)
        
        boundary_iou = boundary_intersection / boundary_union
        boundary_loss = 1.0 - boundary_iou
        
        return torch.tensor(boundary_loss, dtype=torch.float32, device=pred_binary.device)

    def forward(self, pred_masks, target_masks):
        batch_size = pred_masks.shape[0]
        total_loss = 0.0
        valid_classes_count = 0
        
        for batch_idx in range(batch_size):
            pred_mask = pred_masks[batch_idx]
            target_mask = target_masks[batch_idx]
            
            unique_classes = torch.unique(torch.cat([pred_mask, target_mask]))
            
            for class_id in unique_classes:
                class_id = class_id.item()
                if class_id == 0:
                    continue
                    
                class_weight = self.class_weights.get(class_id, self.default_weight)
                if class_weight == 0:
                    continue
                
                pred_binary = (pred_mask == class_id).float()
                target_binary = (target_mask == class_id).float()
                
                if pred_binary.sum() == 0 and target_binary.sum() == 0:
                    continue
                
                class_loss = 0.0
                comp_loss = self.compute_component_loss(pred_binary, target_binary)
                class_loss += comp_loss
                
                boundary_loss = self.compute_boundary_loss(pred_binary, target_binary)
                class_loss += boundary_loss
                
                total_loss += class_weight * class_loss
                valid_classes_count += 1
        
        if valid_classes_count > 0:
            total_loss = total_loss / valid_classes_count
        
        return total_loss

# ==================== COMBINED LOSS ====================
class CombinedLoss(nn.Module):
    def __init__(self, topo_weight=TOPO_LOSS_WEIGHT):
        super().__init__()
        self.ce_loss = nn.CrossEntropyLoss()
        self.topo_loss = TopologicalLoss()
        self.topo_weight = topo_weight
    
    def forward(self, logits, targets, pred_masks=None):
        ce_loss = self.ce_loss(logits, targets)
        
        if pred_masks is not None:
            topo_loss = self.topo_loss(pred_masks, targets)
            total_loss = ce_loss + self.topo_weight * topo_loss
            return total_loss, ce_loss, topo_loss
        else:
            return ce_loss, ce_loss, torch.tensor(0.0)

# ==================== MODEL ARCHITECTURE ====================
class HighIoUSAMWrapper(nn.Module):
    def __init__(self, sam_model, num_classes):
        super().__init__()
        self.sam = sam_model
        self.num_classes = num_classes
        
        self.segmentation_head = nn.Sequential(
            nn.Conv2d(256, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, num_classes, 1)
        )
        
        for param in self.sam.image_encoder.parameters():
            param.requires_grad = False
    
    def unfreeze_encoder(self, percentage=0.5):
        total_layers = len(list(self.sam.image_encoder.parameters()))
        layers_to_unfreeze = int(total_layers * percentage)
        
        for i, param in enumerate(self.sam.image_encoder.parameters()):
            if i >= (total_layers - layers_to_unfreeze):
                param.requires_grad = True
    
    def forward(self, x):
        image_embeddings = self.sam.image_encoder(x)
        logits = self.segmentation_head(image_embeddings)
        return logits

# ==================== SIMPLE TRANSFORM ====================
class SimpleTransform:
    def __call__(self, image, mask):
        image = cv2.resize(image, (256, 256))
        mask = cv2.resize(mask, (256, 256), interpolation=cv2.INTER_NEAREST)
        
        image = image.astype(np.float32) / 255.0
        image = (image - np.array([0.485, 0.456, 0.406])) / np.array([0.229, 0.224, 0.225])
        
        image = torch.from_numpy(image).permute(2, 0, 1).float()
        mask = torch.from_numpy(mask).long()
        
        return image, mask

# ==================== METRICS ====================
def calculate_iou(pred_mask, true_mask, num_classes):
    ious = []
    
    for class_id in range(num_classes):
        pred_inds = (pred_mask == class_id)
        target_inds = (true_mask == class_id)
        
        intersection = np.logical_and(pred_inds, target_inds).sum()
        union = np.logical_or(pred_inds, target_inds).sum()
        
        if union == 0:
            ious.append(float('nan'))
        else:
            ious.append(float(intersection / union))
    
    return np.nanmean(ious)

# ==================== MAIN TRAINING FUNCTION WITH CHECKPOINT ====================
def train_sam_with_cutmix():
    print("=== SAM TRAINING WITH CONFIDENCE-GUIDED CUTMIX ===")
    print(f"Using device: {device}")
    print(f"Batch size: {BATCH_SIZE}")
    print(f"Topological loss weight: {TOPO_LOSS_WEIGHT}")
    print(f"Minority classes: {MINORITY_CLASSES}")
    
    # Initialize CutMix with BOTH datasets
    print("Initializing ConfidenceGuidedCutMix...")
    cutmix = ConfidenceGuidedCutMix(
        real_images_dir=REAL_IMAGES_DIR,
        real_masks_dir=REAL_MASKS_DIR,
        pseudo_images_dir=PSEUDO_IMAGES_DIR,
        pseudo_masks_dir=PSEUDO_MASKS_DIR,
        confidence_csv_path=CONFIDENCE_CSV_PATH,
        minority_classes=MINORITY_CLASSES
    )
    
    # Load SAM model
    print("Loading SAM model...")
    sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
    model = HighIoUSAMWrapper(sam, NUM_CLASSES).to(device)
    
    # Loss and optimizer
    criterion = CombinedLoss(topo_weight=TOPO_LOSS_WEIGHT)
    optimizer = Adam(model.parameters(), lr=LEARNING_RATE)
    scheduler = ReduceLROnPlateau(optimizer, mode='max', patience=5, factor=0.5, verbose=True)
    
    # ==================== CHECKPOINT RESUME LOGIC ====================
    start_epoch = 0
    best_iou = 0.0
    checkpoint_path = 'best_cutmix_sam.pth'
    
    # Check if checkpoint exists
    if os.path.exists(checkpoint_path):
        print("🔄 Found checkpoint! Resuming from saved state...")
        checkpoint = torch.load(checkpoint_path, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch'] + 1
        best_iou = checkpoint['iou']
        
        # Load scheduler state if available
        if 'scheduler_state_dict' in checkpoint:
            scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
        
        print(f"✅ Resumed from epoch {start_epoch} with best IoU: {best_iou:.4f}")
    else:
        print("🚀 Starting fresh training...")
    
    transform = SimpleTransform()
    
    print("Starting training with CutMix augmentation...")
    for epoch in range(start_epoch, NUM_EPOCHS):
        # Set CutMix phase
        if epoch < 20:
            cutmix.set_phase(1)  # Conservative
        elif epoch < 40:
            cutmix.set_phase(2)  # Balanced
        else:
            cutmix.set_phase(3)  # Aggressive
        
        # Training phase
        model.train()
        epoch_total_loss = 0
        epoch_ce_loss = 0
        epoch_topo_loss = 0
        num_batches = 0
        
        # Calculate number of batches
        num_batches_per_epoch = max(1, len(cutmix.pseudo_data) // BATCH_SIZE)
        
        for batch_idx in range(num_batches_per_epoch):
            # Get CutMix augmented batch
            batch_images, batch_masks = cutmix.get_cutmix_batch(batch_size=BATCH_SIZE)
            
            # Convert to tensors and apply transformations
            batch_tensors = []
            mask_tensors = []
            
            for img, mask in zip(batch_images, batch_masks):
                img_tensor, mask_tensor = transform(img, mask)
                batch_tensors.append(img_tensor)
                mask_tensors.append(mask_tensor)
            
            images = torch.stack(batch_tensors).to(device)
            masks = torch.stack(mask_tensors).to(device)
            
            if masks.dtype != torch.long:
                masks = masks.long()
            
            optimizer.zero_grad()
            
            # Resize for SAM
            images_resized = F.interpolate(images, size=1024, mode='bilinear', align_corners=False)
            
            # Forward pass
            logits = model(images_resized)
            
            # Resize logits back
            logits = F.interpolate(logits, size=256, mode='bilinear', align_corners=False)
            
            # Get predicted masks for topological loss
            pred_masks = torch.argmax(logits, dim=1)
            
            # Compute combined loss
            total_loss, ce_loss, topo_loss = criterion(logits, masks, pred_masks)
            
            total_loss.backward()
            optimizer.step()
            
            epoch_total_loss += total_loss.item()
            epoch_ce_loss += ce_loss.item()
            epoch_topo_loss += topo_loss.item()
            num_batches += 1
            
            #if batch_idx % 10 == 0:
                #print(f'Epoch {epoch+1}, Batch {batch_idx}: '
                      #f'Total Loss: {total_loss.item():.4f}, '
                      #f'CE: {ce_loss.item():.4f}, '
                      #f'Topo: {topo_loss.item():.4f}')
        
        avg_total_loss = epoch_total_loss / num_batches if num_batches > 0 else 0
        avg_ce_loss = epoch_ce_loss / num_batches if num_batches > 0 else 0
        avg_topo_loss = epoch_topo_loss / num_batches if num_batches > 0 else 0
        
        # Validation phase (using real data)
        model.eval()
        val_iou = 0
        num_val_samples = 0
        
        with torch.no_grad():
            # Sample some real data for validation
            val_indices = random.sample(range(len(cutmix.real_data)), min(50, len(cutmix.real_data)))
            
            for idx in val_indices:
                img, mask, _ = cutmix.real_data[idx]
                img_tensor, mask_tensor = transform(img, mask)
                img_tensor = img_tensor.unsqueeze(0).to(device)
                mask_tensor = mask_tensor.unsqueeze(0).to(device)
                
                img_resized = F.interpolate(img_tensor, size=1024, mode='bilinear', align_corners=False)
                logits = model(img_resized)
                logits = F.interpolate(logits, size=256, mode='bilinear', align_corners=False)
                pred_mask = torch.argmax(logits, dim=1)
                
                iou = calculate_iou(pred_mask[0].cpu().numpy(), mask_tensor[0].cpu().numpy(), NUM_CLASSES)
                val_iou += iou
                num_val_samples += 1
        
        avg_val_iou = val_iou / num_val_samples if num_val_samples > 0 else 0
        scheduler.step(avg_val_iou)
        
        print(f'Epoch {epoch+1}/{NUM_EPOCHS}:')
        print(f'  Train - Total: {avg_total_loss:.4f}, CE: {avg_ce_loss:.4f}, Topo: {avg_topo_loss:.4f}')
        print(f'  Val IoU: {avg_val_iou:.4f}')
        print(f'  CutMix Phase: {cutmix.phase}')
        
        if avg_val_iou > best_iou:
            best_iou = avg_val_iou
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'loss': avg_total_loss,
                'iou': best_iou,
                'ce_loss': avg_ce_loss,
                'topo_loss': avg_topo_loss,
            }, checkpoint_path)
            print(f'✅ Saved new best model with IoU: {best_iou:.4f}')
        
        # EMERGENCY CHECKPOINT - Save every 10 epochs
        if epoch % 10 == 0:
            emergency_path = f'emergency_checkpoint_epoch_{epoch}.pth'
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'loss': avg_total_loss,
                'iou': best_iou,
            }, emergency_path)
            print(f'🛟 Emergency checkpoint saved: {emergency_path}')
        
        # Gradually unfreeze encoder
        if epoch == 20 and epoch >= start_epoch:
            model.unfreeze_encoder(0.3)
            print("🔄 Unfrozen 30% of encoder layers")
        elif epoch == 40 and epoch >= start_epoch:
            model.unfreeze_encoder(0.6)
            print("🔄 Unfrozen 60% of encoder layers")
        elif epoch == 60 and epoch >= start_epoch:
            model.unfreeze_encoder(1.0)
            print("🔄 Unfrozen all encoder layers")
        
        if best_iou > 0.85 and epoch > 50:
            print(f"🎯 Good IoU achieved! Stopping early at epoch {epoch+1}")
            break
    
    print(f"=== TRAINING COMPLETED ===")
    print(f"Best validation IoU: {best_iou:.4f}")
    
    return model, best_iou

# ==================== MAIN EXECUTION ====================
if __name__ == "__main__":
    try:
        trained_model, final_iou = train_sam_with_cutmix()
        
        print(f"\n🎯 TRAINING COMPLETED with IoU: {final_iou:.4f}")
        
        if final_iou >= 0.85:
            print("✅ Excellent performance achieved!")
        else:
            print("⚠️  Consider tuning hyperparameters for better performance")
            
    except RuntimeError as e:
        if "out of memory" in str(e):
            print("💥 OOM Error occurred!")
            print("🔄 Restart the script to resume from the last checkpoint")
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
        raise e
# Out:
# Using device: cuda
# === SAM TRAINING WITH CONFIDENCE-GUIDED CUTMIX ===
# Using device: cuda
# Batch size: 4
# Topological loss weight: 0.3
# Minority classes: [1, 4, 7, 10, 14, 15]
# Initializing ConfidenceGuidedCutMix...
# Loading real data from /home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_images...
# Loading pseudo data from /home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/full_test_images...
# Loaded 630 real samples
# Loaded 1319 pseudo samples with pre-computed confidence
# Loading SAM model...
# /home/iiitdmk-param/AMB/Proposed_3/SAM/segment-anything-main/segment_anything/build_sam.py:105: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(f)
# /home/iiitdmk-param/.local/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# /tmp/ipykernel_2890787/1352371295.py:567: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# 🔄 Found checkpoint! Resuming from saved state...
# ✅ Resumed from epoch 2 with best IoU: 0.1728
# Starting training with CutMix augmentation...
# Epoch 3/100:
#   Train - Total: 23.7776, CE: 1.5596, Topo: 74.0598
#   Val IoU: 0.1691
#   CutMix Phase: 1
# Epoch 4/100:
#   Train - Total: 24.8658, CE: 1.4936, Topo: 77.9072
#   Val IoU: 0.1974
#   CutMix Phase: 1
# ✅ Saved new best model with IoU: 0.1974
# Epoch 5/100:
#   Train - Total: 24.4774, CE: 1.4379, Topo: 76.7982
#   Val IoU: 0.1968
#   CutMix Phase: 1
# Epoch 6/100:
#   Train - Total: 22.7808, CE: 1.3955, Topo: 71.2846
#   Val IoU: 0.1598
#   CutMix Phase: 1
# Epoch 7/100:
#   Train - Total: 23.1405, CE: 1.3893, Topo: 72.5040
#   Val IoU: 0.2094
#   CutMix Phase: 1
# ✅ Saved new best model with IoU: 0.2094
# Epoch 8/100:
#   Train - Total: 22.2601, CE: 1.3223, Topo: 69.7927
#   Val IoU: 0.1431
#   CutMix Phase: 1
# Epoch 9/100:
#   Train - Total: 22.6075, CE: 1.2820, Topo: 71.0849
#   Val IoU: 0.1689
#   CutMix Phase: 1
# Epoch 10/100:
#   Train - Total: 22.4201, CE: 1.2755, Topo: 70.4821
#   Val IoU: 0.1863
#   CutMix Phase: 1
# Epoch 11/100:
#   Train - Total: 22.2870, CE: 1.2633, Topo: 70.0792
#   Val IoU: 0.1734
#   CutMix Phase: 1
# 🛟 Emergency checkpoint saved: emergency_checkpoint_epoch_10.pth
# Epoch 12/100:
#   Train - Total: 22.3249, CE: 1.2220, Topo: 70.3428
#   Val IoU: 0.1826
#   CutMix Phase: 1
# Epoch 13/100:
#   Train - Total: 22.3741, CE: 1.2350, Topo: 70.4636
#   Val IoU: 0.1796
#   CutMix Phase: 1
# Epoch 14/100:
#   Train - Total: 21.5578, CE: 1.1851, Topo: 67.9093
#   Val IoU: 0.1989
#   CutMix Phase: 1
# Epoch 15/100:
#   Train - Total: 21.6937, CE: 1.1753, Topo: 68.3948
#   Val IoU: 0.1861
#   CutMix Phase: 1
# Epoch 16/100:
#   Train - Total: 23.0995, CE: 1.1686, Topo: 73.1029
#   Val IoU: 0.1914
#   CutMix Phase: 1
# Epoch 17/100:
#   Train - Total: 21.5836, CE: 1.1582, Topo: 68.0847
#   Val IoU: 0.1830
#   CutMix Phase: 1
# Epoch 18/100:
#   Train - Total: 20.8599, CE: 1.1421, Topo: 65.7258
#   Val IoU: 0.1772
#   CutMix Phase: 1
# Epoch 19/100:
#   Train - Total: 21.3843, CE: 1.1495, Topo: 67.4493
#   Val IoU: 0.1912
#   CutMix Phase: 1
# Epoch 20/100:
#   Train - Total: 21.0189, CE: 1.1171, Topo: 66.3392
#   Val IoU: 0.1872
#   CutMix Phase: 1
# Epoch 21/100:
#   Train - Total: 23.3743, CE: 1.2001, Topo: 73.9139
#   Val IoU: 0.1804
#   CutMix Phase: 2
# 🛟 Emergency checkpoint saved: emergency_checkpoint_epoch_20.pth
# 🔄 Unfrozen 30% of encoder layers
# 💥 OOM Error occurred!
# 🔄 Restart the script to resume from the last checkpoint
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[5], line 754
#     752     if torch.cuda.is_available():
#     753         torch.cuda.empty_cache()
# --> 754 raise e
#
# Cell In[5], line 739
#     737 if __name__ == "__main__":
#     738     try:
# --> 739         trained_model, final_iou = train_sam_with_cutmix()
#     741         print(f"\n🎯 TRAINING COMPLETED with IoU: {final_iou:.4f}")
#     743         if final_iou >= 0.85:
#
# Cell In[5], line 639, in train_sam_with_cutmix()
#     636 # Compute combined loss
#     637 total_loss, ce_loss, topo_loss = criterion(logits, masks, pred_masks)
# --> 639 total_loss.backward()
#     640 optimizer.step()
#     642 epoch_total_loss += total_loss.item()
#
# File ~/.local/lib/python3.8/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/.local/lib/python3.8/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/.local/lib/python3.8/site-packages/torch/autograd/graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 3.00 GiB. GPU 0 has a total capacity of 23.67 GiB of which 2.76 GiB is free. Including non-PyTorch memory, this process has 20.23 GiB memory in use. Of the allocated memory 17.49 GiB is allocated by PyTorch, and 2.47 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# memory_efficient_cutmix_trainer.py
import torch
import numpy as np
import cv2
import os
import pandas as pd
from glob import glob
from torch.utils.data import Dataset, DataLoader
from segment_anything import sam_model_registry
from torch.optim import Adam
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.amp import autocast, GradScaler
import gc
import random
import time
import sys

# ==================== CONFIGURATION ====================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Paths - UPDATE THESE
REAL_IMAGES_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_images'
REAL_MASKS_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_1cmasks'
PSEUDO_IMAGES_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/full_test_images'
PSEUDO_MASKS_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/topo_refined_predictions'
CONFIDENCE_CSV_PATH = "/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/pseudo_confidence_scores.csv"

# VALIDATION PATHS - PLEASE UPDATE THESE
VAL_IMAGES_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_images'  # UPDATE THIS
VAL_MASKS_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/train_1cmasks'    # UPDATE THIS

sam_checkpoint = "/home/iiitdmk-param/Desktop/Research/3/Data/sam_vit_b.pth"
model_type = "vit_b"

# Training parameters - MEMORY EFFICIENT
BATCH_SIZE = 1
NUM_EPOCHS = 50
LEARNING_RATE = 1e-4
NUM_CLASSES = 18

# SAM expects 1024x1024 input
TARGET_SIZE = 1024

# ==================== PROGRESS BAR ====================
def print_progress_bar(epoch, batch_idx, total_batches, loss, length=50):
    """Print a progress bar for the current epoch"""
    percent = (batch_idx + 1) / total_batches
    filled_length = int(length * percent)
    bar = '█' * filled_length + '─' * (length - filled_length)
    
    sys.stdout.write(f'\rEpoch {epoch+1}/{NUM_EPOCHS} │{bar}│ {batch_idx+1}/{total_batches} ({percent:.1%}) │ Loss: {loss:.4f}')
    sys.stdout.flush()

# ==================== MEMORY MANAGEMENT ====================
def clear_gpu_memory():
    if torch.cuda.is_available():
        torch.cuda.synchronize()
        torch.cuda.empty_cache()
    gc.collect()

def print_gpu_memory():
    if torch.cuda.is_available():
        allocated = torch.cuda.memory_allocated() / 1024**3
        reserved = torch.cuda.memory_reserved() / 1024**3
        print(f"GPU Memory - Allocated: {allocated:.2f}GB, Reserved: {reserved:.2f}GB")

# ==================== VALIDATION DATASET ====================
class ValidationDataset(Dataset):
    def __init__(self, images_dir, masks_dir, transform=None):
        self.image_paths = sorted(glob(os.path.join(images_dir, "*.png")) + 
                                glob(os.path.join(images_dir, "*.jpg")))
        self.mask_paths = []
        self.transform = transform
        self.num_classes = 18
        
        # Match images with masks
        for img_path in self.image_paths:
            base_name = os.path.basename(img_path)
            mask_name = base_name.replace('.jpg', '.png').replace('.jpeg', '.png')
            mask_path = os.path.join(masks_dir, mask_name)
            
            if os.path.exists(mask_path):
                self.mask_paths.append(mask_path)
            else:
                # Try other naming conventions
                for pattern in [f"mask_{base_name}", base_name.replace('.jpg', '_mask.png')]:
                    alt_path = os.path.join(masks_dir, pattern)
                    if os.path.exists(alt_path):
                        self.mask_paths.append(alt_path)
                        break
                else:
                    print(f"⚠️ Warning: No mask found for {base_name}")
        
        # Remove images without masks
        valid_indices = [i for i, mask_path in enumerate(self.mask_paths) if mask_path is not None]
        self.image_paths = [self.image_paths[i] for i in valid_indices]
        self.mask_paths = [self.mask_paths[i] for i in valid_indices]
        
        print(f"✅ Validation set: {len(self.image_paths)} samples")
    
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        try:
            # Load image and mask
            image = cv2.imread(self.image_paths[idx])
            if image is not None:
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            
            mask = cv2.imread(self.mask_paths[idx], cv2.IMREAD_GRAYSCALE)
            if mask is not None:
                mask = np.clip(mask, 0, self.num_classes - 1)
            
            if image is None or mask is None:
                # Create dummy data if loading failed
                image = np.ones((256, 256, 3), dtype=np.uint8) * 128
                mask = np.zeros((256, 256), dtype=np.uint8)
            
            if self.transform:
                image_tensor, mask_tensor = self.transform(image, mask)
            else:
                # No resizing needed since images are already 256x256
                image = image.astype(np.float32) / 255.0
                image = (image - np.array([0.485, 0.456, 0.406])) / np.array([0.229, 0.224, 0.225])
                
                image_tensor = torch.from_numpy(image).permute(2, 0, 1).float()
                mask_tensor = torch.from_numpy(mask).long()
            
            return image_tensor, mask_tensor
            
        except Exception as e:
            print(f"❌ Error loading validation sample {idx}: {e}")
            # Return dummy data
            image_tensor = torch.ones((3, 256, 256), dtype=torch.float32) * 0.5
            mask_tensor = torch.zeros((256, 256), dtype=torch.long)
            return image_tensor, mask_tensor

# ==================== MEMORY EFFICIENT CUTMIX ====================
class MemoryEfficientCutMix:
    def __init__(self, real_images_dir, real_masks_dir, pseudo_images_dir, pseudo_masks_dir, confidence_csv_path):
        self.num_classes = 18
        
        # Load only paths
        self.real_image_paths, self.real_mask_paths = self._load_paths(real_images_dir, real_masks_dir)
        self.pseudo_images_dir = pseudo_images_dir
        self.pseudo_masks_dir = pseudo_masks_dir
        
        # Load pseudo data
        self.pseudo_data = self._load_pseudo_paths(confidence_csv_path)
        
        print(f"Loaded {len(self.real_image_paths)} real samples")
        print(f"Loaded {len(self.pseudo_data)} pseudo samples")
        
        self.phase = 1
        self.phase_params = {
            1: {'cutmix_prob': 0.3, 'max_ratio': 0.2},
            2: {'cutmix_prob': 0.5, 'max_ratio': 0.3},  
            3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
        }
    
    def _load_paths(self, images_dir, masks_dir):
        image_paths = sorted(glob(os.path.join(images_dir, "*.png")) + 
                           glob(os.path.join(images_dir, "*.jpg")))
        mask_paths = []
        
        for img_path in image_paths:
            base_name = os.path.basename(img_path)
            mask_name = base_name.replace('.jpg', '.png').replace('.jpeg', '.png')
            mask_path = os.path.join(masks_dir, mask_name)
            if os.path.exists(mask_path):
                mask_paths.append(mask_path)
            else:
                for pattern in [f"mask_{base_name}", base_name.replace('.jpg', '_mask.png')]:
                    alt_path = os.path.join(masks_dir, pattern)
                    if os.path.exists(alt_path):
                        mask_paths.append(alt_path)
                        break
        
        return image_paths, mask_paths
    
    def _load_pseudo_paths(self, csv_path):
        df = pd.read_csv(csv_path)
        pseudo_data = []
        
        for _, row in df.iterrows():
            image_name = row['image_name']
            image_path = os.path.join(self.pseudo_images_dir, image_name)
            mask_path = os.path.join(self.pseudo_masks_dir, image_name.replace('.jpg', '.png').replace('.jpeg', '.png'))
            
            # Check if files exist before adding
            if os.path.exists(image_path) and os.path.exists(mask_path):
                pseudo_data.append({
                    'image_path': image_path,
                    'mask_path': mask_path, 
                    'confidence': row['confidence'],
                    'base_name': image_name
                })
            else:
                print(f"⚠️ Warning: Missing files for {image_name}")
        
        pseudo_data.sort(key=lambda x: x['confidence'], reverse=True)
        print(f"✅ Valid pseudo samples: {len(pseudo_data)}")
        return pseudo_data
    
    def set_phase(self, phase):
        self.phase = phase
        print(f"CutMix Phase {phase}: {self.phase_params[phase]}")
    
    def load_image_mask(self, image_path, mask_path):
        try:
            image = cv2.imread(image_path)
            if image is None:
                return None, None
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            
            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
            if mask is None:
                return None, None
            mask = np.clip(mask, 0, self.num_classes - 1)
            
            return image, mask
        except Exception as e:
            print(f"❌ Error loading {image_path}: {e}")
            return None, None
    
    def simple_cutmix(self, pseudo_idx):
        params = self.phase_params[self.phase]
        
        pseudo_info = self.pseudo_data[pseudo_idx]
        pseudo_img, pseudo_mask = self.load_image_mask(
            pseudo_info['image_path'], pseudo_info['mask_path']
        )
        
        if pseudo_img is None or pseudo_mask is None:
            return pseudo_img, pseudo_mask, False
        
        if random.random() > params['cutmix_prob']:
            return pseudo_img, pseudo_mask, False
        
        donor_idx = random.randint(0, len(self.real_image_paths) - 1)
        donor_img, donor_mask = self.load_image_mask(
            self.real_image_paths[donor_idx], self.real_mask_paths[donor_idx]
        )
        
        if donor_img is None or donor_mask is None:
            return pseudo_img, pseudo_mask, False
        
        h, w = pseudo_img.shape[:2]
        cut_size = int(min(h, w) * params['max_ratio'] * random.uniform(0.5, 1.0))
        
        x = random.randint(0, w - cut_size)
        y = random.randint(0, h - cut_size)
        
        result_img = pseudo_img.copy()
        result_mask = pseudo_mask.copy()
        
        result_img[y:y+cut_size, x:x+cut_size] = donor_img[y:y+cut_size, x:x+cut_size]
        
        confidence = pseudo_info['confidence']
        if confidence < 0.3:
            result_mask[y:y+cut_size, x:x+cut_size] = donor_mask[y:y+cut_size, x:x+cut_size]
        elif confidence < 0.7:
            donor_region = donor_mask[y:y+cut_size, x:x+cut_size]
            pseudo_region = pseudo_mask[y:y+cut_size, x:x+cut_size]
            replace_mask = np.random.random(donor_region.shape) > confidence
            blended_region = np.where(replace_mask, donor_region, pseudo_region)
            result_mask[y:y+cut_size, x:x+cut_size] = blended_region
        
        del donor_img, donor_mask
        gc.collect()
        
        return result_img, result_mask, True

# ==================== TRAINING DATASET ====================
class MemoryEfficientDataset(Dataset):
    def __init__(self, cutmix_manager, transform=None, use_cutmix=True):
        self.cutmix = cutmix_manager
        self.transform = transform
        self.use_cutmix = use_cutmix
        self.num_pseudo = len(cutmix_manager.pseudo_data)
    
    def __len__(self):
        return self.num_pseudo
    
    def __getitem__(self, idx):
        try:
            if self.use_cutmix:
                image, mask, applied = self.cutmix.simple_cutmix(idx)
                if not applied:
                    pseudo_info = self.cutmix.pseudo_data[idx]
                    image, mask = self.cutmix.load_image_mask(
                        pseudo_info['image_path'], pseudo_info['mask_path']
                    )
            else:
                pseudo_info = self.cutmix.pseudo_data[idx]
                image, mask = self.cutmix.load_image_mask(
                    pseudo_info['image_path'], pseudo_info['mask_path']
                )
            
            if image is None or mask is None:
                image = np.ones((256, 256, 3), dtype=np.uint8) * 128
                mask = np.zeros((256, 256), dtype=np.uint8)
            
            if self.transform:
                image_tensor, mask_tensor = self.transform(image, mask)
            else:
                image = image.astype(np.float32) / 255.0
                image = (image - np.array([0.485, 0.456, 0.406])) / np.array([0.229, 0.224, 0.225])
                
                image_tensor = torch.from_numpy(image).permute(2, 0, 1).float()
                mask_tensor = torch.from_numpy(mask).long()
            
            return image_tensor, mask_tensor
            
        except Exception as e:
            print(f"❌ Error in dataset __getitem__: {e}")
            image_tensor = torch.ones((3, 256, 256), dtype=torch.float32) * 0.5
            mask_tensor = torch.zeros((256, 256), dtype=torch.long)
            return image_tensor, mask_tensor

# ==================== MODEL WRAPPER ====================
class SimpleSAMWrapper(nn.Module):
    def __init__(self, sam_model, num_classes):
        super().__init__()
        self.sam = sam_model
        self.num_classes = num_classes
        self.seg_head = nn.Conv2d(256, num_classes, 1)
        
        # Freeze encoder initially
        for param in self.sam.image_encoder.parameters():
            param.requires_grad = False
    
    def unfreeze_encoder_layers(self, num_layers=5):
        encoder_params = list(self.sam.image_encoder.parameters())
        for param in encoder_params[-num_layers:]:
            param.requires_grad = True
    
    def forward(self, x):
        x_resized = F.interpolate(x, size=TARGET_SIZE, mode='bilinear', align_corners=False)
        features = self.sam.image_encoder(x_resized)
        logits = self.seg_head(features)
        logits = F.interpolate(logits, size=x.shape[2:], mode='bilinear', align_corners=False)
        return logits

# ==================== TRANSFORM ====================
class SimpleTransform:
    def __call__(self, image, mask):
        image = image.astype(np.float32) / 255.0
        image = (image - np.array([0.485, 0.456, 0.406])) / np.array([0.229, 0.224, 0.225])
        
        image_tensor = torch.from_numpy(image).permute(2, 0, 1).float()
        mask_tensor = torch.from_numpy(mask).long()
        
        return image_tensor, mask_tensor

# ==================== COMPUTE IoU ====================
def compute_iou(pred, target, num_classes):
    """Compute IoU for each class"""
    ious = []
    pred = pred.view(-1)
    target = target.view(-1)
    
    for class_id in range(num_classes):
        pred_inds = (pred == class_id)
        target_inds = (target == class_id)
        
        intersection = (pred_inds[target_inds]).sum().float()
        union = pred_inds.sum().float() + target_inds.sum().float() - intersection
        
        if union == 0:
            ious.append(float('nan'))
        else:
            ious.append(float(intersection / union))
    
    return ious

# ==================== TRAINING FUNCTION ====================
def train_memory_efficient():
    print("=== MEMORY EFFICIENT SAM TRAINING WITH CUTMIX ===")
    print(f"Batch size: {BATCH_SIZE}")
    print(f"Image size: 256x256 -> {TARGET_SIZE}x{TARGET_SIZE} for SAM")
    
    clear_gpu_memory()
    
    # Initialize CutMix manager
    cutmix = MemoryEfficientCutMix(
        real_images_dir=REAL_IMAGES_DIR,
        real_masks_dir=REAL_MASKS_DIR,
        pseudo_images_dir=PSEUDO_IMAGES_DIR,
        pseudo_masks_dir=PSEUDO_MASKS_DIR,
        confidence_csv_path=CONFIDENCE_CSV_PATH
    )
    
    # Load validation dataset
    print("Loading validation dataset...")
    val_dataset = ValidationDataset(VAL_IMAGES_DIR, VAL_MASKS_DIR, transform=SimpleTransform())
    val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False, num_workers=0)
    print(f"✅ Validation samples: {len(val_dataset)}")
    
    # Load SAM model
    print("Loading SAM model...")
    sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
    
    if hasattr(sam.image_encoder, 'set_grad_checkpointing'):
        sam.image_encoder.set_grad_checkpointing(True)
        print("✅ Enabled gradient checkpointing")
    
    model = SimpleSAMWrapper(sam, NUM_CLASSES).to(device)
    print("Model loaded successfully")
    
    # Create training datasets
    transform = SimpleTransform()
    train_dataset = MemoryEfficientDataset(cutmix, transform, use_cutmix=True)
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
    
    total_batches = len(train_loader)
    print(f"Total training batches per epoch: {total_batches}")
    
    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=LEARNING_RATE)
    scaler = GradScaler('cuda')
    
    best_iou = 0.0
    
    print("Starting memory-efficient training...")
    for epoch in range(NUM_EPOCHS):
        if epoch < 15:
            cutmix.set_phase(1)
        elif epoch < 30:
            cutmix.set_phase(2)
        else:
            cutmix.set_phase(3)
        
        # Training
        model.train()
        epoch_loss = 0
        num_batches = 0
        
        print(f"\nEpoch {epoch+1}/{NUM_EPOCHS} - Training:")
        
        for batch_idx, (images, masks) in enumerate(train_loader):
            current_loss = 0.0
            try:
                clear_gpu_memory()
                
                images = images.to(device, non_blocking=True)
                masks = masks.to(device, non_blocking=True)
                
                optimizer.zero_grad(set_to_none=True)
                
                with autocast('cuda'):
                    logits = model(images)
                    loss = criterion(logits, masks)
                
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
                
                current_loss = loss.item()
                epoch_loss += current_loss
                num_batches += 1
                
                del images, masks, logits, loss
                clear_gpu_memory()
                
            except RuntimeError as e:
                if "out of memory" in str(e):
                    print("\n⚠️ OOM detected, clearing memory and skipping batch")
                    clear_gpu_memory()
                    continue
                else:
                    print(f"\n❌ Runtime error: {e}")
                    continue
            
            # Update progress bar
            print_progress_bar(epoch, batch_idx, total_batches, current_loss)
        
        # Clear the progress bar line
        sys.stdout.write('\r' + ' ' * 100 + '\r')
        sys.stdout.flush()
        
        avg_loss = epoch_loss / num_batches if num_batches > 0 else 0
        
        # Validation
        print(f"Epoch {epoch+1}/{NUM_EPOCHS} - Validation:")
        model.eval()
        val_loss = 0
        all_ious = []
        val_samples_processed = 0
        
        with torch.no_grad():
            for val_idx, (images, masks) in enumerate(val_loader):
                try:
                    images = images.to(device, non_blocking=True)
                    masks = masks.to(device, non_blocking=True)
                    
                    with autocast('cuda'):
                        logits = model(images)
                        loss = criterion(logits, masks)
                    
                    val_loss += loss.item()
                    
                    # Compute predictions and IoU
                    preds = torch.argmax(logits, dim=1)
                    batch_ious = compute_iou(preds, masks, NUM_CLASSES)
                    
                    # Filter out NaN values
                    valid_ious = [iou for iou in batch_ious if not np.isnan(iou)]
                    if valid_ious:
                        all_ious.extend(valid_ious)
                    
                    val_samples_processed += 1
                    
                    del images, masks, logits, preds
                    
                    # Print validation progress
                    print(f"\r  Progress: {val_idx+1}/{len(val_loader)}", end='')
                    
                except Exception as e:
                    print(f"\n❌ Validation error: {e}")
                    continue
        
        print()  # New line after validation progress
        
        # Compute metrics
        avg_val_loss = val_loss / val_samples_processed if val_samples_processed > 0 else 0
        mean_iou = np.mean(all_ious) if all_ious else 0
        
        print(f"Epoch {epoch+1}/{NUM_EPOCHS} Results:")
        print(f"  Train Loss: {avg_loss:.4f}")
        print(f"  Val Loss: {avg_val_loss:.4f}")
        print(f"  Val mIoU: {mean_iou:.4f}")
        print(f"  Processed {num_batches}/{total_batches} training batches")
        
        if mean_iou > best_iou and val_samples_processed > 0:
            best_iou = mean_iou
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': avg_loss,
                'val_loss': avg_val_loss,
                'iou': best_iou,
            }, 'memory_efficient_sam.pth')
            print(f"  ✅ Saved model with mIoU: {best_iou:.4f}")
        
        # Gradually unfreeze encoder layers
        if epoch == 10:
            model.unfreeze_encoder_layers(3)
            print("  🔄 Unfrozen last 3 encoder layers")
        elif epoch == 20:
            model.unfreeze_encoder_layers(6)
            print("  🔄 Unfrozen last 6 encoder layers")
        
        clear_gpu_memory()
    
    print(f"\n=== TRAINING COMPLETED ===")
    print(f"Best mIoU: {best_iou:.4f}")
    return model, best_iou

# ==================== MAIN ====================
if __name__ == "__main__":
    cv2.setLogLevel(0)
    clear_gpu_memory()
    
    try:
        model, iou = train_memory_efficient()
        print(f"🎯 Final mIoU: {iou:.4f}")
    except Exception as e:
        print(f"❌ Error during training: {e}")
        import traceback
        traceback.print_exc()
    finally:
        clear_gpu_memory()
# Out:
# Using device: cuda
# === MEMORY EFFICIENT SAM TRAINING WITH CUTMIX ===
# Batch size: 1
# Image size: 256x256 -> 1024x1024 for SAM
# ✅ Valid pseudo samples: 1319
# Loaded 630 real samples
# Loaded 1319 pseudo samples
# Loading validation dataset...
# ✅ Validation set: 630 samples
# ✅ Validation samples: 630
# Loading SAM model...
# /home/iiitdmk-param/AMB/Proposed_3/SAM/segment-anything-main/segment_anything/build_sam.py:105: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(f)
# Model loaded successfully
# Total training batches per epoch: 1319
# Starting memory-efficient training...
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 1/50 - Training:
# Epoch 1/50 - Validation:
#   Progress: 630/630
# Epoch 1/50 Results:
#   Train Loss: 2.4936
#   Val Loss: 2.3101
#   Val mIoU: 0.0658
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.0658
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 2/50 - Training:
# Epoch 2/50 - Validation:
#   Progress: 630/630
# Epoch 2/50 Results:
#   Train Loss: 2.1809
#   Val Loss: 2.1833
#   Val mIoU: 0.0878
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.0878
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 3/50 - Training:
# Epoch 3/50 - Validation:
#   Progress: 630/630
# Epoch 3/50 Results:
#   Train Loss: 2.0735
#   Val Loss: 2.1181
#   Val mIoU: 0.1095
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1095
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 4/50 - Training:
# Epoch 4/50 - Validation:
#   Progress: 630/630
# Epoch 4/50 Results:
#   Train Loss: 2.0035
#   Val Loss: 2.0691
#   Val mIoU: 0.1127
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1127
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 5/50 - Training:
# Epoch 5/50 - Validation:
#   Progress: 630/630
# Epoch 5/50 Results:
#   Train Loss: 1.9479
#   Val Loss: 2.0262
#   Val mIoU: 0.1157
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1157
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 6/50 - Training:
# Epoch 6/50 - Validation:
#   Progress: 630/630
# Epoch 6/50 Results:
#   Train Loss: 1.9016
#   Val Loss: 1.9912
#   Val mIoU: 0.1207
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1207
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 7/50 - Training:
# Epoch 7/50 - Validation:
#   Progress: 630/630
# Epoch 7/50 Results:
#   Train Loss: 1.8630
#   Val Loss: 1.9598
#   Val mIoU: 0.1257
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1257
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 8/50 - Training:
# Epoch 8/50 - Validation:
#   Progress: 630/630
# Epoch 8/50 Results:
#   Train Loss: 1.8300
#   Val Loss: 1.9297
#   Val mIoU: 0.1297
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1297
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 9/50 - Training:
# Epoch 9/50 - Validation:
#   Progress: 630/630
# Epoch 9/50 Results:
#   Train Loss: 1.8006
#   Val Loss: 1.9068
#   Val mIoU: 0.1321
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1321
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 10/50 - Training:
# Epoch 10/50 - Validation:
#   Progress: 630/630
# Epoch 10/50 Results:
#   Train Loss: 1.7740
#   Val Loss: 1.8841
#   Val mIoU: 0.1328
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1328
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 11/50 - Training:
# Epoch 11/50 - Validation:
#   Progress: 630/630
# Epoch 11/50 Results:
#   Train Loss: 1.7511
#   Val Loss: 1.8624
#   Val mIoU: 0.1323
#   Processed 1319/1319 training batches
#   🔄 Unfrozen last 3 encoder layers
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 12/50 - Training:
# Epoch 12/50 - Validation:
#   Progress: 630/630
# Epoch 12/50 Results:
#   Train Loss: 1.4798
#   Val Loss: 1.5150
#   Val mIoU: 0.1346
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1346
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 13/50 - Training:
# Epoch 13/50 - Validation:
#   Progress: 630/630
# Epoch 13/50 Results:
#   Train Loss: 1.2952
#   Val Loss: 1.4206
#   Val mIoU: 0.1397
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1397
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 14/50 - Training:
# Epoch 14/50 - Validation:
#   Progress: 630/630
# Epoch 14/50 Results:
#   Train Loss: 1.2159
#   Val Loss: 1.3154
#   Val mIoU: 0.1514
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1514
# CutMix Phase 1: {'cutmix_prob': 0.3, 'max_ratio': 0.2}
#
# Epoch 15/50 - Training:
# Epoch 15/50 - Validation:
#   Progress: 630/630
# Epoch 15/50 Results:
#   Train Loss: 1.1669
#   Val Loss: 1.3223
#   Val mIoU: 0.1519
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1519
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 16/50 - Training:
# Epoch 16/50 - Validation:
#   Progress: 630/630
# Epoch 16/50 Results:
#   Train Loss: 1.1806
#   Val Loss: 1.2502
#   Val mIoU: 0.1586
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1586
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 17/50 - Training:
# Epoch 17/50 - Validation:
#   Progress: 630/630
# Epoch 17/50 Results:
#   Train Loss: 1.1528
#   Val Loss: 1.2203
#   Val mIoU: 0.1613
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1613
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 18/50 - Training:
# Epoch 18/50 - Validation:
#   Progress: 630/630
# Epoch 18/50 Results:
#   Train Loss: 1.1267
#   Val Loss: 1.2641
#   Val mIoU: 0.1570
#   Processed 1319/1319 training batches
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 19/50 - Training:
# Epoch 19/50 - Validation:
#   Progress: 630/630
# Epoch 19/50 Results:
#   Train Loss: 1.1129
#   Val Loss: 1.1955
#   Val mIoU: 0.1650
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1650
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 20/50 - Training:
# Epoch 20/50 - Validation:
#   Progress: 630/630
# Epoch 20/50 Results:
#   Train Loss: 1.1014
#   Val Loss: 1.2609
#   Val mIoU: 0.1599
#   Processed 1319/1319 training batches
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 21/50 - Training:
# Epoch 21/50 - Validation:
#   Progress: 630/630
# Epoch 21/50 Results:
#   Train Loss: 1.0911
#   Val Loss: 1.1528
#   Val mIoU: 0.1636
#   Processed 1319/1319 training batches
#   🔄 Unfrozen last 6 encoder layers
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 22/50 - Training:
# Epoch 22/50 - Validation:
#   Progress: 630/630
# Epoch 22/50 Results:
#   Train Loss: 1.1140
#   Val Loss: 1.1712
#   Val mIoU: 0.1967
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.1967
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 23/50 - Training:
# Epoch 23/50 - Validation:
#   Progress: 630/630
# Epoch 23/50 Results:
#   Train Loss: 1.0350
#   Val Loss: 1.1595
#   Val mIoU: 0.1756
#   Processed 1319/1319 training batches
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 24/50 - Training:
# Epoch 24/50 - Validation:
#   Progress: 630/630
# Epoch 24/50 Results:
#   Train Loss: 0.9866
#   Val Loss: 1.1293
#   Val mIoU: 0.1864
#   Processed 1319/1319 training batches
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 25/50 - Training:
# Epoch 25/50 - Validation:
#   Progress: 630/630
# Epoch 25/50 Results:
#   Train Loss: 0.9583
#   Val Loss: 1.1761
#   Val mIoU: 0.2152
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.2152
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 26/50 - Training:
# Epoch 26/50 - Validation:
#   Progress: 630/630
# Epoch 26/50 Results:
#   Train Loss: 0.9397
#   Val Loss: 1.0280
#   Val mIoU: 0.2071
#   Processed 1319/1319 training batches
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 27/50 - Training:
# Epoch 27/50 - Validation:
#   Progress: 630/630
# Epoch 27/50 Results:
#   Train Loss: 0.9269
#   Val Loss: 1.0458
#   Val mIoU: 0.2311
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.2311
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 28/50 - Training:
# Epoch 28/50 - Validation:
#   Progress: 630/630
# Epoch 28/50 Results:
#   Train Loss: 0.9132
#   Val Loss: 0.9878
#   Val mIoU: 0.2291
#   Processed 1319/1319 training batches
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 29/50 - Training:
# Epoch 29/50 - Validation:
#   Progress: 630/630
# Epoch 29/50 Results:
#   Train Loss: 0.9007
#   Val Loss: 0.9720
#   Val mIoU: 0.2297
#   Processed 1319/1319 training batches
# CutMix Phase 2: {'cutmix_prob': 0.5, 'max_ratio': 0.3}
#
# Epoch 30/50 - Training:
# Epoch 30/50 - Validation:
#   Progress: 630/630
# Epoch 30/50 Results:
#   Train Loss: 0.8824
#   Val Loss: 0.9605
#   Val mIoU: 0.2292
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 31/50 - Training:
# Epoch 31/50 - Validation:
#   Progress: 630/630
# Epoch 31/50 Results:
#   Train Loss: 0.9555
#   Val Loss: 1.0591
#   Val mIoU: 0.2148
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 32/50 - Training:
# Epoch 32/50 - Validation:
#   Progress: 630/630
# Epoch 32/50 Results:
#   Train Loss: 0.9485
#   Val Loss: 0.9123
#   Val mIoU: 0.2525
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.2525
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 33/50 - Training:
# Epoch 33/50 - Validation:
#   Progress: 630/630
# Epoch 33/50 Results:
#   Train Loss: 0.9345
#   Val Loss: 1.0363
#   Val mIoU: 0.2395
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 34/50 - Training:
# Epoch 34/50 - Validation:
#   Progress: 630/630
# Epoch 34/50 Results:
#   Train Loss: 0.9315
#   Val Loss: 0.9506
#   Val mIoU: 0.2270
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 35/50 - Training:
# Epoch 35/50 - Validation:
#   Progress: 630/630
# Epoch 35/50 Results:
#   Train Loss: 0.9240
#   Val Loss: 0.9668
#   Val mIoU: 0.2308
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 36/50 - Training:
# Epoch 36/50 - Validation:
#   Progress: 630/630
# Epoch 36/50 Results:
#   Train Loss: 0.9196
#   Val Loss: 0.9549
#   Val mIoU: 0.2269
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 37/50 - Training:
# Epoch 37/50 - Validation:
#   Progress: 630/630
# Epoch 37/50 Results:
#   Train Loss: 0.9102
#   Val Loss: 0.9736
#   Val mIoU: 0.2241
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 38/50 - Training:
# Epoch 38/50 - Validation:
#   Progress: 630/630
# Epoch 38/50 Results:
#   Train Loss: 0.9088
#   Val Loss: 0.8964
#   Val mIoU: 0.2606
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.2606
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 39/50 - Training:
# Epoch 39/50 - Validation:
#   Progress: 630/630
# Epoch 39/50 Results:
#   Train Loss: 0.9084
#   Val Loss: 0.9333
#   Val mIoU: 0.2416
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 40/50 - Training:
# Epoch 40/50 - Validation:
#   Progress: 630/630
# Epoch 40/50 Results:
#   Train Loss: 0.8953
#   Val Loss: 0.9317
#   Val mIoU: 0.2494
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 41/50 - Training:
# Epoch 41/50 - Validation:
#   Progress: 630/630
# Epoch 41/50 Results:
#   Train Loss: 0.9002
#   Val Loss: 0.9354
#   Val mIoU: 0.2279
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 42/50 - Training:
# Epoch 42/50 - Validation:
#   Progress: 630/630
# Epoch 42/50 Results:
#   Train Loss: 0.8944
#   Val Loss: 0.8765
#   Val mIoU: 0.2382
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 43/50 - Training:
# Epoch 43/50 - Validation:
#   Progress: 630/630
# Epoch 43/50 Results:
#   Train Loss: 0.8875
#   Val Loss: 0.9134
#   Val mIoU: 0.2635
#   Processed 1319/1319 training batches
#   ✅ Saved model with mIoU: 0.2635
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 44/50 - Training:
# Epoch 44/50 - Validation:
#   Progress: 630/630
# Epoch 44/50 Results:
#   Train Loss: 0.8924
#   Val Loss: 0.8991
#   Val mIoU: 0.2454
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 45/50 - Training:
# Epoch 45/50 - Validation:
#   Progress: 630/630
# Epoch 45/50 Results:
#   Train Loss: 0.8809
#   Val Loss: 0.9066
#   Val mIoU: 0.2465
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 46/50 - Training:
# Epoch 46/50 - Validation:
#   Progress: 630/630
# Epoch 46/50 Results:
#   Train Loss: 0.8846
#   Val Loss: 0.9057
#   Val mIoU: 0.2518
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 47/50 - Training:
# Epoch 47/50 - Validation:
#   Progress: 630/630
# Epoch 47/50 Results:
#   Train Loss: 0.8806
#   Val Loss: 0.9354
#   Val mIoU: 0.2450
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 48/50 - Training:
# Epoch 48/50 - Validation:
#   Progress: 630/630
# Epoch 48/50 Results:
#   Train Loss: 0.8770
#   Val Loss: 0.8944
#   Val mIoU: 0.2585
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 49/50 - Training:
# Epoch 49/50 - Validation:
#   Progress: 630/630
# Epoch 49/50 Results:
#   Train Loss: 0.8811
#   Val Loss: 0.8990
#   Val mIoU: 0.2355
#   Processed 1319/1319 training batches
# CutMix Phase 3: {'cutmix_prob': 0.7, 'max_ratio': 0.4}
#
# Epoch 50/50 - Training:
# Epoch 50/50 - Validation:
#   Progress: 630/630
# Epoch 50/50 Results:
#   Train Loss: 0.8768
#   Val Loss: 0.9281
#   Val mIoU: 0.2572
#   Processed 1319/1319 training batches
#
# === TRAINING COMPLETED ===
# Best mIoU: 0.2635
# 🎯 Final mIoU: 0.2635

# %%
import pandas as pd
import os
import shutil
from glob import glob
import cv2
import matplotlib.pyplot as plt
import numpy as np

# ==================== CONFIGURATION ====================
CONFIDENCE_CSV_PATH = "/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/pseudo_confidence_scores.csv"
PSEUDO_IMAGES_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/full_test_images'
PSEUDO_MASKS_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/topo_refined_predictions'

# Output directories for top 10%
TOP_10_IMAGES_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/top_10_percent_images'
TOP_10_MASKS_DIR = '/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/top_10_percent_masks'

# Create output directories
os.makedirs(TOP_10_IMAGES_DIR, exist_ok=True)
os.makedirs(TOP_10_MASKS_DIR, exist_ok=True)

# ==================== YOUR EXACT COLOR MAP ====================
CLASS_INFO = {
    0: {"name": "background", "rgb": [0, 0, 0]},
    1: {"name": "airplane", "rgb": [166, 202, 240]},
    2: {"name": "bare soil", "rgb": [128, 128, 0]},
    3: {"name": "buildings", "rgb": [0, 0, 128]},
    4: {"name": "cars", "rgb": [255, 0, 0]},
    5: {"name": "chaparral", "rgb": [0, 128, 0]},
    6: {"name": "court", "rgb": [128, 0, 0]},
    7: {"name": "dock", "rgb": [255, 233, 233]},
    8: {"name": "field", "rgb": [160, 160, 164]},
    9: {"name": "grass", "rgb": [0, 128, 128]},
    10: {"name": "mobile home", "rgb": [90, 87, 255]},
    11: {"name": "pavement", "rgb": [255, 255, 0]},
    12: {"name": "sand", "rgb": [255, 192, 0]},
    13: {"name": "sea", "rgb": [0, 0, 255]},
    14: {"name": "ship", "rgb": [255, 0, 192]},
    15: {"name": "tanks", "rgb": [128, 0, 128]},
    16: {"name": "trees", "rgb": [0, 255, 0]},
    17: {"name": "water", "rgb": [0, 255, 255]}
}

def extract_top_10_percent():
    print("=== EXTRACTING TOP 10% MOST CONFIDENT PSEUDO IMAGES ===")
    
    # Load confidence scores
    df = pd.read_csv(CONFIDENCE_CSV_PATH)
    print(f"Total pseudo images: {len(df)}")
    
    # Calculate top 10% threshold
    top_10_count = max(1, len(df) // 10)  # At least 1 image
    print(f"Top 10% will contain: {top_10_count} images")
    
    # Sort by confidence (descending) and take top 10%
    top_df = df.nlargest(top_10_count, 'confidence')
    
    print("\n📊 Confidence Range in Top 10%:")
    print(f"  Highest: {top_df['confidence'].max():.4f}")
    print(f"  Lowest: {top_df['confidence'].min():.4f}")
    print(f"  Average: {top_df['confidence'].mean():.4f}")
    
    # Copy images and masks
    copied_count = 0
    missing_files = []
    
    for idx, row in top_df.iterrows():
        image_name = row['image_name']
        confidence = row['confidence']
        
        # Source paths
        src_image_path = os.path.join(PSEUDO_IMAGES_DIR, image_name)
        src_mask_path = os.path.join(PSEUDO_MASKS_DIR, 
                                   image_name.replace('.jpg', '.png').replace('.jpeg', '.png'))
        
        # Destination paths (include confidence in filename for easy identification)
        base_name = os.path.splitext(image_name)[0]
        dst_image_path = os.path.join(TOP_10_IMAGES_DIR, f"{base_name}_conf_{confidence:.4f}.png")
        dst_mask_path = os.path.join(TOP_10_MASKS_DIR, f"{base_name}_conf_{confidence:.4f}.png")
        
        # Copy files if they exist
        if os.path.exists(src_image_path) and os.path.exists(src_mask_path):
            shutil.copy2(src_image_path, dst_image_path)
            shutil.copy2(src_mask_path, dst_mask_path)
            copied_count += 1
            print(f"✅ Copied: {image_name} (conf: {confidence:.4f})")
        else:
            missing_files.append(image_name)
            print(f"❌ Missing: {image_name}")
    
    print(f"\n🎯 EXTRACTION COMPLETE:")
    print(f"  Successfully copied: {copied_count}/{top_10_count} images")
    print(f"  Output directory: {TOP_10_IMAGES_DIR}")
    print(f"  Masks directory: {TOP_10_MASKS_DIR}")
    
    if missing_files:
        print(f"⚠️  Missing files: {len(missing_files)}")
        for missing in missing_files[:5]:  # Show first 5
            print(f"    - {missing}")
    
    return copied_count

def visualize_top_confident_samples(num_samples=5):
    """Visualize with EXACT color map - NO OVERLAYS"""
    print(f"\n=== VISUALIZING TOP {num_samples} CONFIDENT SAMPLES ===")
    
    top_images = sorted(glob(os.path.join(TOP_10_IMAGES_DIR, "*.png")))[:num_samples]
    
    if not top_images:
        print("No images found to visualize!")
        return
    
    def mask_to_color(mask):
        """Convert class indices to RGB colors using EXACT class colors"""
        h, w = mask.shape
        color_mask = np.zeros((h, w, 3), dtype=np.uint8)
        for class_id, class_info in CLASS_INFO.items():
            color_mask[mask == class_id] = class_info["rgb"]
        return color_mask
    
    # 2 columns: Image + Mask (no overlay column)
    fig, axes = plt.subplots(num_samples, 2, figsize=(12, 5*num_samples))
    if num_samples == 1:
        axes = axes.reshape(1, -1)
    
    for idx, image_path in enumerate(top_images):
        if idx >= num_samples:
            break
            
        # Get corresponding mask path
        base_name = os.path.basename(image_path)
        mask_path = os.path.join(TOP_10_MASKS_DIR, base_name)
        
        # Load image and mask
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        
        if image is None:
            print(f"❌ Could not load image: {image_path}")
            continue
        if mask is None:
            print(f"❌ Could not load mask: {mask_path}")
            continue
        
        # Convert mask to EXACT colors
        color_mask = mask_to_color(mask)
        
        # Extract confidence from filename
        confidence = float(base_name.split('_conf_')[1].replace('.png', ''))
        
        # Plot - CLEAN SIDE-BY-SIDE
        axes[idx, 0].imshow(image)
        axes[idx, 0].set_title(f'Image\nConfidence: {confidence:.4f}', fontsize=12)
        axes[idx, 0].axis('off')
        
        axes[idx, 1].imshow(color_mask)  # EXACT COLORS!
        axes[idx, 1].set_title('Mask (Exact Dataset Colors)', fontsize=12)
        axes[idx, 1].axis('off')
    
    plt.tight_layout()
    plt.savefig('/home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/top_confident_samples_exact_colors.png', 
                dpi=150, bbox_inches='tight')
    plt.show()
    
    print(f"✅ Visualization saved as 'top_confident_samples_exact_colors.png'")

def print_class_legend():
    """Print a legend showing class names and colors"""
    print("\n🎨 CLASS LEGEND:")
    print("=" * 50)
    for class_id, class_info in CLASS_INFO.items():
        rgb = class_info["rgb"]
        print(f"Class {class_id:2d}: {class_info['name']:12} → RGB{tuple(rgb)}")

# ==================== MAIN ====================
if __name__ == "__main__":
    # Show class legend first
    print_class_legend()
    
    # Extract top 10%
    copied_count = extract_top_10_percent()
    
    # Visualize if we have samples
    if copied_count > 0:
        visualize_top_confident_samples(min(5, copied_count))
        
        # Print summary of extracted files
        print(f"\n📁 EXTRACTED FILES SUMMARY:")
        print(f"Images in {TOP_10_IMAGES_DIR}: {len(os.listdir(TOP_10_IMAGES_DIR))}")
        print(f"Masks in {TOP_10_MASKS_DIR}: {len(os.listdir(TOP_10_MASKS_DIR))}")
        
        # Show first few filenames with confidence
        image_files = sorted(os.listdir(TOP_10_IMAGES_DIR))[:3]
        print(f"\nSample files (first 3):")
        for file in image_files:
            confidence = float(file.split('_conf_')[1].replace('.png', ''))
            print(f"  - {file} → Confidence: {confidence:.4f}")
            
    else:
        print("❌ No files were copied. Check file paths and permissions.")
# Out:
# 🎨 CLASS LEGEND:
# ==================================================
# Class  0: background   → RGB(0, 0, 0)
# Class  1: airplane     → RGB(166, 202, 240)
# Class  2: bare soil    → RGB(128, 128, 0)
# Class  3: buildings    → RGB(0, 0, 128)
# Class  4: cars         → RGB(255, 0, 0)
# Class  5: chaparral    → RGB(0, 128, 0)
# Class  6: court        → RGB(128, 0, 0)
# Class  7: dock         → RGB(255, 233, 233)
# Class  8: field        → RGB(160, 160, 164)
# Class  9: grass        → RGB(0, 128, 128)
# Class 10: mobile home  → RGB(90, 87, 255)
# Class 11: pavement     → RGB(255, 255, 0)
# Class 12: sand         → RGB(255, 192, 0)
# Class 13: sea          → RGB(0, 0, 255)
# Class 14: ship         → RGB(255, 0, 192)
# Class 15: tanks        → RGB(128, 0, 128)
# Class 16: trees        → RGB(0, 255, 0)
# Class 17: water        → RGB(0, 255, 255)
# === EXTRACTING TOP 10% MOST CONFIDENT PSEUDO IMAGES ===
# Total pseudo images: 1319
# Top 10% will contain: 131 images
#
# 📊 Confidence Range in Top 10%:
#   Highest: 0.9945
#   Lowest: 0.8168
#   Average: 0.9017
# ✅ Copied: baseb_970.png (conf: 0.9945)
# ✅ Copied: beach_1147.png (conf: 0.9935)
# ✅ Copied: beach_1149.png (conf: 0.9930)
# ✅ Copied: beach_1136.png (conf: 0.9930)
# ✅ Copied: beach_1152.png (conf: 0.9930)
# ✅ Copied: beach_1134.png (conf: 0.9928)
# ✅ Copied: beach_1191.png (conf: 0.9926)
# ✅ Copied: beach_1198.png (conf: 0.9924)
# ✅ Copied: beach_1148.png (conf: 0.9924)
# ✅ Copied: beach_1132.png (conf: 0.9924)
# ✅ Copied: beach_1150.png (conf: 0.9924)
# ✅ Copied: beach_1196.png (conf: 0.9923)
# ✅ Copied: beach_1197.png (conf: 0.9923)
# ✅ Copied: beach_1151.png (conf: 0.9923)
# ✅ Copied: beach_1185.png (conf: 0.9923)
# ✅ Copied: beach_1145.png (conf: 0.9923)
# ✅ Copied: beach_1157.png (conf: 0.9923)
# ✅ Copied: beach_1195.png (conf: 0.9923)
# ✅ Copied: beach_1144.png (conf: 0.9923)
# ✅ Copied: beach_1192.png (conf: 0.9923)
# ✅ Copied: beach_1175.png (conf: 0.9912)
# ✅ Copied: beach_1176.png (conf: 0.9907)
# ✅ Copied: runwa_1850.png (conf: 0.9872)
# ✅ Copied: beach_1187.png (conf: 0.9868)
# ✅ Copied: beach_1181.png (conf: 0.9866)
# ✅ Copied: beach_1139.png (conf: 0.9852)
# ✅ Copied: beach_1146.png (conf: 0.9843)
# ✅ Copied: airpl_873.png (conf: 0.9829)
# ✅ Copied: beach_1137.png (conf: 0.9776)
# ✅ Copied: beach_1156.png (conf: 0.9774)
# ✅ Copied: beach_1154.png (conf: 0.9731)
# ✅ Copied: beach_1153.png (conf: 0.9715)
# ✅ Copied: baseb_968.png (conf: 0.9694)
# ✅ Copied: runwa_1841.png (conf: 0.9672)
# ✅ Copied: beach_1162.png (conf: 0.9657)
# ✅ Copied: beach_1193.png (conf: 0.9626)
# ✅ Copied: beach_1131.png (conf: 0.9623)
# ✅ Copied: beach_1155.png (conf: 0.9580)
# ✅ Copied: beach_1138.png (conf: 0.9562)
# ✅ Copied: baseb_969.png (conf: 0.9554)
# ✅ Copied: beach_1199.png (conf: 0.9552)
# ✅ Copied: beach_1189.png (conf: 0.9515)
# ✅ Copied: runwa_1848.png (conf: 0.9513)
# ✅ Copied: airpl_859.png (conf: 0.9494)
# ✅ Copied: runwa_1845.png (conf: 0.9390)
# ✅ Copied: beach_1165.png (conf: 0.9374)
# ✅ Copied: airpl_879.png (conf: 0.9353)
# ✅ Copied: beach_1174.png (conf: 0.9333)
# ✅ Copied: beach_1133.png (conf: 0.9330)
# ✅ Copied: runwa_1844.png (conf: 0.9329)
# ✅ Copied: beach_1158.png (conf: 0.9318)
# ✅ Copied: beach_1180.png (conf: 0.9313)
# ✅ Copied: runwa_1846.png (conf: 0.9289)
# ✅ Copied: runwa_1831.png (conf: 0.9282)
# ✅ Copied: runwa_1833.png (conf: 0.9275)
# ✅ Copied: baseb_971.png (conf: 0.9222)
# ✅ Copied: runwa_1837.png (conf: 0.9163)
# ✅ Copied: runwa_1834.png (conf: 0.9161)
# ✅ Copied: runwa_1842.png (conf: 0.9157)
# ✅ Copied: runwa_1849.png (conf: 0.9149)
# ✅ Copied: runwa_1843.png (conf: 0.9147)
# ✅ Copied: runwa_1836.png (conf: 0.9146)
# ✅ Copied: runwa_1835.png (conf: 0.9115)
# ✅ Copied: runwa_1847.png (conf: 0.8952)
# ✅ Copied: beach_1161.png (conf: 0.8925)
# ✅ Copied: airpl_848.png (conf: 0.8918)
# ✅ Copied: baseb_974.png (conf: 0.8917)
# ✅ Copied: runwa_1840.png (conf: 0.8830)
# ✅ Copied: beach_1182.png (conf: 0.8824)
# ✅ Copied: runwa_1832.png (conf: 0.8791)
# ✅ Copied: baseb_987.png (conf: 0.8733)
# ✅ Copied: runwa_1839.png (conf: 0.8722)
# ✅ Copied: baseb_991.png (conf: 0.8703)
# ✅ Copied: golfc_67.png (conf: 0.8692)
# ✅ Copied: baseb_935.png (conf: 0.8688)
# ✅ Copied: airpl_843.png (conf: 0.8681)
# ✅ Copied: build_1663.png (conf: 0.8673)
# ✅ Copied: beach_1160.png (conf: 0.8663)
# ✅ Copied: airpl_881.png (conf: 0.8662)
# ✅ Copied: golfc_32.png (conf: 0.8649)
# ✅ Copied: beach_1200.png (conf: 0.8644)
# ✅ Copied: golfc_34.png (conf: 0.8626)
# ✅ Copied: beach_1190.png (conf: 0.8625)
# ✅ Copied: baseb_966.png (conf: 0.8590)
# ✅ Copied: baseb_977.png (conf: 0.8589)
# ✅ Copied: airpl_844.png (conf: 0.8573)
# ✅ Copied: spars_159.png (conf: 0.8520)
# ✅ Copied: airpl_845.png (conf: 0.8482)
# ✅ Copied: overp_1599.png (conf: 0.8477)
# ✅ Copied: beach_1164.png (conf: 0.8455)
# ✅ Copied: build_1693.png (conf: 0.8446)
# ✅ Copied: airpl_886.png (conf: 0.8394)
# ✅ Copied: beach_1194.png (conf: 0.8382)
# ✅ Copied: beach_1177.png (conf: 0.8380)
# ✅ Copied: baseb_975.png (conf: 0.8373)
# ✅ Copied: overp_1565.png (conf: 0.8364)
# ✅ Copied: beach_1179.png (conf: 0.8363)
# ✅ Copied: beach_1178.png (conf: 0.8346)
# ✅ Copied: overp_1600.png (conf: 0.8344)
# ✅ Copied: overp_1566.png (conf: 0.8331)
# ✅ Copied: beach_1171.png (conf: 0.8324)
# ✅ Copied: build_1645.png (conf: 0.8314)
# ✅ Copied: beach_1184.png (conf: 0.8304)
# ✅ Copied: spars_155.png (conf: 0.8304)
# ✅ Copied: baseb_986.png (conf: 0.8301)
# ✅ Copied: airpl_836.png (conf: 0.8298)
# ✅ Copied: golfc_100.png (conf: 0.8296)
# ✅ Copied: overp_1583.png (conf: 0.8296)
# ✅ Copied: baseb_967.png (conf: 0.8296)
# ✅ Copied: baseb_952.png (conf: 0.8276)
# ✅ Copied: overp_1550.png (conf: 0.8268)
# ✅ Copied: parki_299.png (conf: 0.8259)
# ✅ Copied: beach_1163.png (conf: 0.8252)
# ✅ Copied: dense_1453.png (conf: 0.8250)
# ✅ Copied: golfc_39.png (conf: 0.8249)
# ✅ Copied: stora_543.png (conf: 0.8245)
# ✅ Copied: overp_1542.png (conf: 0.8240)
# ✅ Copied: stora_580.png (conf: 0.8234)
# ✅ Copied: overp_1585.png (conf: 0.8223)
# ✅ Copied: beach_1167.png (conf: 0.8215)
# ✅ Copied: runwa_1856.png (conf: 0.8209)
# ✅ Copied: stora_538.png (conf: 0.8207)
# ✅ Copied: overp_1582.png (conf: 0.8207)
# ✅ Copied: build_1669.png (conf: 0.8205)
# ✅ Copied: harbo_495.png (conf: 0.8197)
# ✅ Copied: runwa_1858.png (conf: 0.8187)
# ✅ Copied: overp_1597.png (conf: 0.8186)
# ✅ Copied: spars_132.png (conf: 0.8183)
# ✅ Copied: golfc_41.png (conf: 0.8181)
# ✅ Copied: golfc_37.png (conf: 0.8175)
# ✅ Copied: build_1642.png (conf: 0.8168)
#
# 🎯 EXTRACTION COMPLETE:
#   Successfully copied: 131/131 images
#   Output directory: /home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/top_10_percent_images
#   Masks directory: /home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/top_10_percent_masks
#
# === VISUALIZING TOP 5 CONFIDENT SAMPLES ===
# ✅ Visualization saved as 'top_confident_samples_exact_colors.png'
#
# 📁 EXTRACTED FILES SUMMARY:
# Images in /home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/top_10_percent_images: 131
# Masks in /home/iiitdmk-param/A.C/Anisha/4th objective/dlrsd/top_10_percent_masks: 131
#
# Sample files (first 3):
#   - airpl_836_conf_0.8298.png → Confidence: 0.8298
#   - airpl_843_conf_0.8681.png → Confidence: 0.8681
#   - airpl_844_conf_0.8573.png → Confidence: 0.8573
